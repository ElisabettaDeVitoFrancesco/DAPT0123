# %% [markdown]
# # Exploratory analysis of water quality database

# %% [markdown]
# <a id = 'top'><a/>
#
# ## TABLE OF CONTENT
#
# ## [0. Import datasets](#import_dataset)
#
# ### [0.1 Loading datasets](#load_files)
#
# #### [0.1.1 Loading spatial data](#load_spatial)
#
# #### [0.1.2 Loading emissions data](#load_emissions)
#
# #### [0.1.3 Loading monitoring data](#load_monitoring)
#
# #### [0.1.4 Loading aggregated data](#load_aggregated)
#
# ### [0.2 Web scraping](#web_scraping)
#
# ## [1. Exploratory analysis of datasets](#exploratory_analysis)
#
# ### [1.1 Exploratory analysis of spatial dataset](#explore_spatial)
#
# ### [1.2 Exploratory analysis of emissions dataset](#explore_emissions)
#
# ### [1.3 Exploratory analysis of monitoring dataset](#explore_monitoring)
#
# ### [1.4 Exploratory analysis of aggregated dataset](#explore_aggregated)
#
# ## [2. SQL Server connection](#SQL_connection)
#
# ### [2.1 Create tables in the SQL server database](#create_tables)
#
# #### [2.1.1 Create table with spatial data](#table_spatial)
#
# #### [2.1.2 Create table with emission water quantity data](#table_emissions)
#
# #### [2.1.3 Create table with monitoring data](#table_monitoring)
#
# #### [2.1.4 Create table with measured water quality data](#table_aggregated)

# %% [markdown]
# <a id = 'import_dataset'><a/>
# ## 0. Import datasets
# [Top](#top)
#
# [1.](#exploratory_analysis)

# %% [markdown]
# <a id = 'load_files'><a/>
# ### 0.1 Loading datasets
# [Top](#top)

# %%
from urllib.request import urlopen
import json
import pandas as pd
from pandas import json_normalize
import numpy as np

# %% [markdown]
# <a id = 'load_spatial'><a/>
# #### 0.1.1 Loading spatial data
# [Top](#top)

# %% [markdown]
# The data describing the identifiers, names and locations of the monitored water bodies is referred as "spatial" dataset.
#
# This is imported as a csv file, which was dowloaded from the following website https://discomap.eea.europa.eu/App/DiscodataViewer/?fqn=[WISE_SOE].[v2r1].[Waterbase_S_WISE_SpatialObject_DerivedData].
#
# The json url was not available.

# %%
spatial_raw = pd.read_csv("SpatialObject.csv")
spatial_raw.head()
# Out:
#   countryCode thematicIdIdentifier thematicIdIdentifierScheme  \
# 0          FR         FRFR05234020       euMonitoringSiteCode
# 1          FR         FRFR05236100       euMonitoringSiteCode
# 2          FR         FRFR05237000       euMonitoringSiteCode
# 3          FR         FRFR05238500       euMonitoringSiteCode
# 4          FR         FRGLJ062510T       euMonitoringSiteCode
#
#   monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0             FRFR05234020           euMonitoringSiteCode
# 1             FRFR05236100           euMonitoringSiteCode
# 2             FRFR05237000           euMonitoringSiteCode
# 3             FRFR05238500           euMonitoringSiteCode
# 4             FRGLJ062510T           euMonitoringSiteCode
#
#     monitoringSiteName waterBodyIdentifier waterBodyIdentifierScheme  \
# 0          MAUBOURGUET            FRFR326A    euSurfaceWaterBodyCode
# 1        PONT DE GERDE             FRFR236    euSurfaceWaterBodyCode
# 2               ST-PEE             FRFR273    euSurfaceWaterBodyCode
# 3             BIRIATOU              FRFT08    euSurfaceWaterBodyCode
# 4  RETENUE DE ROPHEMEL             FRGL018    euSurfaceWaterBodyCode
#
#                                        waterBodyName    specialisedZoneType  \
# 0  L'ECHEZ DU CONFLUENT DU CANAL DU MOULIN AU CON...         riverWaterBody
# 1  L'ADOUR DE SA SOURCE AU CONFLUENT DE LA DOULOU...         riverWaterBody
# 2                                         LA NIVELLE         riverWaterBody
# 3                                  ESTUAIRE BIDASSOA  transitionalWaterBody
# 4                                RETENUE DE ROPHEMEL          lakeWaterBody
#
#    ... subUnitIdentifier subUnitIdentifierScheme  \
# 0  ...               FRF           euSubUnitCode
# 1  ...               FRF           euSubUnitCode
# 2  ...               FRF           euSubUnitCode
# 3  ...               FRF           euSubUnitCode
# 4  ...               FRG           euSubUnitCode
#
#                                          subUnitName rbdIdentifier  \
# 0  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...           FRF
# 1  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...           FRF
# 2  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...           FRF
# 3  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...           FRF
# 4  LA LOIRE, LES COURS D'EAU CÔTIERS VENDÉENS ET ...           FRG
#
#   rbdIdentifierScheme                                            rbdName  \
# 0           euRBDCode  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...
# 1           euRBDCode  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...
# 2           euRBDCode  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...
# 3           euRBDCode  LA GARONNE, L'ADOUR, LA DORDOGNE, LA CHARENTE ...
# 4           euRBDCode  LA LOIRE, LES COURS D'EAU CÔTIERS VENDÉENS ET ...
#
#   confidentialityStatus      lon       lat statusCode
# 0                     F  0.03117  43.46819     stable
# 1                     F  0.15756  43.05401     stable
# 2                     F -1.56073  43.35571     stable
# 3                     F -1.74205  43.33168     stable
# 4                     F -2.06050  48.31543     stable
#
# [5 rows x 23 columns]

# %%
records, atrributes = spatial_raw.shape

# %%
print(f"The spatial dataset has {records} records and {atrributes} atrributes.")
# Out:
# The spatial dataset has 73214 records and 23 atrributes.

# %% [markdown]
# <a id = 'load_emissions'><a/>
# #### 0.1.2 Load emissions data
# [Top](#top)

# %% [markdown]
# The dataset that give sinformation about the substances and their amount emitted to the water bodies is referred to as "emissions".
#
# This is imported as json file directly from the website https://discodata.eea.europa.eu/# from the database and table WISE_SOE > latest > Waterbase_T_WISE1_Emissions. The followign query was run on the online server:
#
# SELECT *
# FROM [WISE_SOE].[latest].[Waterbase_T_WISE1_Emissions]
#
# This automatically also created a URL leading to the JSON file. However, this by default included only the first 100 records, therefore the URL was modified changin the attribtue "nrOfHits" from 100 to 103285, the total nr of rows of the table.

# %%
"""
Import json through URL provided by the database online.
The URL shows by default only 100 records (nrOfHits). Therefore it is necessary to loop through the pages (p).
eea_emission_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE1_Emissions%5D&p=1&nrOfHits=103285&mail=null&schema=null"
eea_emission_response = urlopen(eea_emission_url)
emissions_raw = json.loads(eea_emission_response.read())
"""

# %%
emissions_raw = {"results":[]}
p = 1
nr = 1000
while True:
    eea_emission_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%20FROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE1_Emissions%5D&p={page}&nrOfHits={num_record}&mail=null&schema=null".format(page=p, num_record=nr)
    eea_emission_response = urlopen(eea_emission_url)
    json_data = json.loads(eea_emission_response.read())
    if len(json_data.get("results", []))==0:
        break
    else:
        emissions_raw["results"].extend(json_data.get("results", []))
    p = p + 1

# %%
emissions_df_raw = json_normalize(emissions_raw['results'])

# %%
emissions_df_raw
# Out:
#        countryCode spatialUnitIdentifier spatialUnitIdentifierScheme  \
# 0               AT                AT1000                   euRBDCode
# 1               AT                AT1000                   euRBDCode
# 2               AT                AT1000                   euRBDCode
# 3               AT                AT1000                   euRBDCode
# 4               AT                AT1000                   euRBDCode
# ...            ...                   ...                         ...
# 103280          XK                    XK                 countryCode
# 103281          XK                    XK                 countryCode
# 103282          XK                    XK                 countryCode
# 103283          XK                    XK                 countryCode
# 103284          XK                    XK                 countryCode
#
#        phenomenonTimeReferencePeriod observedPropertyDeterminandCode  \
# 0                               2016                   CAS_7439-92-1
# 1                               2016                   CAS_7439-92-1
# 2                               2016                   CAS_7439-97-6
# 3                               2016                   CAS_7440-02-0
# 4                               2016                   CAS_7440-02-0
# ...                              ...                             ...
# 103280                          2019                  EEA_31615-01-7
# 103281                          2020                     EEA_31-02-7
# 103282                          2020                   EEA_3133-01-5
# 103283                          2020                   EEA_3133-03-7
# 103284                          2020                  EEA_31615-01-7
#
#        observedPropertyDeterminandLabel parameterEmissionsSourceCategory  \
# 0                Lead and its compounds                                I
# 1                Lead and its compounds                               U2
# 2             Mercury and its compounds                                I
# 3              Nickel and its compounds                                I
# 4              Nickel and its compounds                               U2
# ...                                 ...                              ...
# 103280                   Total nitrogen                              U22
# 103281           Total suspended solids                              U22
# 103282                             BOD5                              U22
# 103283                            CODCr                              U22
# 103284                   Total nitrogen                              U22
#
#        parameterEPRTRfacilities  resultEmissionsValue resultEmissionsUom  \
# 0                           yes            759.500000               kg/a
# 1                           yes            280.000000               kg/a
# 2                           yes              5.290000               kg/a
# 3                           yes           2568.300000               kg/a
# 4                           yes           3690.000000               kg/a
# ...                         ...                   ...                ...
# 103280                       no              9.477000                t/a
# 103281                       no              6.959722                t/a
# 103282                       no              3.117451                t/a
# 103283                       no             55.646105                t/a
# 103284                       no              6.920974                t/a
#
#        procedureEmissionsMethod resultObservationStatus  \
# 0                    calculated                       X
# 1                    calculated                       X
# 2                    calculated                       X
# 3                    calculated                       X
# 4                    calculated                       X
# ...                         ...                     ...
# 103280                 measured                       A
# 103281                 measured                       A
# 103282                 measured                       A
# 103283                 measured                       A
# 103284                 measured                       A
#
#                                Remarks  \
# 0       data derived from EPRTR by ETC
# 1       data derived from EPRTR by ETC
# 2       data derived from EPRTR by ETC
# 3       data derived from EPRTR by ETC
# 4       data derived from EPRTR by ETC
# ...                                ...
# 103280                            None
# 103281                            None
# 103282                            None
# 103283                            None
# 103284                            None
#
#                                        metadata_versionId  \
# 0       http://discomap.eea.europa.eu/data/wisesoe/der...
# 1       http://discomap.eea.europa.eu/data/wisesoe/der...
# 2       http://discomap.eea.europa.eu/data/wisesoe/der...
# 3       http://discomap.eea.europa.eu/data/wisesoe/der...
# 4       http://discomap.eea.europa.eu/data/wisesoe/der...
# ...                                                   ...
# 103280  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103281  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103282  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103283  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103284  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
#
#        metadata_beginLifeSpanVersion metadata_statusCode  \
# 0            2020-06-08 00:00:00.000        experimental
# 1            2020-06-08 00:00:00.000        experimental
# 2            2020-06-08 00:00:00.000        experimental
# 3            2020-06-08 00:00:00.000        experimental
# 4            2020-06-08 00:00:00.000        experimental
# ...                              ...                 ...
# 103280       2021-01-13 09:43:12.000              stable
# 103281       2022-01-12 23:18:02.000              stable
# 103282       2022-01-12 23:18:02.000              stable
# 103283       2022-01-12 23:18:02.000              stable
# 103284       2022-01-12 23:18:02.000              stable
#
#        metadata_observationStatus metadata_statements     UID
# 0                               A                None  137076
# 1                               A                None  137077
# 2                               A                None  137078
# 3                               A                None  137080
# 4                               A                None  137081
# ...                           ...                 ...     ...
# 103280                          A                None  162583
# 103281                          A                None  179787
# 103282                          A                None  179788
# 103283                          A                None  179789
# 103284                          A                None  179790
#
# [103285 rows x 19 columns]

# %%
record, attributes = emissions_df_raw.shape
print(f"The emisisons df is composed of {record} records and {attributes} attributes.")
# Out:
# The emisisons df is composed of 103285 records and 19 attributes.

# %% [markdown]
# <a id = 'load_monitoring'><a/>
# #### 0.1.3 Loading monitoring data
# [Top](#top)

# %%
monitoring_raw = {"results" : []}

p = 1
nr = 1000000

while True:
    monitoring_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE3_MonitoringData%5D&p={page}&nrOfHits={num_record}&mail=null&schema=null".format(page = p, num_record = nr)
    monitoring_response = urlopen(monitoring_url)
    json_data = json.loads(monitoring_response.read())
    
    if len(json_data.get("results", [])) == 0:
        break
    else:
        monitoring_raw['results'].extend(json_data.get("results", []))
    p = p + 1
# Takes long to load

# %%
monitoring_df_raw = json_normalize(monitoring_raw["results"])

# %% [markdown]
# In case the loading of the JSON file through a URL looping over the entire pages of the resutl table would not work or take to long, the following method to import the data can be chosen.
#
# The total records number is obtained by counting the total records of the table directly at the user interface query editor of the database website https://discodata.eea.europa.eu/#:
# SELECT COUNT(*) AS total_records
# FROM [WISE_SOE].[latest].[Waterbase_T_WISE3_MonitoringData]
#
# Afterward, this number is used to substitute the default value (100) of number of records shown in the URL-JSON which would import the Monitoring dataset, obtained with the query SELECT * AS total_records FROM [WISE_SOE].[latest].[Waterbase_T_WISE3_MonitoringData] directly at the user interface query editor of the database website https://discodata.eea.europa.eu/#.

# %%
monitoring_url_tot_rec = "https://discodata.eea.europa.eu/sql?query=SELECT%20COUNT(*)%20AS%20total_records%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE3_MonitoringData%5D&p=1&nrOfHits=100&mail=null&schema=null"

monitoring_resp_tot_rec = urlopen(monitoring_url_tot_rec)
monitoring_tot_rec_raw = json.loads(monitoring_resp_tot_rec.read())
monitoring_tot_rec_raw2 = json_normalize(monitoring_tot_rec_raw["results"])
monitoring_tot_rec = monitoring_tot_rec_raw2.iloc[0].total_records
monitoring_tot_rec
# Out:
# 4888878

# %%
nr_mon = monitoring_tot_rec

monitoring_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE3_MonitoringData%5D&p=1&nrOfHits={num_rec_mon}&mail=null&schema=null".format(num_rec_mon = nr_mon)
monitoring_response = urlopen(monitoring_url)
monitoring_response
# HTTPError: HTTP Error 500: Internal Server Error
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_23448\1372077080.py in <module>
#       2
#       3 monitoring_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE3_MonitoringData%5D&p=1&nrOfHits={num_rec_mon}&mail=null&schema=null".format(num_rec_mon = nr_mon)
# ----> 4 monitoring_response = urlopen(monitoring_url)
#       5 monitoring_response
#       6 # HTTPError: HTTP Error 500: Internal Server Error
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# ~\anaconda3\lib\urllib\request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# ~\anaconda3\lib\urllib\request.py in https_open(self, req)
#    1387
#    1388         def https_open(self, req):
# -> 1389             return self.do_open(http.client.HTTPSConnection, req,
#    1390                 context=self._context, check_hostname=self._check_hostname)
#    1391
#
# ~\anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1348             except OSError as err: # timeout error
#    1349                 raise URLError(err)
# -> 1350             r = h.getresponse()
#    1351         except:
#    1352             h.close()
#
# ~\anaconda3\lib\http\client.py in getresponse(self)
#    1375         try:
#    1376             try:
# -> 1377                 response.begin()
#    1378             except ConnectionError:
#    1379                 self.close()
#
# ~\anaconda3\lib\http\client.py in begin(self)
#     318         # read until we get a non-100 response
#     319         while True:
# --> 320             version, status, reason = self._read_status()
#     321             if status != CONTINUE:
#     322                 break
#
# ~\anaconda3\lib\http\client.py in _read_status(self)
#     279
#     280     def _read_status(self):
# --> 281         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282         if len(line) > _MAXLINE:
#     283             raise LineTooLong("status line")
#
# ~\anaconda3\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1240                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241                   self.__class__)
# -> 1242             return self.read(nbytes, buffer)
#    1243         else:
#    1244             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\lib\ssl.py in read(self, len, buffer)
#    1098         try:
#    1099             if buffer is not None:
# -> 1100                 return self._sslobj.read(len, buffer)
#    1101             else:
#    1102                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
monitoring_raw = json.loads(monitoring_response.read())
monitoring_df_raw = json_normalize(monitoring_raw["results"])
monitoring_df_raw
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
nr_mon = monitoring_tot_rec

monitoring_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE3_MonitoringData%5D&p=1&nrOfHits={num_rec_mon}&mail=null&schema=null".format(num_rec_mon = nr_mon)
monitoring_response = urlopen(monitoring_url)
# To avoid the unexpected response <http.client.HTTPResponse at 0x1e12612f700>, read the response:
raw_data = monitoring_response.read()
encoding = monitoring_response.info().get_content_charset('utf8')
monitoring_raw = json.loads(raw_data.decode(encoding))

# %% [markdown]
# To avoid the unexpected response <http.client.HTTPResponse at 0x1e12612f700> and HTTPError: HTTP Error 500: Internal Server Error, after trying to get the dataset from URL-JSON obtained with the direct querying at the dataset website, the csv file can be uploaded as follows.

# %%
monitoring_df_raw = pd.read_csv("Monitoring.csv")
monitoring_df_raw
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\630742265.py:1: DtypeWarning: Columns (9,10,15) have mixed types. Specify dtype option on import or set low_memory=False.
#   monitoring_df_raw = pd.read_csv("Monitoring.csv")
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                AT                 AT212753       eionetMonitoringSiteCode
# 1                AT                 AT212753       eionetMonitoringSiteCode
# 2                AT                 AT212753       eionetMonitoringSiteCode
# 3                AT                 AT212753       eionetMonitoringSiteCode
# 4                AT                 AT212753       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4888873          SE          SE635140-128901           euMonitoringSiteCode
# 4888874          SE          SE635140-128901           euMonitoringSiteCode
# 4888875          SE          SE635140-128901           euMonitoringSiteCode
# 4888876          SE          SE635140-128901           euMonitoringSiteCode
# 4888877          SE          SE635140-128901           euMonitoringSiteCode
#
#         observedProperty phenomenonTimePeriod  phenomenonTimePeriod_year  \
# 0                     SF           2007-05-08                       2007
# 1                     SF           2007-05-09                       2007
# 2                     SF           2007-05-10                       2007
# 3                     SF           2007-05-11                       2007
# 4                     SF           2007-05-12                       2007
# ...                  ...                  ...                        ...
# 4888873               SF           2020-08-01                       2020
# 4888874               SF           2020-09-01                       2020
# 4888875               SF           2020-10-01                       2020
# 4888876               SF           2020-11-01                       2020
# 4888877               SF           2020-12-01                       2020
#
#          phenomenonTimePeriod_month  phenomenonTimePeriod_day  \
# 0                               5.0                       8.0
# 1                               5.0                       9.0
# 2                               5.0                      10.0
# 3                               5.0                      11.0
# 4                               5.0                      12.0
# ...                             ...                       ...
# 4888873                         8.0                       1.0
# 4888874                         9.0                       1.0
# 4888875                        10.0                       1.0
# 4888876                        11.0                       1.0
# 4888877                        12.0                       1.0
#
#          resultObservedValue resultObservationStatus Remarks  \
# 0                      26.30                     NaN     NaN
# 1                      25.80                     NaN     NaN
# 2                      25.10                     NaN     NaN
# 3                      24.60                     NaN     NaN
# 4                      25.50                     NaN     NaN
# ...                      ...                     ...     ...
# 4888873                11.40                     NaN     NaN
# 4888874                 8.97                     NaN     NaN
# 4888875                38.80                     NaN     NaN
# 4888876                77.90                     NaN     NaN
# 4888877                61.30                     NaN     NaN
#
#                                         metadata_versionId  \
# 0        http://discomap.eea.europa.eu/data/wisesoe/der...
# 1        http://discomap.eea.europa.eu/data/wisesoe/der...
# 2        http://discomap.eea.europa.eu/data/wisesoe/der...
# 3        http://discomap.eea.europa.eu/data/wisesoe/der...
# 4        http://discomap.eea.europa.eu/data/wisesoe/der...
# ...                                                    ...
# 4888873  https://cdr.eionet.europa.eu/se/eea/wise_soe/w...
# 4888874  https://cdr.eionet.europa.eu/se/eea/wise_soe/w...
# 4888875  https://cdr.eionet.europa.eu/se/eea/wise_soe/w...
# 4888876  https://cdr.eionet.europa.eu/se/eea/wise_soe/w...
# 4888877  https://cdr.eionet.europa.eu/se/eea/wise_soe/w...
#
#         metadata_beginLifeSpanVersion metadata_statusCode  \
# 0             2015-11-30 00:00:00.000        experimental
# 1             2015-11-30 00:00:00.000        experimental
# 2             2015-11-30 00:00:00.000        experimental
# 3             2015-11-30 00:00:00.000        experimental
# 4             2015-11-30 00:00:00.000        experimental
# ...                               ...                 ...
# 4888873       2022-02-12 07:04:29.000               valid
# 4888874       2022-02-12 07:04:29.000               valid
# 4888875       2022-02-12 07:04:29.000               valid
# 4888876       2022-02-12 07:04:29.000               valid
# 4888877       2022-02-12 07:04:29.000               valid
#
#         metadata_observationStatus metadata_statements      UID
# 0                                A                 NaN        1
# 1                                A                 NaN        2
# 2                                A                 NaN        3
# 3                                A                 NaN        4
# 4                                A                 NaN        5
# ...                            ...                 ...      ...
# 4888873                          A                 NaN  6766109
# 4888874                          A                 NaN  6766110
# 4888875                          A                 NaN  6766111
# 4888876                          A                 NaN  6766112
# 4888877                          A                 NaN  6766113
#
# [4888878 rows x 17 columns]

# %%
records, attributes = monitoring_df_raw.shape
print(f"The monitoring dataset has {records} records and {attributes} attributes.")
# Out:
# The monitoring dataset has 4888878 records and 17 attributes.

# %% [markdown]
# <a id = 'load_aggregated'><a/>
# #### 0.1.4 Loading aggregated data
# [Top](#top)

# %%
aggregated_raw = {"results" : []}

p = 1
nr = 1000000

while True:
    aggreagated_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE6_AggregatedData%5D&p={page}&nrOfHits={num_record}&mail=null&schema=null".format(page = p, num_record = nr)
    aggregated_response = urlopen(aggreagated_url)
    json_data = json.loads(aggregated_response.read())
    
    if len(json_data.get("results", [])) == 0:
        break
    else:
        aggregated_raw['results'].extend(json_data.get("results", []))
    p = p + 1

# HTTP Error 500 !!

# %%
aggregated_df_raw = json_normlaize(aggregated_raw["results"])

# %% [markdown]
# Since it returns an error 500, the following method to import the data can be tried.
#
# The total records number is obtained by counting the total records of the table directly at the user interface query editor of the database website https://discodata.eea.europa.eu/#:
# SELECT COUNT(*) AS total_records
# FROM [WISE_SOE].[latest].[Waterbase_T_WISE6_AggregatedData]
#
# Afterward, this number is used to substitute the default value (100) of number of records shown in the URL-JSON which would import the Monitoring dataset, obtained with the query SELECT * AS total_records FROM [WISE_SOE].[latest].[Waterbase_T_WISE6_AggregatedData] directly at the user interface query editor of the database website https://discodata.eea.europa.eu/#.

# %%
aggreagated_url_tot_rec = "https://discodata.eea.europa.eu/sql?query=SELECT%20COUNT(*)%20AS%20total_records%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE6_AggregatedData%5D&p=1&nrOfHits=100&mail=null&schema=null"

aggreagated_resp_tot_rec = urlopen(aggreagated_url_tot_rec)
aggregated_tot_rec_raw = json.loads(aggreagated_resp_tot_rec.read())
aggregated_tot_rec_raw2 = json_normalize(aggregated_tot_rec_raw["results"])
aggregated_tot_rec = aggregated_tot_rec_raw2.iloc[0].total_records
aggregated_tot_rec
# Out:
# 4550559

# %%
nr_aggr = aggregated_tot_rec

aggreagated_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE6_AggregatedData%5D&p=1&nrOfHits={num_rec_aggr}&mail=null&schema=null".format(num_rec_aggr = nr_aggr)
aggregated_response = urlopen(aggreagated_url)
aggregated_raw = json.loads(aggregated_response.read())
aggregated_df_raw = json_normalize(aggregated_raw["results"])
aggregated_df_raw
# Error 500 internal server error

# %% [markdown]
# Since also this attempt to access directyl the database returns a 500 error, internal server error, that can't be managed but only by the server admin, the dataset is directly imported as cav file.

# %%
aggregated_df_raw = pd.read_csv("Aggregated.csv", low_memory=False)
aggregated_df_raw
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                AL                      AL1       eionetMonitoringSiteCode
# 1                AL                      AL1       eionetMonitoringSiteCode
# 2                AL                      AL1       eionetMonitoringSiteCode
# 3                AL                      AL1       eionetMonitoringSiteCode
# 4                AL                      AL1       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4550554          RO                  RO85010           euMonitoringSiteCode
# 4550555          RO                  RO85010           euMonitoringSiteCode
# 4550556          RO                  RO85010           euMonitoringSiteCode
# 4550557          RO                  RO85010           euMonitoringSiteCode
# 4550558          RO                  RO85010           euMonitoringSiteCode
#
#         parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                               LW                  CAS_14265-44-2
# 1                               LW                  CAS_14265-44-2
# 2                               LW                  CAS_14265-44-2
# 3                               LW                  CAS_14265-44-2
# 4                               LW                  CAS_14797-55-8
# ...                            ...                             ...
# 4550554                         RW                   CAS_7440-66-6
# 4550555                         RW                   CAS_7440-47-3
# 4550556                         RW                   CAS_7440-38-2
# 4550557                         RW                     EEA_31-02-7
# 4550558                         RW                   EEA_3164-01-0
#
#         observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 0                              Phosphate                       W    mg{P}/L
# 1                              Phosphate                       W    mg{P}/L
# 2                              Phosphate                       W    mg{P}/L
# 3                              Phosphate                       W    mg{P}/L
# 4                                Nitrate                       W  mg{NO3}/L
# ...                                  ...                     ...        ...
# 4550554           Zinc and its compounds                   W-DIS       ug/L
# 4550555       Chromium and its compounds                   W-DIS       ug/L
# 4550556        Arsenic and its compounds                   W-DIS       ug/L
# 4550557           Total suspended solids                       W       mg/L
# 4550558                    Chlorophyll a                       W       ug/L
#
#          phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 0                               2004        2004-01--2004-12  ...
# 1                               2005        2005-01--2005-12  ...
# 2                               2006        2006-01--2006-12  ...
# 3                               2007        2007-01--2007-12  ...
# 4                               2005        2005-01--2005-12  ...
# ...                              ...                     ...  ...
# 4550554                         2017  2017-01-01--2017-12-31  ...
# 4550555                         2017  2017-01-01--2017-12-31  ...
# 4550556                         2017  2017-01-01--2017-12-31  ...
# 4550557                         2017  2017-01-01--2017-12-31  ...
# 4550558                         2017  2017-01-01--2017-12-31  ...
#
#          procedureAnalyticalMethod  parameterSampleDepth  \
# 0                              NaN               -9999.0
# 1                              NaN               -9999.0
# 2                              NaN               -9999.0
# 3                              NaN               -9999.0
# 4                              NaN               -9999.0
# ...                            ...                   ...
# 4550554    Other analytical method                   0.0
# 4550555          EN ISO 15586:2003                   0.0
# 4550556          EN ISO 15586:2003                   0.0
# 4550557                EN 872:2005                   0.0
# 4550558    Other analytical method                   0.0
#
#          resultObservationStatus           remarks  \
# 0                            NaN               NaN
# 1                            NaN               NaN
# 2                            NaN               NaN
# 3                            NaN               NaN
# 4                            NaN               NaN
# ...                          ...               ...
# 4550554                      NaN  EN ISO 8288:2001
# 4550555                      NaN               NaN
# 4550556                      NaN               NaN
# 4550557                      NaN               NaN
# 4550558                      NaN    ISO 10260:1996
#
#                                         metadata_versionId  \
# 0        http://discomap.eea.europa.eu/data/wisesoe/der...
# 1        http://discomap.eea.europa.eu/data/wisesoe/der...
# 2        http://discomap.eea.europa.eu/data/wisesoe/der...
# 3        http://discomap.eea.europa.eu/data/wisesoe/der...
# 4        http://discomap.eea.europa.eu/data/wisesoe/der...
# ...                                                    ...
# 4550554  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550555  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550556  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550557  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550558  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#         metadata_beginLifeSpanVersion  metadata_statusCode  \
# 0             2015-11-30 00:00:00.000         experimental
# 1             2015-11-30 00:00:00.000         experimental
# 2             2015-11-30 00:00:00.000         experimental
# 3             2015-11-30 00:00:00.000         experimental
# 4             2015-11-30 00:00:00.000         experimental
# ...                               ...                  ...
# 4550554       2019-08-29 07:54:03.000         experimental
# 4550555       2019-08-29 07:54:03.000         experimental
# 4550556       2019-08-29 07:54:03.000         experimental
# 4550557       2019-08-29 07:54:03.000         experimental
# 4550558       2019-08-29 07:54:03.000         experimental
#
#         metadata_observationStatus  metadata_statements       UID
# 0                                A                  NaN         1
# 1                                A                  NaN         2
# 2                                A                  NaN         3
# 3                                A                  NaN         4
# 4                                A                  NaN         5
# ...                            ...                  ...       ...
# 4550554                          A                  NaN  17834956
# 4550555                          A                  NaN  17834957
# 4550556                          A                  NaN  17834958
# 4550557                          A                  NaN  17834959
# 4550558                          A                  NaN  17834960
#
# [4550559 rows x 32 columns]

# %%
records, attributes = aggregated_df_raw.shape
print(f"The aggregated dataset has {records} records and {attributes} attributes.")
# Out:
# The aggregated dataset has 4550559 records and 32 attributes.

# %% [markdown]
# <a id = 'load_aggregated_waterbody'><a/>
# #### 0.1.5 Loading aggregated by water body data
# [Top](#top)

# %%
aggregatedwater_raw = {"results":[]}
p = 1
nr = 1000
while True:
    eea_aggregatedwater_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%20FROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE6_AggregatedDataByWaterBody%5D&p={page}&nrOfHits={num_record}&mail=null&schema=null".format(page=p, num_record=nr)
    eea_aggregatedwater_response = urlopen(eea_aggregatedwater_url)
    json_data = json.loads(eea_aggregatedwater_response.read())
    if len(json_data.get("results", []))==0:
        break
    else:
        aggregatedwater_raw["results"].extend(json_data.get("results", []))
    p = p + 1

# %%
aggregatedwater_df_raw = json_normalize(aggregatedwater_raw["results"])

# %%
aggregatedwater_df_raw
# Out:
#       countryCode waterBodyIdentifier  waterBodyIdentifierScheme  \
# 0              AL            ALGW_011  eionetGroundWaterBodyCode
# 1              AL            ALGW_011  eionetGroundWaterBodyCode
# 2              AL            ALGW_011  eionetGroundWaterBodyCode
# 3              AL            ALGW_011  eionetGroundWaterBodyCode
# 4              AL            ALGW_021  eionetGroundWaterBodyCode
# ...           ...                 ...                        ...
# 20612          UK               UK500  eionetGroundWaterBodyCode
# 20613          UK               UK500  eionetGroundWaterBodyCode
# 20614          UK               UK500  eionetGroundWaterBodyCode
# 20615          UK               UK500  eionetGroundWaterBodyCode
# 20616          UK               UK500  eionetGroundWaterBodyCode
#
#       parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                             GW                  CAS_14797-55-8
# 1                             GW                  CAS_14797-55-8
# 2                             GW                  CAS_14797-65-0
# 3                             GW                   EEA_3132-01-2
# 4                             GW                  CAS_14797-65-0
# ...                          ...                             ...
# 20612                         GW                  CAS_14798-03-9
# 20613                         GW                   EEA_3132-01-2
# 20614                         GW                   EEA_3132-01-2
# 20615                         GW                   EEA_3132-01-2
# 20616                         GW                   EEA_3132-01-2
#
#       observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 0                              Nitrate                       W  mg{NO3}/L
# 1                              Nitrate                       W  mg{NO3}/L
# 2                              Nitrite                       W  mg{NO2}/L
# 3                     Dissolved oxygen                       W       mg/L
# 4                              Nitrite                       W  mg{NO2}/L
# ...                                ...                     ...        ...
# 20612                         Ammonium                       W  mg{NH4}/L
# 20613                 Dissolved oxygen                       W       mg/L
# 20614                 Dissolved oxygen                       W       mg/L
# 20615                 Dissolved oxygen                       W       mg/L
# 20616                 Dissolved oxygen                       W       mg/L
#
#        phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 0                             2004  2004-01-01--2004-12-31  ...
# 1                             2005  2005-01-01--2005-12-31  ...
# 2                             2005  2005-01-01--2005-12-31  ...
# 3                             2005  2005-01-01--2005-12-31  ...
# 4                             2004  2004-01-01--2004-12-31  ...
# ...                            ...                     ...  ...
# 20612                         2004  2004-01-01--2004-12-31  ...
# 20613                         2001  2001-01-01--2001-12-31  ...
# 20614                         2002  2002-01-01--2002-12-31  ...
# 20615                         2003  2003-01-01--2003-12-31  ...
# 20616                         2004  2004-01-01--2004-12-31  ...
#
#        resultNumberOfSitesClass4  resultNumberOfSitesClass5  \
# 0                            0.0                        NaN
# 1                            0.0                        NaN
# 2                            1.0                        0.0
# 3                            NaN                        NaN
# 4                            0.0                        1.0
# ...                          ...                        ...
# 20612                        0.0                        NaN
# 20613                        NaN                        NaN
# 20614                        NaN                        NaN
# 20615                        NaN                        NaN
# 20616                        NaN                        NaN
#
#        resultObservationStatus remarks  \
# 0                         None    None
# 1                         None    None
# 2                         None    None
# 3                         None    None
# 4                         None    None
# ...                        ...     ...
# 20612                     None    None
# 20613                     None    None
# 20614                     None    None
# 20615                     None    None
# 20616                     None    None
#
#                                       metadata_versionId  \
# 0      http://discomap.eea.europa.eu/data/wisesoe/der...
# 1      http://discomap.eea.europa.eu/data/wisesoe/der...
# 2      http://discomap.eea.europa.eu/data/wisesoe/der...
# 3      http://discomap.eea.europa.eu/data/wisesoe/der...
# 4      http://discomap.eea.europa.eu/data/wisesoe/der...
# ...                                                  ...
# 20612  http://discomap.eea.europa.eu/data/wisesoe/der...
# 20613  http://discomap.eea.europa.eu/data/wisesoe/der...
# 20614  http://discomap.eea.europa.eu/data/wisesoe/der...
# 20615  http://discomap.eea.europa.eu/data/wisesoe/der...
# 20616  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#       metadata_beginLifeSpanVersion  metadata_statusCode  \
# 0           2015-11-30 00:00:00.000         experimental
# 1           2015-11-30 00:00:00.000         experimental
# 2           2015-11-30 00:00:00.000         experimental
# 3           2015-11-30 00:00:00.000         experimental
# 4           2015-11-30 00:00:00.000         experimental
# ...                             ...                  ...
# 20612       2015-11-30 00:00:00.000         experimental
# 20613       2015-11-30 00:00:00.000         experimental
# 20614       2015-11-30 00:00:00.000         experimental
# 20615       2015-11-30 00:00:00.000         experimental
# 20616       2015-11-30 00:00:00.000         experimental
#
#       metadata_observationStatus  \
# 0                              A
# 1                              A
# 2                              U
# 3                              A
# 4                              A
# ...                          ...
# 20612                          A
# 20613                          A
# 20614                          A
# 20615                          A
# 20616                          A
#
#                                      metadata_statements    UID
# 0      NOTE_LEGACY: The resultNumberOfSamples changed...      1
# 1      NOTE_LEGACY: The resultNumberOfSamples changed...      2
# 2      NOTE_LEGACY: The resultNumberOfSamples changed...      3
# 3      NOTE_LEGACY: The resultNumberOfSamples changed...      4
# 4      NOTE_LEGACY: The resultNumberOfSamples changed...      5
# ...                                                  ...    ...
# 20612  NOTE_LEGACY: The resultNumberOfSamples changed...  19099
# 20613  NOTE_LEGACY: The resultNumberOfSamples changed...  19100
# 20614  NOTE_LEGACY: The resultNumberOfSamples changed...  19101
# 20615  NOTE_LEGACY: The resultNumberOfSamples changed...  19102
# 20616  NOTE_LEGACY: The resultNumberOfSamples changed...  19103
#
# [20617 rows x 35 columns]

# %%
records, attribtues = aggregatedwater_df_raw.shape
print(f"The aggregated by water bodies dataset has {records} records and {attribtues} attribtues.")
# Out:
# The aggregated by water bodies dataset has 20617 records and 35 attribtues.

# %%
aggregatedwater_df_raw['parameterWaterBodyCategory'].unique()
# Out:
# array(['GW'], dtype=object)

# %% [markdown]
# In case the previous method would not work, the following can be tried.

# %%
aggregatedwater_df_raw = aggregatedwater_raw

# %%
aggreagatedwater_url_tot_rec = "https://discodata.eea.europa.eu/sql?query=SELECT%20COUNT(*)%20AS%20total_records%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE6_AggregatedDataByWaterBody%5D&p=1&nrOfHits=100&mail=null&schema=null"

aggreagatedwater_resp_tot_rec = urlopen(aggreagatedwater_url_tot_rec)
aggregatedwater_tot_rec_raw = json.loads(aggreagatedwater_resp_tot_rec.read())
aggregatedwater_tot_rec_raw2 = json_normalize(aggregatedwater_tot_rec_raw["results"])
aggregatedwater_tot_rec = aggregatedwater_tot_rec_raw2.iloc[0].total_records
aggregatedwater_tot_rec
# Out:
# 20617

# %%
nr_aggrw = aggregatedwater_tot_rec

aggreagatedwater_url = "https://discodata.eea.europa.eu/sql?query=SELECT%20*%0AFROM%20%5BWISE_SOE%5D.%5Blatest%5D.%5BWaterbase_T_WISE6_AggregatedDataByWaterBody%5D&p=1&nrOfHits={num_rec_aggrw}&mail=null&schema=null".format(num_rec_aggrw = nr_aggrw)
aggregatedwater_response = urlopen(aggreagatedwater_url)
aggregatedwater_raw = json.loads(aggregatedwater_response.read())
aggregatedwater_df_raw = json_normalize(aggregatedwater_raw["results"])
aggregatedwater_df_raw

# %% [markdown]
# ##### NOTE
# Since the water body considered in this dataset is only Ground Water (GW), this will not be taken into account during the analysis.

# %% [markdown]
# <a id = 'web_scraping'><a/>
# ### 0.2 Web scraping
# [Top](#top)

# %%
# Install the required libraries
# !pip install selenium
"""
Run if not installed yet
# !pip install BeautifulSoup4
# !pip install requests
# !pip install pandas
# !pip install lxml
"""

# %%
# Import the required libraries
from bs4 import BeautifulSoup
import requests
import lxml
from selenium import webdriver
import time

# %%
# Get the url and the permission
url_emissions = "https://discomap.eea.europa.eu/App/DiscodataViewer/?fqn=[WISE_SOE].[v2r1].[Waterbase_T_WISE1_Emissions]#"
requests.get(url_emissions)
# Out:
# <Response [200]>

# %%
# If Response[200] the permission is allowed
# and it is possible to save into text
text_emissions = requests.get(url_emissions)
text_emissions.text

# %%
# Use a parser to change the html code into py-friendly text
soup_emissions = BeautifulSoup(text_emissions.text, 'lxml')
soup_emissions

# %%
# Inspect the html code for 'table'
table_emisisons = soup_emissions.find('table', class_ = 'table table-bordered table-sm ')
table_emisisons

# %%
# Create a list with all the column names
table_emissions_header = soup_emissions.find
headers = []
for i in table_emisisons.find_all('th'):
    title = i.text
    headers.append(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27536\3703361745.py in <module>
#       2 table_emissions_header = soup_emissions.find
#       3 headers = []
# ----> 4 for i in table_emisisons.find_all('th'):
#       5     title = i.text
#       6     headers.append(title)
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
soup_emissions.find_all('table')
# Out:
# []

# %% [markdown]
# ### Using selenium for dynamic html pages

# %%
url_emissions = "https://discomap.eea.europa.eu/App/DiscodataViewer/?fqn=[WISE_SOE].[v2r1].[Waterbase_T_WISE1_Emissions]#"
webdriver = webdriver.Chrome()
webdriver.get(url_emissions)
#time.sleep(2)

# %%
webdriver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(5)
html_emissions = BeautifulSoup(webdriver.page_source,'lxml')

table_emissions = html.find('table', class_ = 'table table-bordered table-sm ')

print(table_emissions.prettify())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_48908\3285086526.py in <module>
#       5 table_emissions = html.find('table', class_ = 'table table-bordered table-sm ')
#       6
# ----> 7 print(table_emissions.prettify())
#
# AttributeError: 'NoneType' object has no attribute 'prettify'

# %%
print(table_emissions)
# Out:
# None

# %% [markdown]
# ### Web scraping populations of European countries

# %%
url_pop = "https://www.worldometers.info/population/countries-in-europe-by-population/"
requests.get(url_pop)
# Out:
# <Response [200]>

# %%
response_pop = requests.get(url_pop)
bft_pop = BeautifulSoup(response_pop.text, 'lxml')

# %%
bft_pop

# %%
table_pop = bft_pop.find('div', class_ = 'table-responsive')
table_pop

# %%
headers_pop = []
for i in table_pop.find_all('th'):
    title = i.text
    headers_pop.append(title)
headers_pop
# Out:
# ['#',
#  'Country (or dependency)',
#  'Population (2023)',
#  'Yearly Change',
#  'Net Change',
#  'Density (P/Km²)',
#  'Land Area (Km²)',
#  'Migrants (net)',
#  'Fert. Rate',
#  'Med. Age',
#  'Urban Pop %',
#  'World Share']

# %%
pop_df = pd.DataFrame(columns = headers_pop)
pop_df
# Out:
# Empty DataFrame
# Columns: [#, Country (or dependency), Population (2023), Yearly Change, Net Change, Density (P/Km²), Land Area (Km²), Migrants (net), Fert. Rate, Med. Age, Urban Pop %, World Share]
# Index: []

# %%
for j in table_pop.find_all('tr')[1:]:
    row_data = j.find_all('td')
    print(row_data)

# %%
for j in table_pop.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [i.text for i in row_data] # Creates lists of values, which correspond to the table's rows
    length = len(pop_df)
    pop_df.loc[length] = row # At the position lenght, assignthe new row of values

# %%
pop_df
# Out:
#      #   Country (or dependency) Population (2023) Yearly Change  Net Change  \
# 0    1                    Russia       144,444,359       -0.19 %    -268,955
# 1    2                   Germany        83,294,633       -0.09 %     -75,210
# 2    3            United Kingdom        67,736,802        0.34 %     227,866
# 3    4                    France        64,756,584        0.20 %     129,956
# 4    5                     Italy        58,870,762       -0.28 %    -166,712
# 5    6                     Spain        47,519,628       -0.08 %     -39,002
# 6    7                   Ukraine        36,744,634       -7.45 %  -2,957,105
# 7    8                    Poland        41,026,067        2.93 %   1,168,922
# 8    9                   Romania        19,892,812        1.19 %     233,545
# 9   10               Netherlands        17,618,299        0.31 %      54,285
# 10  11                   Belgium        11,686,140        0.26 %      30,210
# 11  12                    Greece        10,341,277       -0.42 %     -43,694
# 12  13  Czech Republic (Czechia)        10,495,295        0.01 %       1,309
# 13  14                  Portugal        10,247,605       -0.23 %     -23,260
# 14  15                    Sweden        10,612,086        0.59 %      62,739
# 15  16                   Hungary        10,156,239        1.90 %     188,931
# 16  17                   Belarus         9,498,238       -0.39 %     -36,716
# 17  18                   Austria         8,958,960        0.22 %      19,343
# 18  19               Switzerland         8,796,669        0.64 %      56,197
# 19  20                    Serbia         7,149,077       -1.00 %     -72,288
# 20  21                  Bulgaria         6,687,717       -1.39 %     -94,236
# 21  22                   Denmark         5,910,913        0.49 %      28,652
# 22  23                   Finland         5,545,475        0.09 %       4,730
# 23  24                  Slovakia         5,795,199        2.69 %     151,746
# 24  25                    Norway         5,474,360        0.74 %      40,041
# 25  26                   Ireland         5,056,935        0.67 %      33,826
# 26  27                   Croatia         4,008,617       -0.54 %     -21,741
# 27  28    Bosnia and Herzegovina         3,210,847       -0.70 %     -22,679
# 28  29                   Moldova         3,435,931        4.98 %     162,935
# 29  30                   Albania         2,832,439       -0.35 %      -9,882
# 30  31                 Lithuania         2,718,352       -1.15 %     -31,703
# 31  32           North Macedonia         2,085,679       -0.38 %      -7,920
# 32  33                  Slovenia         2,119,675       -0.01 %        -169
# 33  34                    Latvia         1,830,211       -1.10 %     -20,440
# 34  35                   Estonia         1,322,765       -0.25 %      -3,297
# 35  36                Montenegro           626,485       -0.10 %        -597
# 36  37                Luxembourg           654,768        1.11 %       7,169
# 37  38                     Malta           535,064        0.33 %       1,778
# 38  39                   Iceland           375,318        0.65 %       2,419
# 39  40               Isle of Man            84,710        0.23 %         191
# 40  41                   Andorra            80,088        0.33 %         264
# 41  42            Faeroe Islands            53,270        0.34 %         180
# 42  43             Liechtenstein            39,584        0.65 %         257
# 43  44                    Monaco            36,297       -0.47 %        -172
# 44  45                San Marino            33,642       -0.05 %         -18
# 45  46                 Gibraltar            32,688        0.12 %          39
# 46  47                  Holy See               518        1.57 %           8
#
#    Density (P/Km²) Land Area (Km²) Migrants (net) Fert. Rate Med. Age  \
# 0                9      16,376,870       -136,414        1.5       39
# 1              239         348,560        155,751        1.5       45
# 2              280         241,930        165,790        1.6       40
# 3              118         547,557         67,761        1.8       42
# 4              200         294,140         58,496        1.3       48
# 5               95         498,800         39,998        1.3       45
# 6               63         579,320      1,784,718        1.3       45
# 7              134         306,230       -910,475        1.5       40
# 8               86         230,170       -254,616        1.7       41
# 9              522          33,720         29,998        1.6       42
# 10             386          30,280         23,999        1.6       41
# 11              80         128,900          5,000        1.4       45
# 12             136          77,240         22,011        1.7       43
# 13             112          91,590          9,999        1.4       46
# 14              26         410,340         39,998        1.7       40
# 15             112          90,530       -156,677        1.6       42
# 16              47         202,910         -4,282        1.5       41
# 17             109          82,409         19,999        1.5       43
# 18             223          39,516         39,998        1.5       42
# 19              82          87,460         -9,999        1.5       43
# 20              62         108,560         -4,800        1.6       45
# 21             139          42,430         19,999        1.7       41
# 22              18         303,890         13,999        1.4       43
# 23             121          48,088       -112,067        1.6       40
# 24              15         365,268         27,998        1.5       40
# 25              73          68,890          9,999        1.8       38
# 26              72          55,960         -2,000        1.4       44
# 27              63          51,000           -500        1.3       42
# 28             105          32,850       -125,204        1.8       35
# 29             103          27,400         -8,000        1.4       38
# 30              43          62,674        -13,128        1.6       44
# 31              83          25,220         -1,000        1.4       39
# 32             105          20,140          2,000        1.6       44
# 33              29          62,200         -7,630        1.6       44
# 34              31          42,390         -1,000        1.7       42
# 35              47          13,450           -480        1.7       39
# 36             253           2,590          4,883        1.4       39
# 37           1,672             320            850        1.2       40
# 38               4         100,250            380        1.7       36
# 39             149             570            340        1.6       46
# 40             170             470            200        1.1       43
# 41              38           1,396              0        2.7       38
# 42             247             160            150        1.5       44
# 43          24,360               1            200        2.1       54
# 44             561              60            100        1.1       47
# 45           3,269              10            -24        1.8       42
# 46           1,295               0              0
#
#    Urban Pop % World Share
# 0         75 %      1.80 %
# 1         77 %      1.04 %
# 2         85 %      0.84 %
# 3         84 %      0.80 %
# 4         72 %      0.73 %
# 5         80 %      0.59 %
# 6         82 %      0.46 %
# 7         55 %      0.51 %
# 8         53 %      0.25 %
# 9         92 %      0.22 %
# 10        99 %      0.15 %
# 11        86 %      0.13 %
# 12        75 %      0.13 %
# 13        67 %      0.13 %
# 14        86 %      0.13 %
# 15        68 %      0.13 %
# 16        80 %      0.12 %
# 17        59 %      0.11 %
# 18        75 %      0.11 %
# 19        69 %      0.09 %
# 20        78 %      0.08 %
# 21        88 %      0.07 %
# 22        87 %      0.07 %
# 23        51 %      0.07 %
# 24        86 %      0.07 %
# 25        64 %      0.06 %
# 26        59 %      0.05 %
# 27        54 %      0.04 %
# 28        50 %      0.04 %
# 29        67 %      0.04 %
# 30        71 %      0.03 %
# 31        60 %      0.03 %
# 32        55 %      0.03 %
# 33        69 %      0.02 %
# 34        68 %      0.02 %
# 35        69 %      0.01 %
# 36        88 %      0.01 %
# 37        78 %      0.01 %
# 38        88 %      0.00 %
# 39        55 %      0.00 %
# 40        85 %      0.00 %
# 41        41 %      0.00 %
# 42        15 %      0.00 %
# 43        N.A.      0.00 %
# 44        99 %      0.00 %
# 45        N.A.      0.00 %
# 46        N.A.      0.00 %

# %%
populations = pop_df.drop(['#', 'Net Change', 'Migrants (net)', 'Fert. Rate', 'World Share'],
                         axis = 1)

# %%
populations
# Out:
#      Country (or dependency) Population (2023) Yearly Change Density (P/Km²)  \
# 0                     Russia       144,444,359       -0.19 %               9
# 1                    Germany        83,294,633       -0.09 %             239
# 2             United Kingdom        67,736,802        0.34 %             280
# 3                     France        64,756,584        0.20 %             118
# 4                      Italy        58,870,762       -0.28 %             200
# 5                      Spain        47,519,628       -0.08 %              95
# 6                    Ukraine        36,744,634       -7.45 %              63
# 7                     Poland        41,026,067        2.93 %             134
# 8                    Romania        19,892,812        1.19 %              86
# 9                Netherlands        17,618,299        0.31 %             522
# 10                   Belgium        11,686,140        0.26 %             386
# 11                    Greece        10,341,277       -0.42 %              80
# 12  Czech Republic (Czechia)        10,495,295        0.01 %             136
# 13                  Portugal        10,247,605       -0.23 %             112
# 14                    Sweden        10,612,086        0.59 %              26
# 15                   Hungary        10,156,239        1.90 %             112
# 16                   Belarus         9,498,238       -0.39 %              47
# 17                   Austria         8,958,960        0.22 %             109
# 18               Switzerland         8,796,669        0.64 %             223
# 19                    Serbia         7,149,077       -1.00 %              82
# 20                  Bulgaria         6,687,717       -1.39 %              62
# 21                   Denmark         5,910,913        0.49 %             139
# 22                   Finland         5,545,475        0.09 %              18
# 23                  Slovakia         5,795,199        2.69 %             121
# 24                    Norway         5,474,360        0.74 %              15
# 25                   Ireland         5,056,935        0.67 %              73
# 26                   Croatia         4,008,617       -0.54 %              72
# 27    Bosnia and Herzegovina         3,210,847       -0.70 %              63
# 28                   Moldova         3,435,931        4.98 %             105
# 29                   Albania         2,832,439       -0.35 %             103
# 30                 Lithuania         2,718,352       -1.15 %              43
# 31           North Macedonia         2,085,679       -0.38 %              83
# 32                  Slovenia         2,119,675       -0.01 %             105
# 33                    Latvia         1,830,211       -1.10 %              29
# 34                   Estonia         1,322,765       -0.25 %              31
# 35                Montenegro           626,485       -0.10 %              47
# 36                Luxembourg           654,768        1.11 %             253
# 37                     Malta           535,064        0.33 %           1,672
# 38                   Iceland           375,318        0.65 %               4
# 39               Isle of Man            84,710        0.23 %             149
# 40                   Andorra            80,088        0.33 %             170
# 41            Faeroe Islands            53,270        0.34 %              38
# 42             Liechtenstein            39,584        0.65 %             247
# 43                    Monaco            36,297       -0.47 %          24,360
# 44                San Marino            33,642       -0.05 %             561
# 45                 Gibraltar            32,688        0.12 %           3,269
# 46                  Holy See               518        1.57 %           1,295
#
#    Land Area (Km²) Med. Age Urban Pop %
# 0       16,376,870       39        75 %
# 1          348,560       45        77 %
# 2          241,930       40        85 %
# 3          547,557       42        84 %
# 4          294,140       48        72 %
# 5          498,800       45        80 %
# 6          579,320       45        82 %
# 7          306,230       40        55 %
# 8          230,170       41        53 %
# 9           33,720       42        92 %
# 10          30,280       41        99 %
# 11         128,900       45        86 %
# 12          77,240       43        75 %
# 13          91,590       46        67 %
# 14         410,340       40        86 %
# 15          90,530       42        68 %
# 16         202,910       41        80 %
# 17          82,409       43        59 %
# 18          39,516       42        75 %
# 19          87,460       43        69 %
# 20         108,560       45        78 %
# 21          42,430       41        88 %
# 22         303,890       43        87 %
# 23          48,088       40        51 %
# 24         365,268       40        86 %
# 25          68,890       38        64 %
# 26          55,960       44        59 %
# 27          51,000       42        54 %
# 28          32,850       35        50 %
# 29          27,400       38        67 %
# 30          62,674       44        71 %
# 31          25,220       39        60 %
# 32          20,140       44        55 %
# 33          62,200       44        69 %
# 34          42,390       42        68 %
# 35          13,450       39        69 %
# 36           2,590       39        88 %
# 37             320       40        78 %
# 38         100,250       36        88 %
# 39             570       46        55 %
# 40             470       43        85 %
# 41           1,396       38        41 %
# 42             160       44        15 %
# 43               1       54        N.A.
# 44              60       47        99 %
# 45              10       42        N.A.
# 46               0                 N.A.

# %%
populations.rename(columns = {'Country (or dependency)':'Country',
                             'Population (2023)':'Population'},
                  inplace = True)

# %%
populations['Country'] = populations['Country'].replace(['Czech Republic (Czechia)'], 'Czechia')

# %%
populations['Country'] = populations['Country'].replace(['Russia'], 'Russian Federation')

# %%
populations['Country'] = populations['Country'].replace(['Moldova'], 'Moldova, Republic of')

# %%
countries = ['Austria','Belgium','Bulgaria','Croatia','Cyprus','Czechia','Denmark','Estonia','Finland','France','Germany',
            'Greece','Hungary','Ireland','Italy','Latvia','Lithuania','Luxembourg','Malta','Netherlands','Poland',
             'Portugal','Romania','Slovakia','Slovenia','Spain','Sweden','Iceland','Liechtenstein','Norway',
             'Switzerland','Albania','Montenegro','North Macedonia','Serbia','Turkey','Andorra','Belarus',
             'Bosnia and Herzegovina','Moldova, Republic of','Monaco','Russian Federation','San Marino','Ukraine',
             'United Kingdom','Vatican City']

# %%
code = ['AT','BE','BG','HR','CY','CZ','DK','EE','FI','FR','DE','EL','HU','IE','IT','LV','LT','LU','MT','NL','PL','PT',
'RO','SK','SI','ES','SE','IS','LI','NO','CH','AL','ME','MK','RS','TR','AD','BY','BA','MD','MC','RU','SM','UA','UK','VA']

# %%
countries_codes = pd.DataFrame(list(zip(countries, code)), columns = ['countries', 'code'])

# %%
populations['Code'] = ['na','na','na','na','na','na','na','na','na','na',
                      'na','na','na','na','na','na','na','na','na','na',
                      'na','na','na','na','na','na','na','na','na','na',
                      'na','na','na','na','na','na','na','na','na','na',
                      'na','na','na','na','na','na','na']

# %%
for i in range(0, len(populations)):
    for j in range(0, len(countries_codes)):
        if populations['Country'].iloc[i] == countries_codes['countries'].iloc[j]:
            populations['Code'].iloc[i] = countries_codes['code'].iloc[j]
            #country_code.append(countries_codes['code'].iloc[j])

# %%
populations
# Out:
#                    Country   Population Yearly Change Density (P/Km²)  \
# 0       Russian Federation  144,444,359       -0.19 %               9
# 1                  Germany   83,294,633       -0.09 %             239
# 2           United Kingdom   67,736,802        0.34 %             280
# 3                   France   64,756,584        0.20 %             118
# 4                    Italy   58,870,762       -0.28 %             200
# 5                    Spain   47,519,628       -0.08 %              95
# 6                  Ukraine   36,744,634       -7.45 %              63
# 7                   Poland   41,026,067        2.93 %             134
# 8                  Romania   19,892,812        1.19 %              86
# 9              Netherlands   17,618,299        0.31 %             522
# 10                 Belgium   11,686,140        0.26 %             386
# 11                  Greece   10,341,277       -0.42 %              80
# 12                 Czechia   10,495,295        0.01 %             136
# 13                Portugal   10,247,605       -0.23 %             112
# 14                  Sweden   10,612,086        0.59 %              26
# 15                 Hungary   10,156,239        1.90 %             112
# 16                 Belarus    9,498,238       -0.39 %              47
# 17                 Austria    8,958,960        0.22 %             109
# 18             Switzerland    8,796,669        0.64 %             223
# 19                  Serbia    7,149,077       -1.00 %              82
# 20                Bulgaria    6,687,717       -1.39 %              62
# 21                 Denmark    5,910,913        0.49 %             139
# 22                 Finland    5,545,475        0.09 %              18
# 23                Slovakia    5,795,199        2.69 %             121
# 24                  Norway    5,474,360        0.74 %              15
# 25                 Ireland    5,056,935        0.67 %              73
# 26                 Croatia    4,008,617       -0.54 %              72
# 27  Bosnia and Herzegovina    3,210,847       -0.70 %              63
# 28    Moldova, Republic of    3,435,931        4.98 %             105
# 29                 Albania    2,832,439       -0.35 %             103
# 30               Lithuania    2,718,352       -1.15 %              43
# 31         North Macedonia    2,085,679       -0.38 %              83
# 32                Slovenia    2,119,675       -0.01 %             105
# 33                  Latvia    1,830,211       -1.10 %              29
# 34                 Estonia    1,322,765       -0.25 %              31
# 35              Montenegro      626,485       -0.10 %              47
# 36              Luxembourg      654,768        1.11 %             253
# 37                   Malta      535,064        0.33 %           1,672
# 38                 Iceland      375,318        0.65 %               4
# 39             Isle of Man       84,710        0.23 %             149
# 40                 Andorra       80,088        0.33 %             170
# 41          Faeroe Islands       53,270        0.34 %              38
# 42           Liechtenstein       39,584        0.65 %             247
# 43                  Monaco       36,297       -0.47 %          24,360
# 44              San Marino       33,642       -0.05 %             561
# 45               Gibraltar       32,688        0.12 %           3,269
# 46                Holy See          518        1.57 %           1,295
#
#    Land Area (Km²) Med. Age Urban Pop % Code
# 0       16,376,870       39        75 %   RU
# 1          348,560       45        77 %   DE
# 2          241,930       40        85 %   UK
# 3          547,557       42        84 %   FR
# 4          294,140       48        72 %   IT
# 5          498,800       45        80 %   ES
# 6          579,320       45        82 %   UA
# 7          306,230       40        55 %   PL
# 8          230,170       41        53 %   RO
# 9           33,720       42        92 %   NL
# 10          30,280       41        99 %   BE
# 11         128,900       45        86 %   EL
# 12          77,240       43        75 %   CZ
# 13          91,590       46        67 %   PT
# 14         410,340       40        86 %   SE
# 15          90,530       42        68 %   HU
# 16         202,910       41        80 %   BY
# 17          82,409       43        59 %   AT
# 18          39,516       42        75 %   CH
# 19          87,460       43        69 %   RS
# 20         108,560       45        78 %   BG
# 21          42,430       41        88 %   DK
# 22         303,890       43        87 %   FI
# 23          48,088       40        51 %   SK
# 24         365,268       40        86 %   NO
# 25          68,890       38        64 %   IE
# 26          55,960       44        59 %   HR
# 27          51,000       42        54 %   BA
# 28          32,850       35        50 %   MD
# 29          27,400       38        67 %   AL
# 30          62,674       44        71 %   LT
# 31          25,220       39        60 %   MK
# 32          20,140       44        55 %   SI
# 33          62,200       44        69 %   LV
# 34          42,390       42        68 %   EE
# 35          13,450       39        69 %   ME
# 36           2,590       39        88 %   LU
# 37             320       40        78 %   MT
# 38         100,250       36        88 %   IS
# 39             570       46        55 %   na
# 40             470       43        85 %   AD
# 41           1,396       38        41 %   na
# 42             160       44        15 %   LI
# 43               1       54        N.A.   MC
# 44              60       47        99 %   SM
# 45              10       42        N.A.   na
# 46               0                 N.A.   na

# %%
countries_codes['Country_present'] = ['na','na','na','na','na','na','na','na','na','na',
                                      'na','na','na','na','na','na','na','na','na','na',
                                      'na','na','na','na','na','na','na','na','na','na',
                                      'na','na','na','na','na','na','na','na','na','na',
                                      'na','na','na','na','na','na']

# %%
for i in range(0, len(countries_codes)):
    for j in range(0, len(populations)):
        if countries_codes['countries'].iloc[i] == populations['Country'].iloc[j]:
            countries_codes['Country_present'].iloc[i] = 'Present'

# %%
countries_codes
# Out:
#                  countries code Country_present
# 0                  Austria   AT         Present
# 1                  Belgium   BE         Present
# 2                 Bulgaria   BG         Present
# 3                  Croatia   HR         Present
# 4                   Cyprus   CY              na
# 5                  Czechia   CZ         Present
# 6                  Denmark   DK         Present
# 7                  Estonia   EE         Present
# 8                  Finland   FI         Present
# 9                   France   FR         Present
# 10                 Germany   DE         Present
# 11                  Greece   EL         Present
# 12                 Hungary   HU         Present
# 13                 Ireland   IE         Present
# 14                   Italy   IT         Present
# 15                  Latvia   LV         Present
# 16               Lithuania   LT         Present
# 17              Luxembourg   LU         Present
# 18                   Malta   MT         Present
# 19             Netherlands   NL         Present
# 20                  Poland   PL         Present
# 21                Portugal   PT         Present
# 22                 Romania   RO         Present
# 23                Slovakia   SK         Present
# 24                Slovenia   SI         Present
# 25                   Spain   ES         Present
# 26                  Sweden   SE         Present
# 27                 Iceland   IS         Present
# 28           Liechtenstein   LI         Present
# 29                  Norway   NO         Present
# 30             Switzerland   CH         Present
# 31                 Albania   AL         Present
# 32              Montenegro   ME         Present
# 33         North Macedonia   MK         Present
# 34                  Serbia   RS         Present
# 35                  Turkey   TR              na
# 36                 Andorra   AD         Present
# 37                 Belarus   BY         Present
# 38  Bosnia and Herzegovina   BA         Present
# 39    Moldova, Republic of   MD         Present
# 40                  Monaco   MC         Present
# 41      Russian Federation   RU         Present
# 42              San Marino   SM         Present
# 43                 Ukraine   UA         Present
# 44          United Kingdom   UK         Present
# 45            Vatican City   VA              na

# %% [markdown]
# Missing population values of Vatican City, Turkey and Cyprus.

# %%
len(populations)
# Out:
# 47

# %%
len(countries_codes)
# Out:
# 46

# %%
populations['Population'] = populations['Population'].str.replace(",", "")

# %%
populations['Land Area (Km²)'] = populations['Land Area (Km²)'].str.replace(",", "")

# %%
populations['Density (P/Km²)'] = populations['Density (P/Km²)'].str.replace(",", "")

# %%
populations['Urban Pop %'] = populations['Urban Pop %'].str.replace(" %", "")

# %%
populations['Yearly Change'] = populations['Yearly Change'].str.replace(" %", "")

# %%
populations.head()
# Out:
#               Country Population Yearly Change Density (P/Km²)  \
# 0  Russian Federation  144444359         -0.19               9
# 1             Germany   83294633         -0.09             239
# 2      United Kingdom   67736802          0.34             280
# 3              France   64756584          0.20             118
# 4               Italy   58870762         -0.28             200
#
#   Land Area (Km²) Med. Age Urban Pop % Code
# 0        16376870       39          75   RU
# 1          348560       45          77   DE
# 2          241930       40          85   UK
# 3          547557       42          84   FR
# 4          294140       48          72   IT

# %%
turkey_pop = ['Turkey', 85903600, 'null', 112, 769630, 31.8, 77.1, 'TR']
cyprus_pop = ['Cyprus', 920701, 'null', 136, 9213, 38.5, 65.5, 'CY']

# %%
populations.loc[len(populations)] = vatican_pop

# %%
populations.loc[len(populations)] = turkey_pop

# %%
populations.loc[len(populations)] = cyprus_pop

# %%
kosovo_pop = ['Kosovo', 1761985, 'null', 166, 10887, 31.5, 50, 'XK']
populations.loc[len(populations)] = kosovo_pop

# %%
for i in range(0, len(countries_codes)):
    for j in range(0, len(populations)):
        if countries_codes['countries'].iloc[i] == populations['Country'].iloc[j]:
            countries_codes['Country_present'].iloc[i] = 'Present'
countries_codes
# Out:
#                  countries code Country_present
# 0                  Austria   AT         Present
# 1                  Belgium   BE         Present
# 2                 Bulgaria   BG         Present
# 3                  Croatia   HR         Present
# 4                   Cyprus   CY         Present
# 5                  Czechia   CZ         Present
# 6                  Denmark   DK         Present
# 7                  Estonia   EE         Present
# 8                  Finland   FI         Present
# 9                   France   FR         Present
# 10                 Germany   DE         Present
# 11                  Greece   EL         Present
# 12                 Hungary   HU         Present
# 13                 Ireland   IE         Present
# 14                   Italy   IT         Present
# 15                  Latvia   LV         Present
# 16               Lithuania   LT         Present
# 17              Luxembourg   LU         Present
# 18                   Malta   MT         Present
# 19             Netherlands   NL         Present
# 20                  Poland   PL         Present
# 21                Portugal   PT         Present
# 22                 Romania   RO         Present
# 23                Slovakia   SK         Present
# 24                Slovenia   SI         Present
# 25                   Spain   ES         Present
# 26                  Sweden   SE         Present
# 27                 Iceland   IS         Present
# 28           Liechtenstein   LI         Present
# 29                  Norway   NO         Present
# 30             Switzerland   CH         Present
# 31                 Albania   AL         Present
# 32              Montenegro   ME         Present
# 33         North Macedonia   MK         Present
# 34                  Serbia   RS         Present
# 35                  Turkey   TR         Present
# 36                 Andorra   AD         Present
# 37                 Belarus   BY         Present
# 38  Bosnia and Herzegovina   BA         Present
# 39    Moldova, Republic of   MD         Present
# 40                  Monaco   MC         Present
# 41      Russian Federation   RU         Present
# 42              San Marino   SM         Present
# 43                 Ukraine   UA         Present
# 44          United Kingdom   UK         Present
# 45            Vatican City   VA         Present

# %% [markdown]
# Now all the countries have the population value.

# %%
populations = populations[~(populations['Country'] == 'Isle of Man')]
populations = populations[~(populations['Country'] == 'Faeroe Islands')]
populations = populations[~(populations['Country'] == 'Gibraltar')]
populations = populations[~(populations['Country'] == 'Holy See')]

# %%
populations = populations[~(populations['Country'] == 'Andorra')]
populations = populations[~(populations['Country'] == 'Belarus')]
populations = populations[~(populations['Country'] == 'Belarus')]  
populations = populations[~(populations['Country'] == 'Monaco')]
populations = populations[~(populations['Country'] == 'Moldova, Republic of')]
populations = populations[~(populations['Country'] == 'Russian Federation')]
populations = populations[~(populations['Country'] == 'San Marino')]
populations = populations[~(populations['Country'] == 'Ukraine')]

# %%
populations
# Out:
#                    Country Population Yearly Change Density (P/Km²)  \
# 1                  Germany   83294633         -0.09             239
# 2           United Kingdom   67736802          0.34             280
# 3                   France   64756584          0.20             118
# 4                    Italy   58870762         -0.28             200
# 5                    Spain   47519628         -0.08              95
# 7                   Poland   41026067          2.93             134
# 8                  Romania   19892812          1.19              86
# 9              Netherlands   17618299          0.31             522
# 10                 Belgium   11686140          0.26             386
# 11                  Greece   10341277         -0.42              80
# 12                 Czechia   10495295          0.01             136
# 13                Portugal   10247605         -0.23             112
# 14                  Sweden   10612086          0.59              26
# 15                 Hungary   10156239          1.90             112
# 17                 Austria    8958960          0.22             109
# 18             Switzerland    8796669          0.64             223
# 19                  Serbia    7149077         -1.00              82
# 20                Bulgaria    6687717         -1.39              62
# 21                 Denmark    5910913          0.49             139
# 22                 Finland    5545475          0.09              18
# 23                Slovakia    5795199          2.69             121
# 24                  Norway    5474360          0.74              15
# 25                 Ireland    5056935          0.67              73
# 26                 Croatia    4008617         -0.54              72
# 27  Bosnia and Herzegovina    3210847         -0.70              63
# 29                 Albania    2832439         -0.35             103
# 30               Lithuania    2718352         -1.15              43
# 31         North Macedonia    2085679         -0.38              83
# 32                Slovenia    2119675         -0.01             105
# 33                  Latvia    1830211         -1.10              29
# 34                 Estonia    1322765         -0.25              31
# 35              Montenegro     626485         -0.10              47
# 36              Luxembourg     654768          1.11             253
# 37                   Malta     535064          0.33            1672
# 38                 Iceland     375318          0.65               4
# 42           Liechtenstein      39584          0.65             247
# 48                  Turkey   85903600          null             112
# 49                  Cyprus     920701          null             136
# 50                  Kosovo    1761985          null             166
#
#    Land Area (Km²) Med. Age Urban Pop % Code
# 1           348560       45          77   DE
# 2           241930       40          85   UK
# 3           547557       42          84   FR
# 4           294140       48          72   IT
# 5           498800       45          80   ES
# 7           306230       40          55   PL
# 8           230170       41          53   RO
# 9            33720       42          92   NL
# 10           30280       41          99   BE
# 11          128900       45          86   EL
# 12           77240       43          75   CZ
# 13           91590       46          67   PT
# 14          410340       40          86   SE
# 15           90530       42          68   HU
# 17           82409       43          59   AT
# 18           39516       42          75   CH
# 19           87460       43          69   RS
# 20          108560       45          78   BG
# 21           42430       41          88   DK
# 22          303890       43          87   FI
# 23           48088       40          51   SK
# 24          365268       40          86   NO
# 25           68890       38          64   IE
# 26           55960       44          59   HR
# 27           51000       42          54   BA
# 29           27400       38          67   AL
# 30           62674       44          71   LT
# 31           25220       39          60   MK
# 32           20140       44          55   SI
# 33           62200       44          69   LV
# 34           42390       42          68   EE
# 35           13450       39          69   ME
# 36            2590       39          88   LU
# 37             320       40          78   MT
# 38          100250       36          88   IS
# 42             160       44          15   LI
# 48          769630     31.8        77.1   TR
# 49            9213     38.5        65.5   CY
# 50           10887     31.5          50   XK

# %%
populations.to_csv("Populations.csv")

# %% [markdown]
# <a id = 'exploratory_analysis'></a>
# ## 1. Exploratory analysis of the datasets
# [Top](#top)
#
# [0.](#import_dataset)

# %% [markdown]
# <a id = 'explore_spatial'></a>
# ### 1.1 Exploratory analysis of spatial dataset
# [Top](#top)

# %%
spatial_raw.columns
# Out:
# Index(['countryCode', 'thematicIdIdentifier', 'thematicIdIdentifierScheme',
#        'monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
#        'monitoringSiteName', 'waterBodyIdentifier',
#        'waterBodyIdentifierScheme', 'waterBodyName', 'specialisedZoneType',
#        'naturalAWBHMWB', 'reservoir', 'surfaceWaterBodyTypeCode',
#        'subUnitIdentifier', 'subUnitIdentifierScheme', 'subUnitName',
#        'rbdIdentifier', 'rbdIdentifierScheme', 'rbdName',
#        'confidentialityStatus', 'lon', 'lat', 'statusCode'],
#       dtype='object')

# %%
spatial_raw['thematicIdIdentifier'].equals(spatial_raw['monitoringSiteIdentifier'])
# Out:
# False

# %%
spatial = spatial_raw[spatial_raw['confidentialityStatus'] == 'F'] # Keep only free confidential data.

# %%
spatial['countryCode'].unique()
# Out:
# array(['FR', 'IT', 'HR', 'PL', 'PT', 'UK', 'HU', 'AL', 'IE', 'AT', 'BA',
#        'BG', 'CY', 'IS', 'DE', 'EL', 'FI', 'LT', 'NL', 'LU', 'LV', 'MT',
#        'NO', 'CH', 'DK', 'RO', 'SI', 'ES', 'SE', 'SK', 'BE', 'CZ', 'EE',
#        'LI', 'ME', 'MK', 'XK', 'RS', 'TR'], dtype=object)

# %%
spatial['thematicIdIdentifier'].unique()
# Out:
# array(['FRFR05234020', 'FRFR05236100', 'FRFR05237000', ...,
#        'FRFR05234000', 'FRFR05234015', 'FRFR05234019'], dtype=object)

# %%
len(spatial['thematicIdIdentifier'].unique())
# Out:
# 57555

# %%
spatial['waterBodyIdentifier'].unique()
# Out:
# array(['FRFR326A', 'FRFR236', 'FRFR273', ..., 'FRFRR238_1', 'FRFR235A',
#        'FRFR235B'], dtype=object)

# %%
len(spatial['waterBodyIdentifier'].unique())
# Out:
# 26759

# %%
spatial['monitoringSiteIdentifier'].unique()
# Out:
# array(['FRFR05234020', 'FRFR05236100', 'FRFR05237000', ...,
#        'FRFR05234000', 'FRFR05234015', 'FRFR05234019'], dtype=object)

# %%
len(spatial['monitoringSiteIdentifier'].unique())
# Out:
# 57555

# %%
len(spatial)
# Out:
# 57687

# %% [markdown]
# #### Null values
# After noticing that there are null values among the countries codes, it is necessary to detect and exclude the rows with null or nan values in them from the dataset.

# %%
spatial[spatial['countryCode'].isna()] # Select all rows with NaN under a single DataFrame column
# Out:
# Empty DataFrame
# Columns: [countryCode, thematicIdIdentifier, thematicIdIdentifierScheme, monitoringSiteIdentifier, monitoringSiteIdentifierScheme, monitoringSiteName, waterBodyIdentifier, waterBodyIdentifierScheme, waterBodyName, specialisedZoneType, naturalAWBHMWB, reservoir, surfaceWaterBodyTypeCode, subUnitIdentifier, subUnitIdentifierScheme, subUnitName, rbdIdentifier, rbdIdentifierScheme, rbdName, confidentialityStatus, lon, lat, statusCode]
# Index: []
#
# [0 rows x 23 columns]

# %%
spatial_lon_na = spatial[spatial['lon'].isna()] # Rows in which 'lon' values are null
spatial_lon_na['countryCode'].unique()          # Which countries do not have lon values for certain water bodies
# Out:
# array(['AL', 'AT', 'BA', 'EL', 'FR', 'HR', 'HU', 'IE', 'IT', 'PT', 'FI',
#        'SE', 'CY', 'BG', 'DE', 'DK', 'EE', 'ES', 'IS', 'LT', 'LU', 'LV',
#        'ME', 'NO', 'UK', 'RO', 'RS', 'SK', 'TR'], dtype=object)

# %%
spatial_lat_na = spatial[spatial['lat'].isna()]
spatial_lat_na['countryCode'].unique()
# Out:
# array(['AL', 'AT', 'BA', 'EL', 'FR', 'HR', 'HU', 'IE', 'IT', 'PT', 'FI',
#        'SE', 'CY', 'BG', 'DE', 'DK', 'EE', 'ES', 'IS', 'LT', 'LU', 'LV',
#        'ME', 'NO', 'UK', 'RO', 'RS', 'SK', 'TR'], dtype=object)

# %%
spatial[spatial.isnull().any(axis=1)]
# Out:
#       countryCode thematicIdIdentifier thematicIdIdentifierScheme  \
# 66             IT             IT02PO29       euMonitoringSiteCode
# 67             IT             IT02PO34       euMonitoringSiteCode
# 107            IT             IT02-PO9       euMonitoringSiteCode
# 127            IT            IT13SA13P       euMonitoringSiteCode
# 187            IT            IT13SA21P       euMonitoringSiteCode
# ...           ...                  ...                        ...
# 72877          IT            IT13SU43P       euMonitoringSiteCode
# 72887          UK         UKEW81120002       euMonitoringSiteCode
# 72914          IT             IT13PE7P       euMonitoringSiteCode
# 72915          IT            IT13PE80P       euMonitoringSiteCode
# 72970          IT            IT13TO60P       euMonitoringSiteCode
#
#       monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 66                    IT02PO29           euMonitoringSiteCode
# 67                    IT02PO34           euMonitoringSiteCode
# 107                   IT02-PO9           euMonitoringSiteCode
# 127                  IT13SA13P           euMonitoringSiteCode
# 187                  IT13SA21P           euMonitoringSiteCode
# ...                        ...                            ...
# 72877                IT13SU43P           euMonitoringSiteCode
# 72887             UKEW81120002           euMonitoringSiteCode
# 72914                 IT13PE7P           euMonitoringSiteCode
# 72915                IT13PE80P           euMonitoringSiteCode
# 72970                IT13TO60P           euMonitoringSiteCode
#
#       monitoringSiteName waterBodyIdentifier waterBodyIdentifierScheme  \
# 66            STAB. SIMA            IT0201VA     euGroundWaterBodyCode
# 67           GRAND PLACE            IT0201VA     euGroundWaterBodyCode
# 107             BIRRERIA            IT0201VA     euGroundWaterBodyCode
# 127                 SA13              IT13SA     euGroundWaterBodyCode
# 187                 SA21              IT13SA     euGroundWaterBodyCode
# ...                  ...                 ...                       ...
# 72877               SU43              IT13SU     euGroundWaterBodyCode
# 72887           81120002    UKGB40802G806700     euGroundWaterBodyCode
# 72914                PE7              IT13PE     euGroundWaterBodyCode
# 72915               PE80              IT13PE     euGroundWaterBodyCode
# 72970               TO60              IT13TO     euGroundWaterBodyCode
#
#            waterBodyName specialisedZoneType  ... subUnitIdentifier  \
# 66        PIANA DI AOSTA     groundWaterBody  ...               NaN
# 67        PIANA DI AOSTA     groundWaterBody  ...               NaN
# 107       PIANA DI AOSTA     groundWaterBody  ...               NaN
# 127     PIANA DEL SANGRO     groundWaterBody  ...               NaN
# 187     PIANA DEL SANGRO     groundWaterBody  ...               NaN
# ...                  ...                 ...  ...               ...
# 72877   PIANA DI SULMONA     groundWaterBody  ...               NaN
# 72887              TAMAR     groundWaterBody  ...               NaN
# 72914  PIANA DEL PESCARA     groundWaterBody  ...               NaN
# 72915  PIANA DEL PESCARA     groundWaterBody  ...               NaN
# 72970  PIANA DEL TORDINO     groundWaterBody  ...               NaN
#
#       subUnitIdentifierScheme subUnitName rbdIdentifier rbdIdentifierScheme  \
# 66                        NaN         NaN       ITB2018           euRBDCode
# 67                        NaN         NaN       ITB2018           euRBDCode
# 107                       NaN         NaN       ITB2018           euRBDCode
# 127                       NaN         NaN       ITE2018           euRBDCode
# 187                       NaN         NaN       ITE2018           euRBDCode
# ...                       ...         ...           ...                 ...
# 72877                     NaN         NaN       ITE2018           euRBDCode
# 72887                     NaN         NaN          UK08           euRBDCode
# 72914                     NaN         NaN       ITE2018           euRBDCode
# 72915                     NaN         NaN       ITE2018           euRBDCode
# 72970                     NaN         NaN       ITE2018           euRBDCode
#
#                       rbdName confidentialityStatus       lon       lat  \
# 66               RBD FIUME PO                     F   7.36693  45.73500
# 67               RBD FIUME PO                     F   7.35605  45.73558
# 107              RBD FIUME PO                     F   7.36670  45.73610
# 127    RBD APPENNINO CENTRALE                     F  14.50610  42.24105
# 187    RBD APPENNINO CENTRALE                     F  14.44058  42.14367
# ...                       ...                   ...       ...       ...
# 72877  RBD APPENNINO CENTRALE                     F  13.80745  42.09816
# 72887              SOUTH WEST                     F  -4.07000  50.47000
# 72914  RBD APPENNINO CENTRALE                     F  14.04828  42.30399
# 72915  RBD APPENNINO CENTRALE                     F  14.15944  42.42583
# 72970  RBD APPENNINO CENTRALE                     F  13.90090  42.71359
#
#        statusCode
# 66         stable
# 67         stable
# 107    deprecated
# 127        stable
# 187        stable
# ...           ...
# 72877      stable
# 72887  deprecated
# 72914      stable
# 72915      stable
# 72970      stable
#
# [29161 rows x 23 columns]

# %%
spatial.isnull().sum().sum() # Total null values
# Out:
# 192972

# %%
spatial = spatial.dropna(subset = ['lon', 'lat'])

# %%
spatial['waterBodyIdentifier'].isna().sum()
# Out:
# 706

# %%
spatial = spatial.dropna(subset = ['waterBodyIdentifier'])

# %%
spatial.isnull().sum().sum()
# Out:
# 153282

# %%
# In case wanted to drop all NaN
"""
spatial.dropna(inplace=True)
spatial.isnull().sum().sum() # Total null values after the cleaning"""
# Out:
# '\nspatial.dropna(inplace=True)\nspatial.isnull().sum().sum() # Total null values after the cleaning'

# %%
spatial['countryCode'].unique() # Unique values of countries after the cleaning
# Out:
# array(['FR', 'IT', 'HR', 'PL', 'PT', 'UK', 'HU', 'IE', 'BA', 'BG', 'CY',
#        'IS', 'DE', 'LT', 'NL', 'LU', 'LV', 'MT', 'NO', 'CH', 'DK', 'RO',
#        'SI', 'SE', 'SK', 'AL', 'AT', 'BE', 'CZ', 'EE', 'EL', 'ES', 'FI',
#        'LI', 'ME', 'MK', 'XK', 'RS', 'TR'], dtype=object)

# %%
countryCode = list(spatial['countryCode'].unique())

# %%
len(countryCode)
# Out:
# 39

# %%
countries = ['Austria','Belgium','Bulgaria','Croatia','Cyprus','Czechia','Denmark','Estonia','Finland','France','Germany',
            'Greece','Hungary','Ireland','Italy','Latvia','Lithuania','Luxembourg','Malta','Netherlands','Poland',
             'Portugal','Romania','Slovakia','Slovenia','Spain','Sweden','Iceland','Liechtenstein','Norway',
             'Switzerland','Albania','Montenegro','North Macedonia','Serbia','Turkey','Andorra','Belarus',
             'Bosnia and Herzegovina','Moldova, Republic of','Monaco','Russian Federation','San Marino','Ukraine',
             'United Kingdom','Vatican City']

# %%
code = ['AT','BE','BG','HR','CY','CZ','DK','EE','FI','FR','DE','EL','HU','IE','IT','LV','LT','LU','MT','NL','PL','PT',
'RO','SK','SI','ES','SE','IS','LI','NO','CH','AL','ME','MK','RS','TR','AD','BY','BA','MD','MC','RU','SM','UA','UK','VA']

# %%
countries_codes = pd.DataFrame(list(zip(countries, code)), columns = ['countries', 'code'])

# %%
countries_codes
# Out:
#                  countries code
# 0                  Austria   AT
# 1                  Belgium   BE
# 2                 Bulgaria   BG
# 3                  Croatia   HR
# 4                   Cyprus   CY
# 5                  Czechia   CZ
# 6                  Denmark   DK
# 7                  Estonia   EE
# 8                  Finland   FI
# 9                   France   FR
# 10                 Germany   DE
# 11                  Greece   EL
# 12                 Hungary   HU
# 13                 Ireland   IE
# 14                   Italy   IT
# 15                  Latvia   LV
# 16               Lithuania   LT
# 17              Luxembourg   LU
# 18                   Malta   MT
# 19             Netherlands   NL
# 20                  Poland   PL
# 21                Portugal   PT
# 22                 Romania   RO
# 23                Slovakia   SK
# 24                Slovenia   SI
# 25                   Spain   ES
# 26                  Sweden   SE
# 27                 Iceland   IS
# 28           Liechtenstein   LI
# 29                  Norway   NO
# 30             Switzerland   CH
# 31                 Albania   AL
# 32              Montenegro   ME
# 33         North Macedonia   MK
# 34                  Serbia   RS
# 35                  Turkey   TR
# 36                 Andorra   AD
# 37                 Belarus   BY
# 38  Bosnia and Herzegovina   BA
# 39    Moldova, Republic of   MD
# 40                  Monaco   MC
# 41      Russian Federation   RU
# 42              San Marino   SM
# 43                 Ukraine   UA
# 44          United Kingdom   UK
# 45            Vatican City   VA

# %%
spatial['countryCode'][1]
# Out:
# 'FR'

# %%
countries_codes['code'][1]
# Out:
# 'BE'

# %%
spatial_col_countries = []

for i in range(0,len(spatial)):
    for j in range(0,len(countries_codes)):
        if spatial['countryCode'].iloc[i] == countries_codes['code'].iloc[j]:
            spatial_col_countries.append(countries_codes['countries'].iloc[j])

# %%
spatial['specialisedZoneType'].unique()
# Out:
# array(['riverWaterBody', 'transitionalWaterBody', 'lakeWaterBody',
#        'groundWaterBody', 'coastalWaterBody', 'territorialWaters'],
#       dtype=object)

# %% [markdown]
# #### Duplicates
# It is necessary now to check the presence of duplicated rows.

# %%
spatial[spatial.duplicated()] # This shows only the duplictaed rows.
# Out:
#       countryCode thematicIdIdentifier thematicIdIdentifierScheme  \
# 3384           IT          IT020561VA1       euMonitoringSiteCode
# 3389           IT       IT020570081VA1       euMonitoringSiteCode
# 3391           IT       IT020570081VA2       euMonitoringSiteCode
# 3393           IT       IT020570082VA1       euMonitoringSiteCode
# 3422           IT          IT020802VA1       euMonitoringSiteCode
# 3426           IT          IT020804VA1       euMonitoringSiteCode
# 3446           IT          IT020941VA2       euMonitoringSiteCode
# 3460           IT          IT021041VA1       euMonitoringSiteCode
# 3702           IT      IT03N0080563IR1       euMonitoringSiteCode
# 3720           IT  IT03N00806000412IR1       euMonitoringSiteCode
# 3722           IT  IT03N00806000413IR1       euMonitoringSiteCode
# 3724           IT  IT03N00806000414IR1       euMonitoringSiteCode
# 3807           IT      IT03N0080991IR1       euMonitoringSiteCode
# 4381           IT     IT03POMI4ILN1LO1       euMonitoringSiteCode
# 4383           IT     IT03POMI4MLN1LO1       euMonitoringSiteCode
# 4997           IT          IT05EC_VE-8       euMonitoringSiteCode
# 5045           IT        IT05ENC4_VE-6       euMonitoringSiteCode
# 5391           IT        IT05PNC1_VE-1       euMonitoringSiteCode
# 5408           IT          IT06GO04BIS       euMonitoringSiteCode
# 38747          IT               ITSAR1   eionetMonitoringSiteCode
# 38751          IT                ITTEN   eionetMonitoringSiteCode
#
#       monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 3384               IT020561VA1           euMonitoringSiteCode
# 3389            IT020570081VA1           euMonitoringSiteCode
# 3391            IT020570081VA2           euMonitoringSiteCode
# 3393            IT020570082VA1           euMonitoringSiteCode
# 3422               IT020802VA1           euMonitoringSiteCode
# 3426               IT020804VA1           euMonitoringSiteCode
# 3446               IT020941VA2           euMonitoringSiteCode
# 3460               IT021041VA1           euMonitoringSiteCode
# 3702           IT03N0080563IR1           euMonitoringSiteCode
# 3720       IT03N00806000412IR1           euMonitoringSiteCode
# 3722       IT03N00806000413IR1           euMonitoringSiteCode
# 3724       IT03N00806000414IR1           euMonitoringSiteCode
# 3807           IT03N0080991IR1           euMonitoringSiteCode
# 4381          IT03POMI4ILN1LO1           euMonitoringSiteCode
# 4383          IT03POMI4MLN1LO1           euMonitoringSiteCode
# 4997               IT05EC_VE-8           euMonitoringSiteCode
# 5045             IT05ENC4_VE-6           euMonitoringSiteCode
# 5391             IT05PNC1_VE-1           euMonitoringSiteCode
# 5408               IT06GO04BIS           euMonitoringSiteCode
# 38747                   ITSAR1       eionetMonitoringSiteCode
# 38751                    ITTEN       eionetMonitoringSiteCode
#
#                                       monitoringSiteName  \
# 3384                 DOIRE DE LA THUILE - CHAZ PONTAILLE
# 3389                        DOIRE DE FERRET - GREUVETTAZ
# 3391                      DOIRE DE FERRET - PLANPINCIEUX
# 3393                              DOIRE DE FERRET - FOCE
# 3422                  SAINT-BARTHÏ¿½LEMY - PONTE PIERREY
# 3426                           SAINT-BARTHÏ¿½LEMY - FOCE
# 3446                           EVANÏ¿½ON  - MONTE VERRAZ
# 3460                                        LYS - GRENNE
# 3702                                           MARMIROLO
# 3720                                              BARGHE
# 3722                                             GAVARDO
# 3724                                            PREVALLE
# 3807                                        ZAVATTARELLO
# 4381                                             MANTOVA
# 4383                                             MANTOVA
# 4997                      VENEZIA - EX SALINA SAN FELICE
# 5045                             VENEZIA - SACCA SESSOLA
# 5391                                    VENEZIA - FUSINA
# 5408   FIUME ISONZO - A VALLE IMPIANTO DEPURAZIONE GR...
# 38747                                       SARDA - SAR1
# 38751                                     LA TENZA - TEN
#
#                      waterBodyIdentifier waterBodyIdentifierScheme  \
# 3384                          IT020561VA    euSurfaceWaterBodyCode
# 3389                       IT020570081VA    euSurfaceWaterBodyCode
# 3391                       IT020570081VA    euSurfaceWaterBodyCode
# 3393                       IT020570082VA    euSurfaceWaterBodyCode
# 3422                          IT020802VA    euSurfaceWaterBodyCode
# 3426                          IT020804VA    euSurfaceWaterBodyCode
# 3446                          IT020941VA    euSurfaceWaterBodyCode
# 3460                          IT021041VA    euSurfaceWaterBodyCode
# 3702                      IT03N0080564LO    euSurfaceWaterBodyCode
# 3720                  IT03N00806000412LO    euSurfaceWaterBodyCode
# 3722                  IT03N00806000413LO    euSurfaceWaterBodyCode
# 3724                  IT03N00806000414LO    euSurfaceWaterBodyCode
# 3807                      IT03N0080991LO    euSurfaceWaterBodyCode
# 4381                     IT03POMI4ILN1LO    euSurfaceWaterBodyCode
# 4383                     IT03POMI4MLN1LO    euSurfaceWaterBodyCode
# 4997                     ITATW00001700VN    euSurfaceWaterBodyCode
# 5045                     ITATW00001000VN    euSurfaceWaterBodyCode
# 5391                     ITATW00001100VN    euSurfaceWaterBodyCode
# 5408                 ITARW13IS00100030FR    euSurfaceWaterBodyCode
# 38747        ITF015RWI02000359SARDA18IN7    euSurfaceWaterBodyCode
# 38751  ITF015RWI02500891LATENZA18SS2TEN1    euSurfaceWaterBodyCode
#
#                      waterBodyName    specialisedZoneType  ...  \
# 3384            DOIRE DE LA THUILE         riverWaterBody  ...
# 3389           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3391           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3393           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3422   TORRENT DE SAINT-BARTH?LEMY         riverWaterBody  ...
# 3426   TORRENT DE SAINT-BARTH?LEMY         riverWaterBody  ...
# 3446               TORRENT EVENSON         riverWaterBody  ...
# 3460                   TORRENT LYS         riverWaterBody  ...
# 3702                MINCIO (FIUME)         riverWaterBody  ...
# 3720                CHIESE (FIUME)         riverWaterBody  ...
# 3722                CHIESE (FIUME)         riverWaterBody  ...
# 3724                CHIESE (FIUME)         riverWaterBody  ...
# 3807             TIDONE (TORRENTE)         riverWaterBody  ...
# 4381      MANTOVA INFERIORE (LAGO)          lakeWaterBody  ...
# 4383       MANTOVA DI MEZZO (LAGO)          lakeWaterBody  ...
# 4997               PALUDE MAGGIORE  transitionalWaterBody  ...
# 5045                 SACCA SESSOLA  transitionalWaterBody  ...
# 5391                      MARGHERA  transitionalWaterBody  ...
# 5408                  FIUME ISONZO         riverWaterBody  ...
# 38747                        SARDA         riverWaterBody  ...
# 38751                     LA TENZA         riverWaterBody  ...
#
#       subUnitIdentifier subUnitIdentifierScheme                subUnitName  \
# 3384             ITN008           euSubUnitCode                      SU PO
# 3389             ITN008           euSubUnitCode                      SU PO
# 3391             ITN008           euSubUnitCode                      SU PO
# 3393             ITN008           euSubUnitCode                      SU PO
# 3422             ITN008           euSubUnitCode                      SU PO
# 3426             ITN008           euSubUnitCode                      SU PO
# 3446             ITN008           euSubUnitCode                      SU PO
# 3460             ITN008           euSubUnitCode                      SU PO
# 3702             ITN008           euSubUnitCode                      SU PO
# 3720             ITN008           euSubUnitCode                      SU PO
# 3722             ITN008           euSubUnitCode                      SU PO
# 3724             ITN008           euSubUnitCode                      SU PO
# 3807             ITN008           euSubUnitCode                      SU PO
# 4381             ITN008           euSubUnitCode                      SU PO
# 4383             ITN008           euSubUnitCode                      SU PO
# 4997            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5045            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5391            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5408            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 38747           ITF2018           euSubUnitCode  RBD APPENNINO MERIDIONALE
# 38751           ITF2018           euSubUnitCode  RBD APPENNINO MERIDIONALE
#
#       rbdIdentifier rbdIdentifierScheme                    rbdName  \
# 3384        ITB2018           euRBDCode               RBD FIUME PO
# 3389        ITB2018           euRBDCode               RBD FIUME PO
# 3391        ITB2018           euRBDCode               RBD FIUME PO
# 3393        ITB2018           euRBDCode               RBD FIUME PO
# 3422        ITB2018           euRBDCode               RBD FIUME PO
# 3426        ITB2018           euRBDCode               RBD FIUME PO
# 3446        ITB2018           euRBDCode               RBD FIUME PO
# 3460        ITB2018           euRBDCode               RBD FIUME PO
# 3702        ITB2018           euRBDCode               RBD FIUME PO
# 3720        ITB2018           euRBDCode               RBD FIUME PO
# 3722        ITB2018           euRBDCode               RBD FIUME PO
# 3724        ITB2018           euRBDCode               RBD FIUME PO
# 3807        ITB2018           euRBDCode               RBD FIUME PO
# 4381        ITB2018           euRBDCode               RBD FIUME PO
# 4383        ITB2018           euRBDCode               RBD FIUME PO
# 4997        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5045        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5391        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5408        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 38747       ITF2018           euRBDCode  RBD APPENNINO MERIDIONALE
# 38751       ITF2018           euRBDCode  RBD APPENNINO MERIDIONALE
#
#       confidentialityStatus       lon       lat statusCode
# 3384                      F   6.90119  45.70563     stable
# 3389                      F   7.04696  45.86905     stable
# 3391                      F   6.98846  45.83103     stable
# 3393                      F   6.96235  45.80982     stable
# 3422                      F   7.51992  45.80641     stable
# 3426                      F   7.45950  45.73625     stable
# 3446                      F   7.74147  45.88489     stable
# 3460                      F   7.81165  45.86369     stable
# 3702                      F  10.70809  45.30345     stable
# 3720                      F  10.40019  45.68847     stable
# 3722                      F  10.44006  45.59145     stable
# 3724                      F  10.43708  45.54479     stable
# 3807                      F   9.26964  44.87896     stable
# 4381                      F  10.80875  45.14752     stable
# 4383                      F  10.80299  45.16247     stable
# 4997                      F  12.48787  45.50469     stable
# 5045                      F  12.32424  45.40250     stable
# 5391                      F  12.27414  45.41314     stable
# 5408                      F  13.46204  45.86489     stable
# 38747                     F  15.30926  40.94507     stable
# 38751                     F  15.10764  40.66780     stable
#
# [21 rows x 23 columns]

# %%
spatial[spatial.duplicated(keep = False)] # This shows the duplictaed items, including the duplicated rows.
# Out:
#       countryCode thematicIdIdentifier thematicIdIdentifierScheme  \
# 3383           IT          IT020561VA1       euMonitoringSiteCode
# 3384           IT          IT020561VA1       euMonitoringSiteCode
# 3388           IT       IT020570081VA1       euMonitoringSiteCode
# 3389           IT       IT020570081VA1       euMonitoringSiteCode
# 3390           IT       IT020570081VA2       euMonitoringSiteCode
# 3391           IT       IT020570081VA2       euMonitoringSiteCode
# 3392           IT       IT020570082VA1       euMonitoringSiteCode
# 3393           IT       IT020570082VA1       euMonitoringSiteCode
# 3421           IT          IT020802VA1       euMonitoringSiteCode
# 3422           IT          IT020802VA1       euMonitoringSiteCode
# 3425           IT          IT020804VA1       euMonitoringSiteCode
# 3426           IT          IT020804VA1       euMonitoringSiteCode
# 3445           IT          IT020941VA2       euMonitoringSiteCode
# 3446           IT          IT020941VA2       euMonitoringSiteCode
# 3459           IT          IT021041VA1       euMonitoringSiteCode
# 3460           IT          IT021041VA1       euMonitoringSiteCode
# 3701           IT      IT03N0080563IR1       euMonitoringSiteCode
# 3702           IT      IT03N0080563IR1       euMonitoringSiteCode
# 3719           IT  IT03N00806000412IR1       euMonitoringSiteCode
# 3720           IT  IT03N00806000412IR1       euMonitoringSiteCode
# 3721           IT  IT03N00806000413IR1       euMonitoringSiteCode
# 3722           IT  IT03N00806000413IR1       euMonitoringSiteCode
# 3723           IT  IT03N00806000414IR1       euMonitoringSiteCode
# 3724           IT  IT03N00806000414IR1       euMonitoringSiteCode
# 3806           IT      IT03N0080991IR1       euMonitoringSiteCode
# 3807           IT      IT03N0080991IR1       euMonitoringSiteCode
# 4380           IT     IT03POMI4ILN1LO1       euMonitoringSiteCode
# 4381           IT     IT03POMI4ILN1LO1       euMonitoringSiteCode
# 4382           IT     IT03POMI4MLN1LO1       euMonitoringSiteCode
# 4383           IT     IT03POMI4MLN1LO1       euMonitoringSiteCode
# 4996           IT          IT05EC_VE-8       euMonitoringSiteCode
# 4997           IT          IT05EC_VE-8       euMonitoringSiteCode
# 5044           IT        IT05ENC4_VE-6       euMonitoringSiteCode
# 5045           IT        IT05ENC4_VE-6       euMonitoringSiteCode
# 5390           IT        IT05PNC1_VE-1       euMonitoringSiteCode
# 5391           IT        IT05PNC1_VE-1       euMonitoringSiteCode
# 5407           IT          IT06GO04BIS       euMonitoringSiteCode
# 5408           IT          IT06GO04BIS       euMonitoringSiteCode
# 38746          IT               ITSAR1   eionetMonitoringSiteCode
# 38747          IT               ITSAR1   eionetMonitoringSiteCode
# 38750          IT                ITTEN   eionetMonitoringSiteCode
# 38751          IT                ITTEN   eionetMonitoringSiteCode
#
#       monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 3383               IT020561VA1           euMonitoringSiteCode
# 3384               IT020561VA1           euMonitoringSiteCode
# 3388            IT020570081VA1           euMonitoringSiteCode
# 3389            IT020570081VA1           euMonitoringSiteCode
# 3390            IT020570081VA2           euMonitoringSiteCode
# 3391            IT020570081VA2           euMonitoringSiteCode
# 3392            IT020570082VA1           euMonitoringSiteCode
# 3393            IT020570082VA1           euMonitoringSiteCode
# 3421               IT020802VA1           euMonitoringSiteCode
# 3422               IT020802VA1           euMonitoringSiteCode
# 3425               IT020804VA1           euMonitoringSiteCode
# 3426               IT020804VA1           euMonitoringSiteCode
# 3445               IT020941VA2           euMonitoringSiteCode
# 3446               IT020941VA2           euMonitoringSiteCode
# 3459               IT021041VA1           euMonitoringSiteCode
# 3460               IT021041VA1           euMonitoringSiteCode
# 3701           IT03N0080563IR1           euMonitoringSiteCode
# 3702           IT03N0080563IR1           euMonitoringSiteCode
# 3719       IT03N00806000412IR1           euMonitoringSiteCode
# 3720       IT03N00806000412IR1           euMonitoringSiteCode
# 3721       IT03N00806000413IR1           euMonitoringSiteCode
# 3722       IT03N00806000413IR1           euMonitoringSiteCode
# 3723       IT03N00806000414IR1           euMonitoringSiteCode
# 3724       IT03N00806000414IR1           euMonitoringSiteCode
# 3806           IT03N0080991IR1           euMonitoringSiteCode
# 3807           IT03N0080991IR1           euMonitoringSiteCode
# 4380          IT03POMI4ILN1LO1           euMonitoringSiteCode
# 4381          IT03POMI4ILN1LO1           euMonitoringSiteCode
# 4382          IT03POMI4MLN1LO1           euMonitoringSiteCode
# 4383          IT03POMI4MLN1LO1           euMonitoringSiteCode
# 4996               IT05EC_VE-8           euMonitoringSiteCode
# 4997               IT05EC_VE-8           euMonitoringSiteCode
# 5044             IT05ENC4_VE-6           euMonitoringSiteCode
# 5045             IT05ENC4_VE-6           euMonitoringSiteCode
# 5390             IT05PNC1_VE-1           euMonitoringSiteCode
# 5391             IT05PNC1_VE-1           euMonitoringSiteCode
# 5407               IT06GO04BIS           euMonitoringSiteCode
# 5408               IT06GO04BIS           euMonitoringSiteCode
# 38746                   ITSAR1       eionetMonitoringSiteCode
# 38747                   ITSAR1       eionetMonitoringSiteCode
# 38750                    ITTEN       eionetMonitoringSiteCode
# 38751                    ITTEN       eionetMonitoringSiteCode
#
#                                       monitoringSiteName  \
# 3383                 DOIRE DE LA THUILE - CHAZ PONTAILLE
# 3384                 DOIRE DE LA THUILE - CHAZ PONTAILLE
# 3388                        DOIRE DE FERRET - GREUVETTAZ
# 3389                        DOIRE DE FERRET - GREUVETTAZ
# 3390                      DOIRE DE FERRET - PLANPINCIEUX
# 3391                      DOIRE DE FERRET - PLANPINCIEUX
# 3392                              DOIRE DE FERRET - FOCE
# 3393                              DOIRE DE FERRET - FOCE
# 3421                  SAINT-BARTHÏ¿½LEMY - PONTE PIERREY
# 3422                  SAINT-BARTHÏ¿½LEMY - PONTE PIERREY
# 3425                           SAINT-BARTHÏ¿½LEMY - FOCE
# 3426                           SAINT-BARTHÏ¿½LEMY - FOCE
# 3445                           EVANÏ¿½ON  - MONTE VERRAZ
# 3446                           EVANÏ¿½ON  - MONTE VERRAZ
# 3459                                        LYS - GRENNE
# 3460                                        LYS - GRENNE
# 3701                                           MARMIROLO
# 3702                                           MARMIROLO
# 3719                                              BARGHE
# 3720                                              BARGHE
# 3721                                             GAVARDO
# 3722                                             GAVARDO
# 3723                                            PREVALLE
# 3724                                            PREVALLE
# 3806                                        ZAVATTARELLO
# 3807                                        ZAVATTARELLO
# 4380                                             MANTOVA
# 4381                                             MANTOVA
# 4382                                             MANTOVA
# 4383                                             MANTOVA
# 4996                      VENEZIA - EX SALINA SAN FELICE
# 4997                      VENEZIA - EX SALINA SAN FELICE
# 5044                             VENEZIA - SACCA SESSOLA
# 5045                             VENEZIA - SACCA SESSOLA
# 5390                                    VENEZIA - FUSINA
# 5391                                    VENEZIA - FUSINA
# 5407   FIUME ISONZO - A VALLE IMPIANTO DEPURAZIONE GR...
# 5408   FIUME ISONZO - A VALLE IMPIANTO DEPURAZIONE GR...
# 38746                                       SARDA - SAR1
# 38747                                       SARDA - SAR1
# 38750                                     LA TENZA - TEN
# 38751                                     LA TENZA - TEN
#
#                      waterBodyIdentifier waterBodyIdentifierScheme  \
# 3383                          IT020561VA    euSurfaceWaterBodyCode
# 3384                          IT020561VA    euSurfaceWaterBodyCode
# 3388                       IT020570081VA    euSurfaceWaterBodyCode
# 3389                       IT020570081VA    euSurfaceWaterBodyCode
# 3390                       IT020570081VA    euSurfaceWaterBodyCode
# 3391                       IT020570081VA    euSurfaceWaterBodyCode
# 3392                       IT020570082VA    euSurfaceWaterBodyCode
# 3393                       IT020570082VA    euSurfaceWaterBodyCode
# 3421                          IT020802VA    euSurfaceWaterBodyCode
# 3422                          IT020802VA    euSurfaceWaterBodyCode
# 3425                          IT020804VA    euSurfaceWaterBodyCode
# 3426                          IT020804VA    euSurfaceWaterBodyCode
# 3445                          IT020941VA    euSurfaceWaterBodyCode
# 3446                          IT020941VA    euSurfaceWaterBodyCode
# 3459                          IT021041VA    euSurfaceWaterBodyCode
# 3460                          IT021041VA    euSurfaceWaterBodyCode
# 3701                      IT03N0080564LO    euSurfaceWaterBodyCode
# 3702                      IT03N0080564LO    euSurfaceWaterBodyCode
# 3719                  IT03N00806000412LO    euSurfaceWaterBodyCode
# 3720                  IT03N00806000412LO    euSurfaceWaterBodyCode
# 3721                  IT03N00806000413LO    euSurfaceWaterBodyCode
# 3722                  IT03N00806000413LO    euSurfaceWaterBodyCode
# 3723                  IT03N00806000414LO    euSurfaceWaterBodyCode
# 3724                  IT03N00806000414LO    euSurfaceWaterBodyCode
# 3806                      IT03N0080991LO    euSurfaceWaterBodyCode
# 3807                      IT03N0080991LO    euSurfaceWaterBodyCode
# 4380                     IT03POMI4ILN1LO    euSurfaceWaterBodyCode
# 4381                     IT03POMI4ILN1LO    euSurfaceWaterBodyCode
# 4382                     IT03POMI4MLN1LO    euSurfaceWaterBodyCode
# 4383                     IT03POMI4MLN1LO    euSurfaceWaterBodyCode
# 4996                     ITATW00001700VN    euSurfaceWaterBodyCode
# 4997                     ITATW00001700VN    euSurfaceWaterBodyCode
# 5044                     ITATW00001000VN    euSurfaceWaterBodyCode
# 5045                     ITATW00001000VN    euSurfaceWaterBodyCode
# 5390                     ITATW00001100VN    euSurfaceWaterBodyCode
# 5391                     ITATW00001100VN    euSurfaceWaterBodyCode
# 5407                 ITARW13IS00100030FR    euSurfaceWaterBodyCode
# 5408                 ITARW13IS00100030FR    euSurfaceWaterBodyCode
# 38746        ITF015RWI02000359SARDA18IN7    euSurfaceWaterBodyCode
# 38747        ITF015RWI02000359SARDA18IN7    euSurfaceWaterBodyCode
# 38750  ITF015RWI02500891LATENZA18SS2TEN1    euSurfaceWaterBodyCode
# 38751  ITF015RWI02500891LATENZA18SS2TEN1    euSurfaceWaterBodyCode
#
#                      waterBodyName    specialisedZoneType  ...  \
# 3383            DOIRE DE LA THUILE         riverWaterBody  ...
# 3384            DOIRE DE LA THUILE         riverWaterBody  ...
# 3388           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3389           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3390           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3391           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3392           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3393           DOIRE DE VAL FERRET         riverWaterBody  ...
# 3421   TORRENT DE SAINT-BARTH?LEMY         riverWaterBody  ...
# 3422   TORRENT DE SAINT-BARTH?LEMY         riverWaterBody  ...
# 3425   TORRENT DE SAINT-BARTH?LEMY         riverWaterBody  ...
# 3426   TORRENT DE SAINT-BARTH?LEMY         riverWaterBody  ...
# 3445               TORRENT EVENSON         riverWaterBody  ...
# 3446               TORRENT EVENSON         riverWaterBody  ...
# 3459                   TORRENT LYS         riverWaterBody  ...
# 3460                   TORRENT LYS         riverWaterBody  ...
# 3701                MINCIO (FIUME)         riverWaterBody  ...
# 3702                MINCIO (FIUME)         riverWaterBody  ...
# 3719                CHIESE (FIUME)         riverWaterBody  ...
# 3720                CHIESE (FIUME)         riverWaterBody  ...
# 3721                CHIESE (FIUME)         riverWaterBody  ...
# 3722                CHIESE (FIUME)         riverWaterBody  ...
# 3723                CHIESE (FIUME)         riverWaterBody  ...
# 3724                CHIESE (FIUME)         riverWaterBody  ...
# 3806             TIDONE (TORRENTE)         riverWaterBody  ...
# 3807             TIDONE (TORRENTE)         riverWaterBody  ...
# 4380      MANTOVA INFERIORE (LAGO)          lakeWaterBody  ...
# 4381      MANTOVA INFERIORE (LAGO)          lakeWaterBody  ...
# 4382       MANTOVA DI MEZZO (LAGO)          lakeWaterBody  ...
# 4383       MANTOVA DI MEZZO (LAGO)          lakeWaterBody  ...
# 4996               PALUDE MAGGIORE  transitionalWaterBody  ...
# 4997               PALUDE MAGGIORE  transitionalWaterBody  ...
# 5044                 SACCA SESSOLA  transitionalWaterBody  ...
# 5045                 SACCA SESSOLA  transitionalWaterBody  ...
# 5390                      MARGHERA  transitionalWaterBody  ...
# 5391                      MARGHERA  transitionalWaterBody  ...
# 5407                  FIUME ISONZO         riverWaterBody  ...
# 5408                  FIUME ISONZO         riverWaterBody  ...
# 38746                        SARDA         riverWaterBody  ...
# 38747                        SARDA         riverWaterBody  ...
# 38750                     LA TENZA         riverWaterBody  ...
# 38751                     LA TENZA         riverWaterBody  ...
#
#       subUnitIdentifier subUnitIdentifierScheme                subUnitName  \
# 3383             ITN008           euSubUnitCode                      SU PO
# 3384             ITN008           euSubUnitCode                      SU PO
# 3388             ITN008           euSubUnitCode                      SU PO
# 3389             ITN008           euSubUnitCode                      SU PO
# 3390             ITN008           euSubUnitCode                      SU PO
# 3391             ITN008           euSubUnitCode                      SU PO
# 3392             ITN008           euSubUnitCode                      SU PO
# 3393             ITN008           euSubUnitCode                      SU PO
# 3421             ITN008           euSubUnitCode                      SU PO
# 3422             ITN008           euSubUnitCode                      SU PO
# 3425             ITN008           euSubUnitCode                      SU PO
# 3426             ITN008           euSubUnitCode                      SU PO
# 3445             ITN008           euSubUnitCode                      SU PO
# 3446             ITN008           euSubUnitCode                      SU PO
# 3459             ITN008           euSubUnitCode                      SU PO
# 3460             ITN008           euSubUnitCode                      SU PO
# 3701             ITN008           euSubUnitCode                      SU PO
# 3702             ITN008           euSubUnitCode                      SU PO
# 3719             ITN008           euSubUnitCode                      SU PO
# 3720             ITN008           euSubUnitCode                      SU PO
# 3721             ITN008           euSubUnitCode                      SU PO
# 3722             ITN008           euSubUnitCode                      SU PO
# 3723             ITN008           euSubUnitCode                      SU PO
# 3724             ITN008           euSubUnitCode                      SU PO
# 3806             ITN008           euSubUnitCode                      SU PO
# 3807             ITN008           euSubUnitCode                      SU PO
# 4380             ITN008           euSubUnitCode                      SU PO
# 4381             ITN008           euSubUnitCode                      SU PO
# 4382             ITN008           euSubUnitCode                      SU PO
# 4383             ITN008           euSubUnitCode                      SU PO
# 4996            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 4997            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5044            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5045            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5390            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5391            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5407            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 5408            ITA2018           euSubUnitCode         RBD ALPI ORIENTALI
# 38746           ITF2018           euSubUnitCode  RBD APPENNINO MERIDIONALE
# 38747           ITF2018           euSubUnitCode  RBD APPENNINO MERIDIONALE
# 38750           ITF2018           euSubUnitCode  RBD APPENNINO MERIDIONALE
# 38751           ITF2018           euSubUnitCode  RBD APPENNINO MERIDIONALE
#
#       rbdIdentifier rbdIdentifierScheme                    rbdName  \
# 3383        ITB2018           euRBDCode               RBD FIUME PO
# 3384        ITB2018           euRBDCode               RBD FIUME PO
# 3388        ITB2018           euRBDCode               RBD FIUME PO
# 3389        ITB2018           euRBDCode               RBD FIUME PO
# 3390        ITB2018           euRBDCode               RBD FIUME PO
# 3391        ITB2018           euRBDCode               RBD FIUME PO
# 3392        ITB2018           euRBDCode               RBD FIUME PO
# 3393        ITB2018           euRBDCode               RBD FIUME PO
# 3421        ITB2018           euRBDCode               RBD FIUME PO
# 3422        ITB2018           euRBDCode               RBD FIUME PO
# 3425        ITB2018           euRBDCode               RBD FIUME PO
# 3426        ITB2018           euRBDCode               RBD FIUME PO
# 3445        ITB2018           euRBDCode               RBD FIUME PO
# 3446        ITB2018           euRBDCode               RBD FIUME PO
# 3459        ITB2018           euRBDCode               RBD FIUME PO
# 3460        ITB2018           euRBDCode               RBD FIUME PO
# 3701        ITB2018           euRBDCode               RBD FIUME PO
# 3702        ITB2018           euRBDCode               RBD FIUME PO
# 3719        ITB2018           euRBDCode               RBD FIUME PO
# 3720        ITB2018           euRBDCode               RBD FIUME PO
# 3721        ITB2018           euRBDCode               RBD FIUME PO
# 3722        ITB2018           euRBDCode               RBD FIUME PO
# 3723        ITB2018           euRBDCode               RBD FIUME PO
# 3724        ITB2018           euRBDCode               RBD FIUME PO
# 3806        ITB2018           euRBDCode               RBD FIUME PO
# 3807        ITB2018           euRBDCode               RBD FIUME PO
# 4380        ITB2018           euRBDCode               RBD FIUME PO
# 4381        ITB2018           euRBDCode               RBD FIUME PO
# 4382        ITB2018           euRBDCode               RBD FIUME PO
# 4383        ITB2018           euRBDCode               RBD FIUME PO
# 4996        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 4997        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5044        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5045        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5390        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5391        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5407        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 5408        ITA2018           euRBDCode         RBD ALPI ORIENTALI
# 38746       ITF2018           euRBDCode  RBD APPENNINO MERIDIONALE
# 38747       ITF2018           euRBDCode  RBD APPENNINO MERIDIONALE
# 38750       ITF2018           euRBDCode  RBD APPENNINO MERIDIONALE
# 38751       ITF2018           euRBDCode  RBD APPENNINO MERIDIONALE
#
#       confidentialityStatus       lon       lat statusCode
# 3383                      F   6.90119  45.70563     stable
# 3384                      F   6.90119  45.70563     stable
# 3388                      F   7.04696  45.86905     stable
# 3389                      F   7.04696  45.86905     stable
# 3390                      F   6.98846  45.83103     stable
# 3391                      F   6.98846  45.83103     stable
# 3392                      F   6.96235  45.80982     stable
# 3393                      F   6.96235  45.80982     stable
# 3421                      F   7.51992  45.80641     stable
# 3422                      F   7.51992  45.80641     stable
# 3425                      F   7.45950  45.73625     stable
# 3426                      F   7.45950  45.73625     stable
# 3445                      F   7.74147  45.88489     stable
# 3446                      F   7.74147  45.88489     stable
# 3459                      F   7.81165  45.86369     stable
# 3460                      F   7.81165  45.86369     stable
# 3701                      F  10.70809  45.30345     stable
# 3702                      F  10.70809  45.30345     stable
# 3719                      F  10.40019  45.68847     stable
# 3720                      F  10.40019  45.68847     stable
# 3721                      F  10.44006  45.59145     stable
# 3722                      F  10.44006  45.59145     stable
# 3723                      F  10.43708  45.54479     stable
# 3724                      F  10.43708  45.54479     stable
# 3806                      F   9.26964  44.87896     stable
# 3807                      F   9.26964  44.87896     stable
# 4380                      F  10.80875  45.14752     stable
# 4381                      F  10.80875  45.14752     stable
# 4382                      F  10.80299  45.16247     stable
# 4383                      F  10.80299  45.16247     stable
# 4996                      F  12.48787  45.50469     stable
# 4997                      F  12.48787  45.50469     stable
# 5044                      F  12.32424  45.40250     stable
# 5045                      F  12.32424  45.40250     stable
# 5390                      F  12.27414  45.41314     stable
# 5391                      F  12.27414  45.41314     stable
# 5407                      F  13.46204  45.86489     stable
# 5408                      F  13.46204  45.86489     stable
# 38746                     F  15.30926  40.94507     stable
# 38747                     F  15.30926  40.94507     stable
# 38750                     F  15.10764  40.66780     stable
# 38751                     F  15.10764  40.66780     stable
#
# [42 rows x 23 columns]

# %%
spatial = spatial.drop_duplicates() # Drop all duplicated rows keepign the first one.
spatial[spatial.duplicated()]       # Checking that no duplictaes are present in the df anymore.
# Out:
# Empty DataFrame
# Columns: [countryCode, thematicIdIdentifier, thematicIdIdentifierScheme, monitoringSiteIdentifier, monitoringSiteIdentifierScheme, monitoringSiteName, waterBodyIdentifier, waterBodyIdentifierScheme, waterBodyName, specialisedZoneType, naturalAWBHMWB, reservoir, surfaceWaterBodyTypeCode, subUnitIdentifier, subUnitIdentifierScheme, subUnitName, rbdIdentifier, rbdIdentifierScheme, rbdName, confidentialityStatus, lon, lat, statusCode]
# Index: []
#
# [0 rows x 23 columns]

# %%
spatial_duplicated_monitoringSite = spatial[spatial.duplicated(subset = ['monitoringSiteIdentifier'], keep = False)]

# %%
spatial_duplicated_monitoringSite.to_csv("spatial_duplicated_monitoringSite.csv") # Duplicated values because monitoring
                                                                                  # site id scheme was eu or eionet

# %%
len(spatial[spatial['monitoringSiteIdentifierScheme'] == 'euMonitoringSiteCode'])
# Out:
# 45448

# %%
len(spatial)
# Out:
# 54322

# %%
spatial = spatial.drop_duplicates(subset = ['monitoringSiteIdentifier'], keep = 'first')

# %%
spatial.shape
# Out:
# (54212, 23)

# %%
spatial[spatial['monitoringSiteIdentifier'] == 'IT12-F1_68']
# Out:
#      countryCode thematicIdIdentifier thematicIdIdentifierScheme  \
# 8564          IT           IT12-F1_68       euMonitoringSiteCode
#
#      monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 8564               IT12-F1_68           euMonitoringSiteCode
#
#      monitoringSiteName  waterBodyIdentifier waterBodyIdentifierScheme  \
# 8564      FIUME SACCO 5  ITN005_SACCO_13SS4T    euSurfaceWaterBodyCode
#
#      waterBodyName specialisedZoneType  ... subUnitIdentifier  \
# 8564   FIUME SACCO      riverWaterBody  ...           ITF2018
#
#      subUnitIdentifierScheme                subUnitName rbdIdentifier  \
# 8564           euSubUnitCode  RBD APPENNINO MERIDIONALE       ITF2018
#
#      rbdIdentifierScheme                    rbdName confidentialityStatus  \
# 8564           euRBDCode  RBD APPENNINO MERIDIONALE                     F
#
#            lon       lat statusCode
# 8564  13.37379  41.53829     stable
#
# [1 rows x 23 columns]

# %%
len(spatial['monitoringSiteIdentifier'].unique())
# Out:
# 54212

# %%
len(spatial)
# Out:
# 54212

# %%
# Select only necessary columns to reduce its size. (Can be reivsed later, afetr checking all the df).
spatial = spatial[['countryCode', 'thematicIdIdentifier', 'monitoringSiteIdentifier', 'monitoringSiteIdentifierScheme',
                   'monitoringSiteName', 'waterBodyIdentifier', 'waterBodyIdentifierScheme', 'waterBodyName',
                   'specialisedZoneType', 'naturalAWBHMWB', 'reservoir', 'surfaceWaterBodyTypeCode', 'subUnitIdentifier',
                   'rbdIdentifier', 'rbdName', 'lon', 'lat', 'statusCode']]

# %%
spatial.insert(0, 'ID', range(1, 1 + len(spatial)))

# %%
spatial.isnull().sum()
# Out:
# ID                                    0
# countryCode                           0
# thematicIdIdentifier                  0
# monitoringSiteIdentifier              0
# monitoringSiteIdentifierScheme        0
# monitoringSiteName                    0
# waterBodyIdentifier                   0
# waterBodyIdentifierScheme             0
# waterBodyName                         0
# specialisedZoneType                   0
# naturalAWBHMWB                    25737
# reservoir                         25737
# surfaceWaterBodyTypeCode          25737
# subUnitIdentifier                 24970
# rbdIdentifier                       227
# rbdName                             227
# lon                                   0
# lat                                   0
# statusCode                            0
# dtype: int64

# %%
spatial.fillna('Unknown', inplace = True)

# %%
spatial.isnull().sum()
# Out:
# ID                                0
# countryCode                       0
# thematicIdIdentifier              0
# monitoringSiteIdentifier          0
# monitoringSiteIdentifierScheme    0
# monitoringSiteName                0
# waterBodyIdentifier               0
# waterBodyIdentifierScheme         0
# waterBodyName                     0
# specialisedZoneType               0
# naturalAWBHMWB                    0
# reservoir                         0
# surfaceWaterBodyTypeCode          0
# subUnitIdentifier                 0
# rbdIdentifier                     0
# rbdName                           0
# lon                               0
# lat                               0
# statusCode                        0
# dtype: int64

# %%
spatial.columns
# Out:
# Index(['ID', 'countryCode', 'thematicIdIdentifier', 'monitoringSiteIdentifier',
#        'monitoringSiteIdentifierScheme', 'monitoringSiteName',
#        'waterBodyIdentifier', 'waterBodyIdentifierScheme', 'waterBodyName',
#        'specialisedZoneType', 'naturalAWBHMWB', 'reservoir',
#        'surfaceWaterBodyTypeCode', 'subUnitIdentifier', 'rbdIdentifier',
#        'rbdName', 'lon', 'lat', 'statusCode'],
#       dtype='object')

# %%
records2, attributes2 = spatial.shape
print(f"The cleaned spatial df has {records2} records and {attributes2} attributes")
# Out:
# The cleaned spatial df has 54212 records and 19 attributes

# %%
spatial.to_csv("spatial_cleaned.csv") # Save the cleaned df in csv format.

# %%
countries_codes.to_csv("countries_codes.csv")

# %% [markdown]
# <a id = 'explore_emissions'></a>
# ### 1.2 Exploratory analysis of emissions dataset
# [Top](#top)
#
# [Monitoring](#explore_monitoring)

# %%
emissions_df_raw.columns
# Out:
# Index(['countryCode', 'spatialUnitIdentifier', 'spatialUnitIdentifierScheme',
#        'phenomenonTimeReferencePeriod', 'observedPropertyDeterminandCode',
#        'observedPropertyDeterminandLabel', 'parameterEmissionsSourceCategory',
#        'parameterEPRTRfacilities', 'resultEmissionsValue',
#        'resultEmissionsUom', 'procedureEmissionsMethod',
#        'resultObservationStatus', 'Remarks', 'metadata_versionId',
#        'metadata_beginLifeSpanVersion', 'metadata_statusCode',
#        'metadata_observationStatus', 'metadata_statements', 'UID'],
#       dtype='object')

# %% [markdown]
# #### Null values

# %%
emissions_df_raw.isnull().sum().sum()
# Out:
# 299218

# %%
emissions_df_raw[emissions_df_raw.isnull().any(axis=1)]
# Out:
#        countryCode spatialUnitIdentifier spatialUnitIdentifierScheme  \
# 0               AT                AT1000                   euRBDCode
# 1               AT                AT1000                   euRBDCode
# 2               AT                AT1000                   euRBDCode
# 3               AT                AT1000                   euRBDCode
# 4               AT                AT1000                   euRBDCode
# ...            ...                   ...                         ...
# 103280          XK                    XK                 countryCode
# 103281          XK                    XK                 countryCode
# 103282          XK                    XK                 countryCode
# 103283          XK                    XK                 countryCode
# 103284          XK                    XK                 countryCode
#
#        phenomenonTimeReferencePeriod observedPropertyDeterminandCode  \
# 0                               2016                   CAS_7439-92-1
# 1                               2016                   CAS_7439-92-1
# 2                               2016                   CAS_7439-97-6
# 3                               2016                   CAS_7440-02-0
# 4                               2016                   CAS_7440-02-0
# ...                              ...                             ...
# 103280                          2019                  EEA_31615-01-7
# 103281                          2020                     EEA_31-02-7
# 103282                          2020                   EEA_3133-01-5
# 103283                          2020                   EEA_3133-03-7
# 103284                          2020                  EEA_31615-01-7
#
#        observedPropertyDeterminandLabel parameterEmissionsSourceCategory  \
# 0                Lead and its compounds                                I
# 1                Lead and its compounds                               U2
# 2             Mercury and its compounds                                I
# 3              Nickel and its compounds                                I
# 4              Nickel and its compounds                               U2
# ...                                 ...                              ...
# 103280                   Total nitrogen                              U22
# 103281           Total suspended solids                              U22
# 103282                             BOD5                              U22
# 103283                            CODCr                              U22
# 103284                   Total nitrogen                              U22
#
#        parameterEPRTRfacilities  resultEmissionsValue resultEmissionsUom  \
# 0                           yes            759.500000               kg/a
# 1                           yes            280.000000               kg/a
# 2                           yes              5.290000               kg/a
# 3                           yes           2568.300000               kg/a
# 4                           yes           3690.000000               kg/a
# ...                         ...                   ...                ...
# 103280                       no              9.477000                t/a
# 103281                       no              6.959722                t/a
# 103282                       no              3.117451                t/a
# 103283                       no             55.646105                t/a
# 103284                       no              6.920974                t/a
#
#        procedureEmissionsMethod resultObservationStatus  \
# 0                    calculated                       X
# 1                    calculated                       X
# 2                    calculated                       X
# 3                    calculated                       X
# 4                    calculated                       X
# ...                         ...                     ...
# 103280                 measured                       A
# 103281                 measured                       A
# 103282                 measured                       A
# 103283                 measured                       A
# 103284                 measured                       A
#
#                                Remarks  \
# 0       data derived from EPRTR by ETC
# 1       data derived from EPRTR by ETC
# 2       data derived from EPRTR by ETC
# 3       data derived from EPRTR by ETC
# 4       data derived from EPRTR by ETC
# ...                                ...
# 103280                            None
# 103281                            None
# 103282                            None
# 103283                            None
# 103284                            None
#
#                                        metadata_versionId  \
# 0       http://discomap.eea.europa.eu/data/wisesoe/der...
# 1       http://discomap.eea.europa.eu/data/wisesoe/der...
# 2       http://discomap.eea.europa.eu/data/wisesoe/der...
# 3       http://discomap.eea.europa.eu/data/wisesoe/der...
# 4       http://discomap.eea.europa.eu/data/wisesoe/der...
# ...                                                   ...
# 103280  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103281  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103282  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103283  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
# 103284  https://cdr.eionet.europa.eu/xk/eea/wise_soe/w...
#
#        metadata_beginLifeSpanVersion metadata_statusCode  \
# 0            2020-06-08 00:00:00.000        experimental
# 1            2020-06-08 00:00:00.000        experimental
# 2            2020-06-08 00:00:00.000        experimental
# 3            2020-06-08 00:00:00.000        experimental
# 4            2020-06-08 00:00:00.000        experimental
# ...                              ...                 ...
# 103280       2021-01-13 09:43:12.000              stable
# 103281       2022-01-12 23:18:02.000              stable
# 103282       2022-01-12 23:18:02.000              stable
# 103283       2022-01-12 23:18:02.000              stable
# 103284       2022-01-12 23:18:02.000              stable
#
#        metadata_observationStatus metadata_statements     UID
# 0                               A                None  137076
# 1                               A                None  137077
# 2                               A                None  137078
# 3                               A                None  137080
# 4                               A                None  137081
# ...                           ...                 ...     ...
# 103280                          A                None  162583
# 103281                          A                None  179787
# 103282                          A                None  179788
# 103283                          A                None  179789
# 103284                          A                None  179790
#
# [102854 rows x 19 columns]

# %%
emissions_df_raw = emissions_df_raw.drop(['metadata_versionId',
                                           'metadata_beginLifeSpanVersion', 'metadata_statusCode',
                                           'metadata_observationStatus', 'metadata_statements'], axis = 1)

# %%
emissions_df_raw[emissions_df_raw.isnull().any(axis=1)]
# Out:
#        countryCode spatialUnitIdentifier spatialUnitIdentifierScheme  \
# 107             AT                AT1001               euSubUnitCode
# 108             AT                AT1001               euSubUnitCode
# 109             AT                AT1001               euSubUnitCode
# 110             AT                AT1001               euSubUnitCode
# 111             AT                AT1001               euSubUnitCode
# ...            ...                   ...                         ...
# 103280          XK                    XK                 countryCode
# 103281          XK                    XK                 countryCode
# 103282          XK                    XK                 countryCode
# 103283          XK                    XK                 countryCode
# 103284          XK                    XK                 countryCode
#
#        phenomenonTimeReferencePeriod observedPropertyDeterminandCode  \
# 107                       2004--2007                   CAS_7723-14-0
# 108                       2004--2007                   CAS_7723-14-0
# 109                       2004--2007                   CAS_7723-14-0
# 110                       2004--2007                   CAS_7723-14-0
# 111                       2004--2007                  EEA_31615-01-7
# ...                              ...                             ...
# 103280                          2019                  EEA_31615-01-7
# 103281                          2020                     EEA_31-02-7
# 103282                          2020                   EEA_3133-01-5
# 103283                          2020                   EEA_3133-03-7
# 103284                          2020                  EEA_31615-01-7
#
#        observedPropertyDeterminandLabel parameterEmissionsSourceCategory  \
# 107                    Total phosphorus                               NP
# 108                    Total phosphorus                              NP1
# 109                    Total phosphorus                              NP2
# 110                    Total phosphorus                              NP4
# 111                      Total nitrogen                               NP
# ...                                 ...                              ...
# 103280                   Total nitrogen                              U22
# 103281           Total suspended solids                              U22
# 103282                             BOD5                              U22
# 103283                            CODCr                              U22
# 103284                   Total nitrogen                              U22
#
#        parameterEPRTRfacilities  resultEmissionsValue resultEmissionsUom  \
# 107                        None           4722.000000                t/a
# 108                        None           1529.000000                t/a
# 109                        None             44.000000                t/a
# 110                        None            299.000000                t/a
# 111                        None          83218.000000                t/a
# ...                         ...                   ...                ...
# 103280                       no              9.477000                t/a
# 103281                       no              6.959722                t/a
# 103282                       no              3.117451                t/a
# 103283                       no             55.646105                t/a
# 103284                       no              6.920974                t/a
#
#        procedureEmissionsMethod resultObservationStatus Remarks     UID
# 107                        None                    None    None  169087
# 108                        None                    None    None  169088
# 109                        None                    None    None  169089
# 110                        None                    None    None  169090
# 111                        None                    None    None  169091
# ...                         ...                     ...     ...     ...
# 103280                 measured                       A    None  162583
# 103281                 measured                       A    None  179787
# 103282                 measured                       A    None  179788
# 103283                 measured                       A    None  179789
# 103284                 measured                       A    None  179790
#
# [88974 rows x 14 columns]

# %%
emissions_df_raw['countryCode'].unique()
emissions_df_raw['spatialUnitIdentifier'].unique()
emissions_df_raw['observedPropertyDeterminandCode'].unique()
emissions_df_raw['resultEmissionsValue'].unique()
emissions_df_raw['resultEmissionsUom'].unique()
emissions_df_raw['parameterEmissionsSourceCategory'].unique()
emissions_df_raw['spatialUnitIdentifierScheme'].unique()
# Out:
# array(['euRBDCode', 'euSubUnitCode', 'eionetSubUnitCode', 'countryCode',
#        'eionetRBDCode'], dtype=object)

# %%
emissions_df_raw = emissions_df_raw.dropna(subset = ['observedPropertyDeterminandCode', 'resultEmissionsValue', 'resultEmissionsUom'])

# %%
emissions_df_raw.isnull().sum().sum()
# Out:
# 186743

# %%
emissions_df_raw[emissions_df_raw['resultEmissionsUom'] == "None"]
emissions_df_raw[emissions_df_raw['resultEmissionsUom'].isnull()]
emissions_df_raw['resultEmissionsUom'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #### Normalizing unit of measure columns

# %%
# Normalizing measured data from kg/a to t/a to have comparable data
emissions_df_raw['resultsEmissionsValueNEW'] = np.where(emissions_df_raw['resultEmissionsUom'] == "kg/a",
                                                       emissions_df_raw['resultEmissionsValue']/1000,
                                                        emissions_df_raw['resultEmissionsValue'])
emissions_df_raw['resultEmissionsUomNEW'] = np.where(emissions_df_raw['resultEmissionsUom'] == "kg/a",
                                                     "t/a",
                                                     emissions_df_raw['resultEmissionsUom'])
emissions_df_raw
# Out:
#        countryCode spatialUnitIdentifier spatialUnitIdentifierScheme  \
# 0               AT                AT1000                   euRBDCode
# 1               AT                AT1000                   euRBDCode
# 2               AT                AT1000                   euRBDCode
# 3               AT                AT1000                   euRBDCode
# 4               AT                AT1000                   euRBDCode
# ...            ...                   ...                         ...
# 103280          XK                    XK                 countryCode
# 103281          XK                    XK                 countryCode
# 103282          XK                    XK                 countryCode
# 103283          XK                    XK                 countryCode
# 103284          XK                    XK                 countryCode
#
#        phenomenonTimeReferencePeriod observedPropertyDeterminandCode  \
# 0                               2016                   CAS_7439-92-1
# 1                               2016                   CAS_7439-92-1
# 2                               2016                   CAS_7439-97-6
# 3                               2016                   CAS_7440-02-0
# 4                               2016                   CAS_7440-02-0
# ...                              ...                             ...
# 103280                          2019                  EEA_31615-01-7
# 103281                          2020                     EEA_31-02-7
# 103282                          2020                   EEA_3133-01-5
# 103283                          2020                   EEA_3133-03-7
# 103284                          2020                  EEA_31615-01-7
#
#        observedPropertyDeterminandLabel parameterEmissionsSourceCategory  \
# 0                Lead and its compounds                                I
# 1                Lead and its compounds                               U2
# 2             Mercury and its compounds                                I
# 3              Nickel and its compounds                                I
# 4              Nickel and its compounds                               U2
# ...                                 ...                              ...
# 103280                   Total nitrogen                              U22
# 103281           Total suspended solids                              U22
# 103282                             BOD5                              U22
# 103283                            CODCr                              U22
# 103284                   Total nitrogen                              U22
#
#        parameterEPRTRfacilities  resultEmissionsValue resultEmissionsUom  \
# 0                           yes            759.500000               kg/a
# 1                           yes            280.000000               kg/a
# 2                           yes              5.290000               kg/a
# 3                           yes           2568.300000               kg/a
# 4                           yes           3690.000000               kg/a
# ...                         ...                   ...                ...
# 103280                       no              9.477000                t/a
# 103281                       no              6.959722                t/a
# 103282                       no              3.117451                t/a
# 103283                       no             55.646105                t/a
# 103284                       no              6.920974                t/a
#
#        procedureEmissionsMethod resultObservationStatus  \
# 0                    calculated                       X
# 1                    calculated                       X
# 2                    calculated                       X
# 3                    calculated                       X
# 4                    calculated                       X
# ...                         ...                     ...
# 103280                 measured                       A
# 103281                 measured                       A
# 103282                 measured                       A
# 103283                 measured                       A
# 103284                 measured                       A
#
#                                Remarks     UID  resultsEmissionsValueNEW  \
# 0       data derived from EPRTR by ETC  137076                  0.759500
# 1       data derived from EPRTR by ETC  137077                  0.280000
# 2       data derived from EPRTR by ETC  137078                  0.005290
# 3       data derived from EPRTR by ETC  137080                  2.568300
# 4       data derived from EPRTR by ETC  137081                  3.690000
# ...                                ...     ...                       ...
# 103280                            None  162583                  9.477000
# 103281                            None  179787                  6.959722
# 103282                            None  179788                  3.117451
# 103283                            None  179789                 55.646105
# 103284                            None  179790                  6.920974
#
#        resultEmissionsUomNEW
# 0                        t/a
# 1                        t/a
# 2                        t/a
# 3                        t/a
# 4                        t/a
# ...                      ...
# 103280                   t/a
# 103281                   t/a
# 103282                   t/a
# 103283                   t/a
# 103284                   t/a
#
# [98045 rows x 16 columns]

# %%
emissions_df_raw = emissions_df_raw.drop(['resultEmissionsUom', 'resultEmissionsValue'], axis = 1)

# %%
emissions_df_raw
# Out:
#        countryCode spatialUnitIdentifier spatialUnitIdentifierScheme  \
# 0               AT                AT1000                   euRBDCode
# 1               AT                AT1000                   euRBDCode
# 2               AT                AT1000                   euRBDCode
# 3               AT                AT1000                   euRBDCode
# 4               AT                AT1000                   euRBDCode
# ...            ...                   ...                         ...
# 103280          XK                    XK                 countryCode
# 103281          XK                    XK                 countryCode
# 103282          XK                    XK                 countryCode
# 103283          XK                    XK                 countryCode
# 103284          XK                    XK                 countryCode
#
#        phenomenonTimeReferencePeriod observedPropertyDeterminandCode  \
# 0                               2016                   CAS_7439-92-1
# 1                               2016                   CAS_7439-92-1
# 2                               2016                   CAS_7439-97-6
# 3                               2016                   CAS_7440-02-0
# 4                               2016                   CAS_7440-02-0
# ...                              ...                             ...
# 103280                          2019                  EEA_31615-01-7
# 103281                          2020                     EEA_31-02-7
# 103282                          2020                   EEA_3133-01-5
# 103283                          2020                   EEA_3133-03-7
# 103284                          2020                  EEA_31615-01-7
#
#        observedPropertyDeterminandLabel parameterEmissionsSourceCategory  \
# 0                Lead and its compounds                                I
# 1                Lead and its compounds                               U2
# 2             Mercury and its compounds                                I
# 3              Nickel and its compounds                                I
# 4              Nickel and its compounds                               U2
# ...                                 ...                              ...
# 103280                   Total nitrogen                              U22
# 103281           Total suspended solids                              U22
# 103282                             BOD5                              U22
# 103283                            CODCr                              U22
# 103284                   Total nitrogen                              U22
#
#        parameterEPRTRfacilities procedureEmissionsMethod  \
# 0                           yes               calculated
# 1                           yes               calculated
# 2                           yes               calculated
# 3                           yes               calculated
# 4                           yes               calculated
# ...                         ...                      ...
# 103280                       no                 measured
# 103281                       no                 measured
# 103282                       no                 measured
# 103283                       no                 measured
# 103284                       no                 measured
#
#        resultObservationStatus                         Remarks     UID  \
# 0                            X  data derived from EPRTR by ETC  137076
# 1                            X  data derived from EPRTR by ETC  137077
# 2                            X  data derived from EPRTR by ETC  137078
# 3                            X  data derived from EPRTR by ETC  137080
# 4                            X  data derived from EPRTR by ETC  137081
# ...                        ...                             ...     ...
# 103280                       A                            None  162583
# 103281                       A                            None  179787
# 103282                       A                            None  179788
# 103283                       A                            None  179789
# 103284                       A                            None  179790
#
#         resultsEmissionsValueNEW resultEmissionsUomNEW
# 0                       0.759500                   t/a
# 1                       0.280000                   t/a
# 2                       0.005290                   t/a
# 3                       2.568300                   t/a
# 4                       3.690000                   t/a
# ...                          ...                   ...
# 103280                  9.477000                   t/a
# 103281                  6.959722                   t/a
# 103282                  3.117451                   t/a
# 103283                 55.646105                   t/a
# 103284                  6.920974                   t/a
#
# [98045 rows x 14 columns]

# %% [markdown]
# #### Split date columns

# %%
emissions_df_raw['phenomenonTimeReferencePeriod'].unique()
# Out:
# array(['2016', '2017', '2018', '2019', '2020', '2004--2007', '2007',
#        '2009--2011', '2010', '2011', '2012', '2014', '2015', '2005',
#        '1998', '2000', '2001', '2002', '2003', '2004', '2006', '2008',
#        '2009', '2013', '1977--1998', '1987--1998', '1985', '1992', '1995',
#        '1996', '2009--2014', '2012--2015', '2011--2014', '2000--2006',
#        '2009--2012', '2016--2018', '2018--2019', '2019--2020',
#        '2013--2014'], dtype=object)

# %%
emissions_df_raw[['TimeReferenceStart', 'TimeReferenceEnd']] = emissions_df_raw['phenomenonTimeReferencePeriod'].str.split('--', expand = True)

# %%
emissions_df_raw['TimeReferenceEnd'].isna().sum()
# Out:
# 97366

# %%
emissions_df_raw['TimeReferenceEnd'] = np.where(emissions_df_raw['TimeReferenceEnd'].isnull(),
                                                emissions_df_raw['TimeReferenceStart'],
                                                emissions_df_raw['TimeReferenceEnd'])

# %%
emissions_df_raw = emissions_df_raw.drop(['phenomenonTimeReferencePeriod'], axis = 1)

# %% [markdown]
# #### Duplicates

# %%
emissions_df_raw[emissions_df_raw.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [countryCode, spatialUnitIdentifier, spatialUnitIdentifierScheme, observedPropertyDeterminandCode, observedPropertyDeterminandLabel, parameterEmissionsSourceCategory, parameterEPRTRfacilities, procedureEmissionsMethod, resultObservationStatus, Remarks, UID, resultsEmissionsValueNEW, resultEmissionsUomNEW, TimeReferenceStart, TimeReferenceEnd]
# Index: []

# %% [markdown]
# There are no duplicated rows.

# %%
emissions_df_raw
# Out:
#        countryCode spatialUnitIdentifier spatialUnitIdentifierScheme  \
# 0               AT                AT1000                   euRBDCode
# 1               AT                AT1000                   euRBDCode
# 2               AT                AT1000                   euRBDCode
# 3               AT                AT1000                   euRBDCode
# 4               AT                AT1000                   euRBDCode
# ...            ...                   ...                         ...
# 103280          XK                    XK                 countryCode
# 103281          XK                    XK                 countryCode
# 103282          XK                    XK                 countryCode
# 103283          XK                    XK                 countryCode
# 103284          XK                    XK                 countryCode
#
#        observedPropertyDeterminandCode observedPropertyDeterminandLabel  \
# 0                        CAS_7439-92-1           Lead and its compounds
# 1                        CAS_7439-92-1           Lead and its compounds
# 2                        CAS_7439-97-6        Mercury and its compounds
# 3                        CAS_7440-02-0         Nickel and its compounds
# 4                        CAS_7440-02-0         Nickel and its compounds
# ...                                ...                              ...
# 103280                  EEA_31615-01-7                   Total nitrogen
# 103281                     EEA_31-02-7           Total suspended solids
# 103282                   EEA_3133-01-5                             BOD5
# 103283                   EEA_3133-03-7                            CODCr
# 103284                  EEA_31615-01-7                   Total nitrogen
#
#        parameterEmissionsSourceCategory parameterEPRTRfacilities  \
# 0                                     I                      yes
# 1                                    U2                      yes
# 2                                     I                      yes
# 3                                     I                      yes
# 4                                    U2                      yes
# ...                                 ...                      ...
# 103280                              U22                       no
# 103281                              U22                       no
# 103282                              U22                       no
# 103283                              U22                       no
# 103284                              U22                       no
#
#        procedureEmissionsMethod resultObservationStatus  \
# 0                    calculated                       X
# 1                    calculated                       X
# 2                    calculated                       X
# 3                    calculated                       X
# 4                    calculated                       X
# ...                         ...                     ...
# 103280                 measured                       A
# 103281                 measured                       A
# 103282                 measured                       A
# 103283                 measured                       A
# 103284                 measured                       A
#
#                                Remarks     UID  resultsEmissionsValueNEW  \
# 0       data derived from EPRTR by ETC  137076                  0.759500
# 1       data derived from EPRTR by ETC  137077                  0.280000
# 2       data derived from EPRTR by ETC  137078                  0.005290
# 3       data derived from EPRTR by ETC  137080                  2.568300
# 4       data derived from EPRTR by ETC  137081                  3.690000
# ...                                ...     ...                       ...
# 103280                            None  162583                  9.477000
# 103281                            None  179787                  6.959722
# 103282                            None  179788                  3.117451
# 103283                            None  179789                 55.646105
# 103284                            None  179790                  6.920974
#
#        resultEmissionsUomNEW TimeReferenceStart TimeReferenceEnd
# 0                        t/a               2016             2016
# 1                        t/a               2016             2016
# 2                        t/a               2016             2016
# 3                        t/a               2016             2016
# 4                        t/a               2016             2016
# ...                      ...                ...              ...
# 103280                   t/a               2019             2019
# 103281                   t/a               2020             2020
# 103282                   t/a               2020             2020
# 103283                   t/a               2020             2020
# 103284                   t/a               2020             2020
#
# [98045 rows x 15 columns]

# %% [markdown]
# #### Emissions source categories

# %%
emissions_df_raw['observedPropertyDeterminandLabel'].unique()
emissions_df_raw['parameterEmissionsSourceCategory'].unique()
# Out:
# array(['I', 'U2', 'NP', 'NP1', 'NP2', 'NP4', 'U21', 'U22', 'U23', 'U24',
#        'I4', 'NP3', 'NP7', 'U', 'U1', 'NP72', 'O', 'NP8', 'I3', 'NP5',
#        'PT', 'O2', 'O3', 'O4', 'U11', 'NP71', 'U12', 'U13', 'O1', 'U14'],
#       dtype=object)

# %%
emission_source_category = ['PT', 
                            'U',
                            'U1', 'U11', 'U12', 'U13', 'U14',
                            'U2', 'U21', 'U22', 'U23', 'U24',
                            'I', 'I3', 'I4', 
                            'O', 'O1', 'O2', 'O3', 'O4', 
                            'NP',
                            'NP1', 'NP2', 'NP3', 'NP4', 'NP5', 'NP7', 'NP8',
                            'NP71', 'NP72', 'NP73', 'NP74']
emission_source_category_label = ['Point Sources',
                                  'Point Urban Wastewater',
                                  'Point Urban Wastewater Untreated',
                                  'Point Urban Wastewater Untreated less than 2000 p.e.',
                                  'Point Urban Wastewater Untreated between 2000 and 10000 p.e.',
                                  'Point Urban Wastewater Untreated between 10000 and 100000 p.e.',
                                  'Point Urban Wastewater Untreated more than 100000 p.e.',
                                  'Point Urban Wastewater Treated',
                                  'Point Urban Wastewater Treated less than 2000 p.e.',
                                  'Point Urban Wastewater Treated between 2000 and 10000 p.e.',
                                  'Point Urban Wastewater Treated between 10000 and 100000 p.e.',
                                  'Point Urban Wastewater Treated more than 100000 p.e.',
                                  'Point Industrial Wastewater',
                                  'Point Industrial Wastewater Treated',
                                  'Point Industrial Wastewater Untreated',
                                  'Point Other point emissions',
                                  'Point Contaminated sites or abandoned industrial sites',
                                  'Point Waste disposal sites',
                                  'Point Mine waters',
                                  'Point Aquaculture',
                                  'Diffuse sources',
                                  'Diffuse Agricultural emissions',
                                  'Diffuse Atmospheric deposition',
                                  'Diffuse Un-connected dwellings emissions',
                                  'Diffuse Urban run-off',
                                  'Diffuse Storm overflow emissions',
                                  'Diffuse Other diffuse emissions',
                                  'Diffuse Background emissions',
                                  'Diffuse Other Forestry emissions',
                                  'Diffuse Other Transport emissions',
                                  'Diffuse Other Mining emissions',
                                  'Diffuse Other Aquaculture emissions']

# %%
emission_category = pd.DataFrame(list(zip(emission_source_category, emission_source_category_label)), columns = ['EmissionSourceCat', 'EmissionSourceCatLabel'])
emission_category
# Out:
#    EmissionSourceCat                             EmissionSourceCatLabel
# 0                 PT                                      Point Sources
# 1                  U                             Point Urban Wastewater
# 2                 U1                   Point Urban Wastewater Untreated
# 3                U11  Point Urban Wastewater Untreated less than 200...
# 4                U12  Point Urban Wastewater Untreated between 2000 ...
# 5                U13  Point Urban Wastewater Untreated between 10000...
# 6                U14  Point Urban Wastewater Untreated more than 100...
# 7                 U2                     Point Urban Wastewater Treated
# 8                U21  Point Urban Wastewater Treated less than 2000 ...
# 9                U22  Point Urban Wastewater Treated between 2000 an...
# 10               U23  Point Urban Wastewater Treated between 10000 a...
# 11               U24  Point Urban Wastewater Treated more than 10000...
# 12                 I                        Point Industrial Wastewater
# 13                I3                Point Industrial Wastewater Treated
# 14                I4              Point Industrial Wastewater Untreated
# 15                 O                        Point Other point emissions
# 16                O1  Point Contaminated sites or abandoned industri...
# 17                O2                         Point Waste disposal sites
# 18                O3                                  Point Mine waters
# 19                O4                                  Point Aquaculture
# 20                NP                                    Diffuse sources
# 21               NP1                     Diffuse Agricultural emissions
# 22               NP2                     Diffuse Atmospheric deposition
# 23               NP3           Diffuse Un-connected dwellings emissions
# 24               NP4                              Diffuse Urban run-off
# 25               NP5                   Diffuse Storm overflow emissions
# 26               NP7                    Diffuse Other diffuse emissions
# 27               NP8                       Diffuse Background emissions
# 28              NP71                   Diffuse Other Forestry emissions
# 29              NP72                  Diffuse Other Transport emissions
# 30              NP73                     Diffuse Other Mining emissions
# 31              NP74                Diffuse Other Aquaculture emissions

# %%
emissions_df_raw.columns
# Out:
# Index(['countryCode', 'spatialUnitIdentifier', 'spatialUnitIdentifierScheme',
#        'observedPropertyDeterminandCode', 'observedPropertyDeterminandLabel',
#        'parameterEmissionsSourceCategory', 'parameterEPRTRfacilities',
#        'procedureEmissionsMethod', 'resultObservationStatus', 'Remarks', 'UID',
#        'resultsEmissionsValueNEW', 'resultEmissionsUomNEW',
#        'TimeReferenceStart', 'TimeReferenceEnd'],
#       dtype='object')

# %%
emissions_df_raw.shape
# Out:
# (98045, 15)

# %% [markdown]
# #### Save cleaned df

# %%
emission_category.to_csv("emission_category.csv")

# %%
emissions_df_raw.to_csv("emissions_cleaned.csv")

# %% [markdown]
# <a id = 'explore_monitoring'></a>
# ### 1.3 Exploratory analysis of monitoring dataset
# [Top](#top)
#
# [Emissions](#explore_emissions)

# %% [markdown]
# The explanantion with some metadata of the monitoring dataset is available here https://www.eea.europa.eu/data-and-maps/data/waterbase-water-quantity-14/waterbase-water-quantity-microsoft-access-database-2-tables.

# %%
monitoring_df_raw.columns
# Out:
# Index(['countryCode', 'monitoringSiteIdentifier',
#        'monitoringSiteIdentifierScheme', 'observedProperty',
#        'phenomenonTimePeriod', 'phenomenonTimePeriod_year',
#        'phenomenonTimePeriod_month', 'phenomenonTimePeriod_day',
#        'resultObservedValue', 'resultObservationStatus', 'Remarks',
#        'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %%
monitoring_df_raw.head()
# Out:
#   countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0          AT                 AT212753       eionetMonitoringSiteCode
# 1          AT                 AT212753       eionetMonitoringSiteCode
# 2          AT                 AT212753       eionetMonitoringSiteCode
# 3          AT                 AT212753       eionetMonitoringSiteCode
# 4          AT                 AT212753       eionetMonitoringSiteCode
#
#   observedProperty phenomenonTimePeriod  phenomenonTimePeriod_year  \
# 0               SF           2007-05-08                       2007
# 1               SF           2007-05-09                       2007
# 2               SF           2007-05-10                       2007
# 3               SF           2007-05-11                       2007
# 4               SF           2007-05-12                       2007
#
#    phenomenonTimePeriod_month  phenomenonTimePeriod_day  resultObservedValue  \
# 0                         5.0                       8.0                 26.3
# 1                         5.0                       9.0                 25.8
# 2                         5.0                      10.0                 25.1
# 3                         5.0                      11.0                 24.6
# 4                         5.0                      12.0                 25.5
#
#   resultObservationStatus Remarks  \
# 0                     NaN     NaN
# 1                     NaN     NaN
# 2                     NaN     NaN
# 3                     NaN     NaN
# 4                     NaN     NaN
#
#                                   metadata_versionId  \
# 0  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1  http://discomap.eea.europa.eu/data/wisesoe/der...
# 2  http://discomap.eea.europa.eu/data/wisesoe/der...
# 3  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion metadata_statusCode  \
# 0       2015-11-30 00:00:00.000        experimental
# 1       2015-11-30 00:00:00.000        experimental
# 2       2015-11-30 00:00:00.000        experimental
# 3       2015-11-30 00:00:00.000        experimental
# 4       2015-11-30 00:00:00.000        experimental
#
#   metadata_observationStatus metadata_statements  UID
# 0                          A                 NaN    1
# 1                          A                 NaN    2
# 2                          A                 NaN    3
# 3                          A                 NaN    4
# 4                          A                 NaN    5

# %%
monitoring_df_raw['observedProperty'].unique() # SF GWL
monitoring_df_raw['metadata_statusCode'].unique() #'experimental', 'stable', 'valid' 
monitoring_df_raw['metadata_observationStatus'].unique() # 'A', 'U'
monitoring_df_raw['resultObservationStatus'].unique() # nan, 'A', 'O', 'L', 'M', 'N'
monitoring_df_raw['Remarks'].unique() #
# Out:
# array([nan, 'under repair', 'ES_QA_4004', ..., 'IT02_VALTOURNENCHE_MAEN',
#        'IT02_GRESSONEY_LA_TRINITE_ALPE_COURTLYS',
#        'IT02_GRESSONEY_SAINT_JEAN_CAPOLUOGO'], dtype=object)

# %%
monitoring_df_raw['resultObservationStatus'].value_counts()
# Out:
# A    1118445
# L      30219
# M      22010
# O      16265
# N        579
# Name: resultObservationStatus, dtype: int64

# %%
resultObservationStatus = ['A', 'O', 'L', 'M', 'N', 'W', 'X', 'Y']
resultObservationStatusLabel = ['Correct',
                                'Missing value - no further information or past record should be deleted',
                                'Missing value - not collected',
                                'Missing value - not exist',
                                'Missing value - not relevant or not significant',
                                'Missing value - in another source category',
                                'Reported value includes data from another source category (categories)',
                                'The source category does not exactly match the standard definition']
obs_status_df = pd.DataFrame(list(zip(resultObservationStatus, resultObservationStatusLabel)),
                             columns = ['Obs_status', 'Obs_status_label'])

# %%
obs_status_df
# Out:
#   Obs_status                                   Obs_status_label
# 0          A                                            Correct
# 1          O  Missing value - no further information or past...
# 2          L                      Missing value - not collected
# 3          M                          Missing value - not exist
# 4          N    Missing value - not relevant or not significant
# 5          W         Missing value - in another source category
# 6          X  Reported value includes data from another sour...
# 7          Y  The source category does not exactly match the...

# %%
monitoring_df_raw_missing = monitoring_df_raw[(monitoring_df_raw['resultObservationStatus'] == 'O') |
                                               (monitoring_df_raw['resultObservationStatus'] == 'L') |
                                               (monitoring_df_raw['resultObservationStatus'] == 'M') |
                                               (monitoring_df_raw['resultObservationStatus'] == 'N') |
                                               (monitoring_df_raw['resultObservationStatus'] == 'W')]
""" |
                                               (monitoring_df_raw['resultObservationStatus'] == 'X') |
                                               (monitoring_df_raw['resultObservationStatus'] == 'Y')"""
# Out:
# " |\n                                               (monitoring_df_raw['resultObservationStatus'] == 'X') |\n                                               (monitoring_df_raw['resultObservationStatus'] == 'Y')"

# %%
monitoring_df_raw_missing['resultObservedValue'].unique()
# Out:
# array([            nan,  2.27300000e+01,  2.27000000e+01,  2.26600000e+01,
#         2.25800000e+01,  2.25200000e+01,  2.27200000e+01,  2.27400000e+01,
#         2.27500000e+01,  2.27900000e+01,  2.27600000e+01,  2.80100000e+01,
#         1.06700000e+02,  0.00000000e+00,  9.56000000e+01,  4.81612903e-01,
#         3.03500000e-01,  2.83968254e-01,  7.06666667e-01,  1.36126984e+00,
#        -1.17283333e+00,  8.69838710e-01,  1.81800000e+00, -5.21129032e-01,
#        -6.08500000e-01,  4.96282615e+01,  4.80228420e+01,  4.86930356e+01,
#         5.35070200e+01,  5.25833333e+01,  5.23266667e+01,  5.14500000e+01,
#         5.15533333e+01,  5.22950000e+01,  5.15100000e+01,  5.01000000e+01,
#         1.00000000e+01,  1.24000000e+01,  1.26000000e+01,  1.31000000e+01,
#         1.56000000e+01,  1.55000000e+01,  1.62000000e+01,  1.61000000e+01,
#         1.54000000e+01,  1.47000000e+01,  1.44000000e+01,  1.06000000e+01,
#         1.08000000e+01,  9.31000000e+00,  2.04000000e+01,  4.80000000e+01,
#         6.22000000e+01,  6.07000000e+01,  6.56000000e+01,  5.15000000e+01,
#         4.16000000e+01,  3.42000000e+01,  3.32000000e+01,  2.98000000e+01,
#         2.86000000e+01,  2.63000000e+01,  2.50000000e+01,  2.45000000e+01,
#         2.36000000e+01,  2.32000000e+01,  2.54000000e+01,  2.66000000e+01,
#         2.69000000e+01,  2.71000000e+01,  9.40000000e-01,  3.11000000e+00,
#         1.28550000e+02,  3.10000000e+01,  8.32000000e+01,  5.00000000e-01,
#         4.00000000e-01,  4.00000000e+00,  8.60000000e+00,  1.70000000e+00,
#         1.50000000e+00,  2.30000000e+00,  2.50000000e+00,  3.20000000e+00,
#         7.00000000e-01,  1.60000000e+00,  1.00000000e+00,  8.00000000e-01,
#         4.50000000e+00,  8.80000000e+00,  1.40000000e+00,  2.00000000e+00,
#         1.19000000e+01,  3.00000000e-01,  2.00000000e-01,  1.80000000e+00,
#         1.21000000e+01,  2.10000000e+00,  1.18000000e+01,  9.60000000e+00,
#         7.30000000e+00,  6.40000000e+00,  1.20000000e+00,  1.90000000e+00,
#         6.00000000e-01,  9.00000000e-01,  1.10000000e+00,  1.30000000e+00,
#         2.90000000e+00,  4.10000000e+00,  4.30000000e+00,  4.80000000e+00,
#         6.60000000e+00,  6.90000000e+00,  6.80000000e+00,  4.20000000e+00,
#         3.10000000e+00,  2.60000000e+00,  4.70000000e+00,  2.70000000e+00,
#         2.80000000e+00,  9.30000000e+00,  5.10000000e+00,  2.20000000e+00,
#         4.60000000e+00,  3.00000000e+00,  9.10000000e+00,  7.10000000e-02,
#         5.40000000e-02,  4.70000000e-02,  4.50000000e-02,  4.30000000e-02,
#         2.21000000e-01,  9.40000000e-02,  6.60000000e-02,  5.80000000e-02,
#         4.85000000e-01,  2.63000000e-01,  1.80000000e-01,  1.47000000e-01,
#         5.99000000e-01,  2.07000000e-01,  1.49000000e-01,  1.23000000e-01,
#         1.39000000e-01,  1.11000000e-01,  9.90000000e-02,  8.90000000e-02,
#         8.80000000e-02,  8.10000000e-02,  7.70000000e-02,  7.52000000e-01,
#         1.24000000e+00,  4.67000000e-01])

# %% [markdown]
# Not all the observation results labeled as "missing" actually shows a null value, some of them shows also an actual value.

# %%
monitoring = monitoring_df_raw.drop(['metadata_versionId', 'metadata_beginLifeSpanVersion',
                                     'metadata_statements', 'Remarks'],
                                      axis = 1)

# %%
monitoring[monitoring['phenomenonTimePeriod'].str.contains(pat = '--')]
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 2861493          IT                IT13G-G4S       eionetMonitoringSiteCode
# 2861494          IT                IT13G-G4S       eionetMonitoringSiteCode
# 2861495          IT                IT13G-G4S       eionetMonitoringSiteCode
# 2861496          IT                IT13G-G4S       eionetMonitoringSiteCode
# 2861497          IT                IT13G-G5S       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4824880          IT                 IT05GW98           euMonitoringSiteCode
# 4824881          IT                 IT05GW99           euMonitoringSiteCode
# 4824882          IT                 IT05GW99           euMonitoringSiteCode
# 4824883          IT                 IT05GW99           euMonitoringSiteCode
# 4824884          IT                 IT05GW99           euMonitoringSiteCode
#
#         observedProperty phenomenonTimePeriod  phenomenonTimePeriod_year  \
# 2861493               SF     2015-01--2015-03                       2015
# 2861494               SF     2015-04--2015-06                       2015
# 2861495               SF     2015-07--2015-09                       2015
# 2861496               SF     2015-10--2015-12                       2015
# 2861497               SF     2015-01--2015-03                       2015
# ...                  ...                  ...                        ...
# 4824880              GWL     2020-10--2020-12                       2020
# 4824881              GWL     2020-01--2020-03                       2020
# 4824882              GWL     2020-04--2020-06                       2020
# 4824883              GWL     2020-07--2020-09                       2020
# 4824884              GWL     2020-10--2020-12                       2020
#
#          phenomenonTimePeriod_month  phenomenonTimePeriod_day  \
# 2861493                         1.0                       NaN
# 2861494                         4.0                       NaN
# 2861495                         7.0                       NaN
# 2861496                        10.0                       NaN
# 2861497                         1.0                       NaN
# ...                             ...                       ...
# 4824880                        10.0                       NaN
# 4824881                         1.0                       NaN
# 4824882                         4.0                       NaN
# 4824883                         7.0                       NaN
# 4824884                        10.0                       NaN
#
#          resultObservedValue resultObservationStatus metadata_statusCode  \
# 2861493                 1.50                     NaN               valid
# 2861494                 2.20                     NaN               valid
# 2861495                 1.00                     NaN               valid
# 2861496                 2.20                     NaN               valid
# 2861497                 0.30                     NaN               valid
# ...                      ...                     ...                 ...
# 4824880                 5.18                     NaN               valid
# 4824881                15.67                     NaN               valid
# 4824882                15.58                     NaN               valid
# 4824883                15.76                     NaN               valid
# 4824884                16.03                     NaN               valid
#
#         metadata_observationStatus      UID
# 2861493                          A  4400977
# 2861494                          A  4400978
# 2861495                          A  4400979
# 2861496                          A  4400980
# 2861497                          A  4400981
# ...                            ...      ...
# 4824880                          A  6702116
# 4824881                          A  6702117
# 4824882                          A  6702118
# 4824883                          A  6702119
# 4824884                          A  6702120
#
# [12578 rows x 13 columns]

# %%
monitoring[['phenomenonTimePeriodStart', 'phenomenonTimePeriodEnd']] = monitoring['phenomenonTimePeriod'].str.split('--', expand=True)

# %%
monitoring
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                AT                 AT212753       eionetMonitoringSiteCode
# 1                AT                 AT212753       eionetMonitoringSiteCode
# 2                AT                 AT212753       eionetMonitoringSiteCode
# 3                AT                 AT212753       eionetMonitoringSiteCode
# 4                AT                 AT212753       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4888873          SE          SE635140-128901           euMonitoringSiteCode
# 4888874          SE          SE635140-128901           euMonitoringSiteCode
# 4888875          SE          SE635140-128901           euMonitoringSiteCode
# 4888876          SE          SE635140-128901           euMonitoringSiteCode
# 4888877          SE          SE635140-128901           euMonitoringSiteCode
#
#         observedProperty phenomenonTimePeriod  phenomenonTimePeriod_year  \
# 0                     SF           2007-05-08                       2007
# 1                     SF           2007-05-09                       2007
# 2                     SF           2007-05-10                       2007
# 3                     SF           2007-05-11                       2007
# 4                     SF           2007-05-12                       2007
# ...                  ...                  ...                        ...
# 4888873               SF           2020-08-01                       2020
# 4888874               SF           2020-09-01                       2020
# 4888875               SF           2020-10-01                       2020
# 4888876               SF           2020-11-01                       2020
# 4888877               SF           2020-12-01                       2020
#
#          phenomenonTimePeriod_month  phenomenonTimePeriod_day  \
# 0                               5.0                       8.0
# 1                               5.0                       9.0
# 2                               5.0                      10.0
# 3                               5.0                      11.0
# 4                               5.0                      12.0
# ...                             ...                       ...
# 4888873                         8.0                       1.0
# 4888874                         9.0                       1.0
# 4888875                        10.0                       1.0
# 4888876                        11.0                       1.0
# 4888877                        12.0                       1.0
#
#          resultObservedValue resultObservationStatus metadata_statusCode  \
# 0                      26.30                     NaN        experimental
# 1                      25.80                     NaN        experimental
# 2                      25.10                     NaN        experimental
# 3                      24.60                     NaN        experimental
# 4                      25.50                     NaN        experimental
# ...                      ...                     ...                 ...
# 4888873                11.40                     NaN               valid
# 4888874                 8.97                     NaN               valid
# 4888875                38.80                     NaN               valid
# 4888876                77.90                     NaN               valid
# 4888877                61.30                     NaN               valid
#
#         metadata_observationStatus      UID phenomenonTimePeriodStart  \
# 0                                A        1                2007-05-08
# 1                                A        2                2007-05-09
# 2                                A        3                2007-05-10
# 3                                A        4                2007-05-11
# 4                                A        5                2007-05-12
# ...                            ...      ...                       ...
# 4888873                          A  6766109                2020-08-01
# 4888874                          A  6766110                2020-09-01
# 4888875                          A  6766111                2020-10-01
# 4888876                          A  6766112                2020-11-01
# 4888877                          A  6766113                2020-12-01
#
#         phenomenonTimePeriodEnd
# 0                          None
# 1                          None
# 2                          None
# 3                          None
# 4                          None
# ...                         ...
# 4888873                    None
# 4888874                    None
# 4888875                    None
# 4888876                    None
# 4888877                    None
#
# [4888878 rows x 15 columns]

# %%
monitoring['phenomenonTimePeriodStart'] = np.where(monitoring['phenomenonTimePeriodStart'].isna(),
                                                  monitoring['phenomenonTimePeriod'],
                                                  monitoring['phenomenonTimePeriodStart'])

# %%
monitoring['phenomenonTimePeriodEnd'] = np.where(monitoring['phenomenonTimePeriodEnd'].isna(),
                                                monitoring['phenomenonTimePeriod'],
                                                monitoring['phenomenonTimePeriodEnd'])

# %%
monitoring.drop(['phenomenonTimePeriod'], axis = 1, inplace = True)

# %% [markdown]
# #### Null values

# %%
monitoring[monitoring.isnull().any(axis=1)]
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                AT                 AT212753       eionetMonitoringSiteCode
# 1                AT                 AT212753       eionetMonitoringSiteCode
# 2                AT                 AT212753       eionetMonitoringSiteCode
# 3                AT                 AT212753       eionetMonitoringSiteCode
# 4                AT                 AT212753       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4888873          SE          SE635140-128901           euMonitoringSiteCode
# 4888874          SE          SE635140-128901           euMonitoringSiteCode
# 4888875          SE          SE635140-128901           euMonitoringSiteCode
# 4888876          SE          SE635140-128901           euMonitoringSiteCode
# 4888877          SE          SE635140-128901           euMonitoringSiteCode
#
#         observedProperty  phenomenonTimePeriod_year  \
# 0                     SF                       2007
# 1                     SF                       2007
# 2                     SF                       2007
# 3                     SF                       2007
# 4                     SF                       2007
# ...                  ...                        ...
# 4888873               SF                       2020
# 4888874               SF                       2020
# 4888875               SF                       2020
# 4888876               SF                       2020
# 4888877               SF                       2020
#
#          phenomenonTimePeriod_month  phenomenonTimePeriod_day  \
# 0                               5.0                       8.0
# 1                               5.0                       9.0
# 2                               5.0                      10.0
# 3                               5.0                      11.0
# 4                               5.0                      12.0
# ...                             ...                       ...
# 4888873                         8.0                       1.0
# 4888874                         9.0                       1.0
# 4888875                        10.0                       1.0
# 4888876                        11.0                       1.0
# 4888877                        12.0                       1.0
#
#          resultObservedValue resultObservationStatus metadata_statusCode  \
# 0                      26.30                     NaN        experimental
# 1                      25.80                     NaN        experimental
# 2                      25.10                     NaN        experimental
# 3                      24.60                     NaN        experimental
# 4                      25.50                     NaN        experimental
# ...                      ...                     ...                 ...
# 4888873                11.40                     NaN               valid
# 4888874                 8.97                     NaN               valid
# 4888875                38.80                     NaN               valid
# 4888876                77.90                     NaN               valid
# 4888877                61.30                     NaN               valid
#
#         metadata_observationStatus      UID phenomenonTimePeriodStart  \
# 0                                A        1                2007-05-08
# 1                                A        2                2007-05-09
# 2                                A        3                2007-05-10
# 3                                A        4                2007-05-11
# 4                                A        5                2007-05-12
# ...                            ...      ...                       ...
# 4888873                          A  6766109                2020-08-01
# 4888874                          A  6766110                2020-09-01
# 4888875                          A  6766111                2020-10-01
# 4888876                          A  6766112                2020-11-01
# 4888877                          A  6766113                2020-12-01
#
#         phenomenonTimePeriodEnd
# 0                    2007-05-08
# 1                    2007-05-09
# 2                    2007-05-10
# 3                    2007-05-11
# 4                    2007-05-12
# ...                         ...
# 4888873              2020-08-01
# 4888874              2020-09-01
# 4888875              2020-10-01
# 4888876              2020-11-01
# 4888877              2020-12-01
#
# [3862206 rows x 14 columns]

# %%
monitoring.isnull().sum().sum()
# Out:
# 4125968

# %%
monitoring.isnull().sum()
# Out:
# countryCode                             0
# monitoringSiteIdentifier                0
# monitoringSiteIdentifierScheme          0
# observedProperty                        0
# phenomenonTimePeriod_year               0
# phenomenonTimePeriod_month          27909
# phenomenonTimePeriod_day           327895
# resultObservedValue                 68804
# resultObservationStatus           3701360
# metadata_statusCode                     0
# metadata_observationStatus              0
# UID                                     0
# phenomenonTimePeriodStart               0
# phenomenonTimePeriodEnd                 0
# dtype: int64

# %% [markdown]
# Remove all the rows that shows a null value in the column 'resultObservedValue'. The null values in the rest of the columns are not influencing the analysis because the 'phenomenonTimePeriod' column has the month and day values in case of null values in columns 'phenomenonTimePeriod_month' and 'phenomenonTimePeriod_day'. And the status of the observation result will be considered as 'accepted' unless is it missing.
#
# For both cases, the null values will be replaces with dummy values.

# %%
monitoring = monitoring.dropna(subset = ['resultObservedValue'], axis = 0)

# %%
monitoring.isnull().sum()
# Out:
# countryCode                             0
# monitoringSiteIdentifier                0
# monitoringSiteIdentifierScheme          0
# observedProperty                        0
# phenomenonTimePeriod_year               0
# phenomenonTimePeriod_month          27859
# phenomenonTimePeriod_day           317631
# resultObservedValue                     0
# resultObservationStatus           3701342
# metadata_statusCode                     0
# metadata_observationStatus              0
# UID                                     0
# phenomenonTimePeriodStart               0
# phenomenonTimePeriodEnd                 0
# dtype: int64

# %% [markdown]
# Replace the null values in the column 'resultObservationStatus' with the value 'Unknown'.
#
# Replace the null values in the columns 'phenomenonTimePeriod_month' and 'phenomenonTimePeriod_day' with the value 1, as first month and first day.

# %%
monitoring['resultObservationStatus'] = monitoring['resultObservationStatus'].fillna('Unknown')
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\3885256282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monitoring['resultObservationStatus'] = monitoring['resultObservationStatus'].fillna('Unknown')

# %%
monitoring['phenomenonTimePeriod_month'] = monitoring['phenomenonTimePeriod_month'].fillna(1)
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\776262584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monitoring['phenomenonTimePeriod_month'] = monitoring['phenomenonTimePeriod_month'].fillna(1)

# %%
monitoring['phenomenonTimePeriod_day'] = monitoring['phenomenonTimePeriod_day'].fillna(1)
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\1691629293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monitoring['phenomenonTimePeriod_day'] = monitoring['phenomenonTimePeriod_day'].fillna(1)

# %%
monitoring.isnull().sum()
# Out:
# countryCode                       0
# monitoringSiteIdentifier          0
# monitoringSiteIdentifierScheme    0
# observedProperty                  0
# phenomenonTimePeriod_year         0
# phenomenonTimePeriod_month        0
# phenomenonTimePeriod_day          0
# resultObservedValue               0
# resultObservationStatus           0
# metadata_statusCode               0
# metadata_observationStatus        0
# UID                               0
# phenomenonTimePeriodStart         0
# phenomenonTimePeriodEnd           0
# dtype: int64

# %% [markdown]
# #### Duplicates

# %%
monitoring[monitoring.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [countryCode, monitoringSiteIdentifier, monitoringSiteIdentifierScheme, observedProperty, phenomenonTimePeriod_year, phenomenonTimePeriod_month, phenomenonTimePeriod_day, resultObservedValue, resultObservationStatus, metadata_statusCode, metadata_observationStatus, UID, phenomenonTimePeriodStart, phenomenonTimePeriodEnd]
# Index: []

# %% [markdown]
# Add a column with the unit of measure, depending on the property observed: GWL as Groundwater level (m) and SF as Stream flow (m3/s).

# %%
monitoring['resultObservedUnit'] = np.where(monitoring['observedProperty'] == 'SF',
                                           'm3/s',
                                           'm')
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\692912243.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monitoring['resultObservedUnit'] = np.where(monitoring['observedProperty'] == 'SF',

# %%
monitoring[monitoring['observedProperty'] == 'GWL']
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 64438            BE         BEVL_VMM_MS_A051           euMonitoringSiteCode
# 64439            BE         BEVL_VMM_MS_A051           euMonitoringSiteCode
# 64440            BE         BEVL_VMM_MS_A051           euMonitoringSiteCode
# 64441            BE         BEVL_VMM_MS_A051           euMonitoringSiteCode
# 64442            BE         BEVL_VMM_MS_A051           euMonitoringSiteCode
# ...             ...                      ...                            ...
# 4871998          IE    IEWE_G_0002_1200_0013           euMonitoringSiteCode
# 4871999          IE    IEWE_G_0002_1200_0013           euMonitoringSiteCode
# 4872000          IE    IEWE_G_0002_1200_0013           euMonitoringSiteCode
# 4872001          IE    IEWE_G_0002_1200_0013           euMonitoringSiteCode
# 4872002          IE    IEWE_G_0002_1200_0013           euMonitoringSiteCode
#
#         observedProperty  phenomenonTimePeriod_year  \
# 64438                GWL                       2008
# 64439                GWL                       2008
# 64440                GWL                       2008
# 64441                GWL                       2008
# 64442                GWL                       2008
# ...                  ...                        ...
# 4871998              GWL                       2020
# 4871999              GWL                       2020
# 4872000              GWL                       2020
# 4872001              GWL                       2020
# 4872002              GWL                       2020
#
#          phenomenonTimePeriod_month  phenomenonTimePeriod_day  \
# 64438                           1.0                       1.0
# 64439                           2.0                       1.0
# 64440                           3.0                       1.0
# 64441                           4.0                       1.0
# 64442                           5.0                       1.0
# ...                             ...                       ...
# 4871998                         7.0                       1.0
# 4871999                         8.0                       1.0
# 4872000                         9.0                       1.0
# 4872001                        10.0                       1.0
# 4872002                        11.0                       1.0
#
#          resultObservedValue resultObservationStatus metadata_statusCode  \
# 64438              44.435234                 Unknown        experimental
# 64439              44.481923                 Unknown        experimental
# 64440              44.660132                 Unknown        experimental
# 64441              44.674854                 Unknown        experimental
# 64442              44.469028                 Unknown        experimental
# ...                      ...                     ...                 ...
# 4871998             3.691000                 Unknown               valid
# 4871999             5.660000                 Unknown               valid
# 4872000             6.954000                 Unknown               valid
# 4872001             4.813000                 Unknown               valid
# 4872002             9.720000                 Unknown               valid
#
#         metadata_observationStatus      UID phenomenonTimePeriodStart  \
# 64438                            A   287723                   2008-01
# 64439                            A   287724                   2008-02
# 64440                            A   287725                   2008-03
# 64441                            A   287726                   2008-04
# 64442                            A   287727                   2008-05
# ...                            ...      ...                       ...
# 4871998                          A  6749234                2020-07-01
# 4871999                          A  6749235                2020-08-01
# 4872000                          A  6749236                2020-09-01
# 4872001                          A  6749237                2020-10-01
# 4872002                          A  6749238                2020-11-01
#
#         phenomenonTimePeriodEnd resultObservedUnit
# 64438                   2008-01                  m
# 64439                   2008-02                  m
# 64440                   2008-03                  m
# 64441                   2008-04                  m
# 64442                   2008-05                  m
# ...                         ...                ...
# 4871998              2020-07-01                  m
# 4871999              2020-08-01                  m
# 4872000              2020-09-01                  m
# 4872001              2020-10-01                  m
# 4872002              2020-11-01                  m
#
# [745456 rows x 15 columns]

# %%
records, attributes = monitoring.shape
print(f"The cleaned monitoring df has now {records} records and {attributes} attributes.")
# Out:
# The cleaned monitoring df has now 4820074 records and 15 attributes.

# %% [markdown]
# Filter the dataset to surface waters results only.

# %%
monitoring_surf = monitoring[monitoring['observedProperty'] == 'SF']

# %%
monitoring_surf['phenomenonTimePeriodStart'] = pd.to_datetime(monitoring_surf['phenomenonTimePeriodStart'])
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\4012915895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monitoring_surf['phenomenonTimePeriodStart'] = pd.to_datetime(monitoring_surf['phenomenonTimePeriodStart'])

# %%
monitoring_surf['phenomenonTimePeriodEnd'] = pd.to_datetime(monitoring_surf['phenomenonTimePeriodEnd'])
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\1863918446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   monitoring_surf['phenomenonTimePeriodEnd'] = pd.to_datetime(monitoring_surf['phenomenonTimePeriodEnd'])

# %%
monitoring_surf.columns
# Out:
# Index(['countryCode', 'monitoringSiteIdentifier',
#        'monitoringSiteIdentifierScheme', 'observedProperty',
#        'phenomenonTimePeriod_year', 'phenomenonTimePeriod_month',
#        'phenomenonTimePeriod_day', 'resultObservedValue',
#        'resultObservationStatus', 'metadata_statusCode',
#        'metadata_observationStatus', 'UID', 'phenomenonTimePeriodStart',
#        'phenomenonTimePeriodEnd', 'resultObservedUnit'],
#       dtype='object')

# %% [markdown]
# #### Save the cleaned df

# %%
monitoring.to_csv("Monitoring_cleaned.csv")

# %%
monitoring_surf.to_csv("Monitoring_surf_cleaned.csv")

# %% [markdown]
# <a id = 'explore_aggregated'></a>
# ### 1.4 Exploratory analysis of aggregated dataset
# [Top](#top)

# %%
aggregated_df_raw.columns
# Out:
# Index(['countryCode', 'monitoringSiteIdentifier',
#        'monitoringSiteIdentifierScheme', 'parameterWaterBodyCategory',
#        'observedPropertyDeterminandCode', 'observedPropertyDeterminandLabel',
#        'procedureAnalysedMatrix', 'resultUom', 'phenomenonTimeReferenceYear',
#        'parameterSamplingPeriod', 'procedureLOQValue', 'resultNumberOfSamples',
#        'resultQualityNumberOfSamplesBelowLOQ', 'resultQualityMinimumBelowLOQ',
#        'resultMinimumValue', 'resultQualityMeanBelowLOQ', 'resultMeanValue',
#        'resultQualityMaximumBelowLOQ', 'resultMaximumValue',
#        'resultQualityMedianBelowLOQ', 'resultMedianValue',
#        'resultStandardDeviationValue', 'procedureAnalyticalMethod',
#        'parameterSampleDepth', 'resultObservationStatus', 'remarks',
#        'metadata_versionId', 'metadata_beginLifeSpanVersion',
#        'metadata_statusCode', 'metadata_observationStatus',
#        'metadata_statements', 'UID'],
#       dtype='object')

# %%
aggregated_df_raw.head()
# Out:
#   countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0          AL                      AL1       eionetMonitoringSiteCode
# 1          AL                      AL1       eionetMonitoringSiteCode
# 2          AL                      AL1       eionetMonitoringSiteCode
# 3          AL                      AL1       eionetMonitoringSiteCode
# 4          AL                      AL1       eionetMonitoringSiteCode
#
#   parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                         LW                  CAS_14265-44-2
# 1                         LW                  CAS_14265-44-2
# 2                         LW                  CAS_14265-44-2
# 3                         LW                  CAS_14265-44-2
# 4                         LW                  CAS_14797-55-8
#
#   observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 0                        Phosphate                       W    mg{P}/L
# 1                        Phosphate                       W    mg{P}/L
# 2                        Phosphate                       W    mg{P}/L
# 3                        Phosphate                       W    mg{P}/L
# 4                          Nitrate                       W  mg{NO3}/L
#
#    phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 0                         2004        2004-01--2004-12  ...
# 1                         2005        2005-01--2005-12  ...
# 2                         2006        2006-01--2006-12  ...
# 3                         2007        2007-01--2007-12  ...
# 4                         2005        2005-01--2005-12  ...
#
#    procedureAnalyticalMethod  parameterSampleDepth  resultObservationStatus  \
# 0                        NaN               -9999.0                      NaN
# 1                        NaN               -9999.0                      NaN
# 2                        NaN               -9999.0                      NaN
# 3                        NaN               -9999.0                      NaN
# 4                        NaN               -9999.0                      NaN
#
#   remarks                                 metadata_versionId  \
# 0     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
# 1     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
# 2     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
# 3     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4     NaN  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#   metadata_beginLifeSpanVersion  metadata_statusCode  \
# 0       2015-11-30 00:00:00.000         experimental
# 1       2015-11-30 00:00:00.000         experimental
# 2       2015-11-30 00:00:00.000         experimental
# 3       2015-11-30 00:00:00.000         experimental
# 4       2015-11-30 00:00:00.000         experimental
#
#   metadata_observationStatus  metadata_statements UID
# 0                          A                  NaN   1
# 1                          A                  NaN   2
# 2                          A                  NaN   3
# 3                          A                  NaN   4
# 4                          A                  NaN   5
#
# [5 rows x 32 columns]

# %%
aggregated_df_raw['resultObservationStatus'].unique() # nan, 'A', 'O'
aggregated_df_raw['metadata_statusCode'].unique() # 'experimental', 'valid', 'stable'
aggregated_df_raw['metadata_observationStatus'].unique() # 'A', 'U'
aggregated_df_raw['metadata_statements'].unique() # 
aggregated_df_raw['remarks'].unique() # 
aggregated_df_raw['procedureAnalyticalMethod'].unique() #
# Out:
# array([nan, 'ISO 7890-3 : 2000', 'EN 26777:1993', ...,
#        'APAT CNR IRSA 9020 Man 29 2005',
#        'APAT CNR IRSA 4110 A2 Man 29 2015',
#        'APAT CNR IRSA 4110 A2 Man 29 2006'], dtype=object)

# %%
aggregated_df_raw[~(aggregated_df_raw['remarks'].isna())]
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 168              BA                     BAB3       eionetMonitoringSiteCode
# 170              BA                     BAB3       eionetMonitoringSiteCode
# 172              BA                     BAB3       eionetMonitoringSiteCode
# 173              BA                     BAB3       eionetMonitoringSiteCode
# 174              BA                     BAB3       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4550544          RO               RO144300_3           euMonitoringSiteCode
# 4550548          RO                  RO85010           euMonitoringSiteCode
# 4550549          RO                  RO85010           euMonitoringSiteCode
# 4550554          RO                  RO85010           euMonitoringSiteCode
# 4550558          RO                  RO85010           euMonitoringSiteCode
#
#         parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 168                             LW                   CAS_7439-89-6
# 170                             LW                   CAS_7439-96-5
# 172                             LW                   CAS_7439-97-6
# 173                             LW                   CAS_7439-97-6
# 174                             LW                   CAS_7440-02-0
# ...                            ...                             ...
# 4550544                         RW                   CAS_7439-97-6
# 4550548                         RW                  CAS_14798-03-9
# 4550549                         RW                  CAS_14797-55-8
# 4550554                         RW                   CAS_7440-66-6
# 4550558                         RW                   EEA_3164-01-0
#
#         observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 168               Iron and its compounds                       W       ug/L
# 170          Manganese and its compounds                       W       ug/L
# 172            Mercury and its compounds                       W       ug/L
# 173            Mercury and its compounds                       W       ug/L
# 174             Nickel and its compounds                       W       ug/L
# ...                                  ...                     ...        ...
# 4550544        Mercury and its compounds                   W-DIS       ug/L
# 4550548                         Ammonium                       W  mg{NH4}/L
# 4550549                          Nitrate                       W  mg{NO3}/L
# 4550554           Zinc and its compounds                   W-DIS       ug/L
# 4550558                    Chlorophyll a                       W       ug/L
#
#          phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 168                             2005        2005-01--2005-12  ...
# 170                             2005        2005-01--2005-12  ...
# 172                             2005        2005-01--2005-12  ...
# 173                             2006        2006-01--2006-12  ...
# 174                             2005        2005-01--2005-12  ...
# ...                              ...                     ...  ...
# 4550544                         2017  2017-01-01--2017-12-31  ...
# 4550548                         2017  2017-01-01--2017-12-31  ...
# 4550549                         2017  2017-01-01--2017-12-31  ...
# 4550554                         2017  2017-01-01--2017-12-31  ...
# 4550558                         2017  2017-01-01--2017-12-31  ...
#
#          procedureAnalyticalMethod  parameterSampleDepth  \
# 168                            NaN                 11.17
# 170                            NaN                 11.17
# 172                            NaN                 12.06
# 173                            NaN                  9.56
# 174                            NaN                 11.17
# ...                            ...                   ...
# 4550544    Other analytical method                  0.00
# 4550548    Other analytical method                  0.00
# 4550549    Other analytical method                  0.00
# 4550554    Other analytical method                  0.00
# 4550558    Other analytical method                  0.00
#
#          resultObservationStatus  \
# 168                          NaN
# 170                          NaN
# 172                          NaN
# 173                          NaN
# 174                          NaN
# ...                          ...
# 4550544                      NaN
# 4550548                      NaN
# 4550549                      NaN
# 4550554                      NaN
# 4550558                      NaN
#
#                                                    remarks  \
# 168      0-1m,1-7m,7-bottom,0-2m,19-bottom,10-bottom,0-...
# 170      0-1m,1-7m,7-bottom,0-2m,19-bottom,10-bottom,0-...
# 172      0-1m,7-bottom,0-2m,19-bottom,10-bottom,0-4m,17...
# 173             0-2,2-bottom,0-3,3-bottom,0-4,4-8,8-bottom
# 174      0-1m,1-7m,7-bottom,0-2m,19-bottom,10-bottom,0-...
# ...                                                    ...
# 4550544                                  EN ISO 17852:2006
# 4550548                                    ISO 7150-1:2001
# 4550549                                    ISO 7890-3:2000
# 4550554                                   EN ISO 8288:2001
# 4550558                                     ISO 10260:1996
#
#                                         metadata_versionId  \
# 168      http://discomap.eea.europa.eu/data/wisesoe/der...
# 170      http://discomap.eea.europa.eu/data/wisesoe/der...
# 172      http://discomap.eea.europa.eu/data/wisesoe/der...
# 173      http://discomap.eea.europa.eu/data/wisesoe/der...
# 174      http://discomap.eea.europa.eu/data/wisesoe/der...
# ...                                                    ...
# 4550544  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550548  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550549  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550554  http://discomap.eea.europa.eu/data/wisesoe/der...
# 4550558  http://discomap.eea.europa.eu/data/wisesoe/der...
#
#         metadata_beginLifeSpanVersion  metadata_statusCode  \
# 168           2015-11-30 00:00:00.000         experimental
# 170           2015-11-30 00:00:00.000         experimental
# 172           2015-11-30 00:00:00.000         experimental
# 173           2015-11-30 00:00:00.000         experimental
# 174           2015-11-30 00:00:00.000         experimental
# ...                               ...                  ...
# 4550544       2019-08-29 07:54:03.000         experimental
# 4550548       2019-08-29 07:54:03.000         experimental
# 4550549       2019-08-29 07:54:03.000         experimental
# 4550554       2019-08-29 07:54:03.000         experimental
# 4550558       2019-08-29 07:54:03.000         experimental
#
#         metadata_observationStatus  metadata_statements       UID
# 168                              A                  NaN      3755
# 170                              A                  NaN      3757
# 172                              A                  NaN      3759
# 173                              A                  NaN      3760
# 174                              A                  NaN      3761
# ...                            ...                  ...       ...
# 4550544                          A                  NaN  17834946
# 4550548                          A                  NaN  17834950
# 4550549                          A                  NaN  17834951
# 4550554                          A                  NaN  17834956
# 4550558                          A                  NaN  17834960
#
# [925531 rows x 32 columns]

# %%
aggregated = aggregated_df_raw.drop(['metadata_versionId', 'metadata_beginLifeSpanVersion', 'remarks',
                                     'procedureAnalyticalMethod', 'metadata_statusCode', 'metadata_observationStatus'],
                                      axis = 1)

# %%
aggregated = aggregated[aggregated['metadata_statements'].isna()]

# %%
aggregated['metadata_statements'].unique()
# Out:
# array([nan], dtype=object)

# %%
aggregated = aggregated.drop(['metadata_statements'],
                            axis = 1)

# %%
aggregated[aggregated['resultObservationStatus'] == 'O'] # The results are actually there
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 2610347          SK                 SKIDK002           euMonitoringSiteCode
# 2610348          SK                 SKIDK002           euMonitoringSiteCode
# 2610349          SK                 SKIDK003           euMonitoringSiteCode
# 2610350          SK                 SKIDK003           euMonitoringSiteCode
# 2610351          SK                 SKIDK005           euMonitoringSiteCode
# 2610352          SK                 SKIDK005           euMonitoringSiteCode
#
#         parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 2610347                         RW                   EEA_3133-05-9
# 2610348                         RW                   EEA_3133-05-9
# 2610349                         RW                   EEA_3133-05-9
# 2610350                         RW                   EEA_3133-05-9
# 2610351                         RW                   EEA_3133-05-9
# 2610352                         RW                   EEA_3133-05-9
#
#         observedPropertyDeterminandLabel procedureAnalysedMatrix resultUom  \
# 2610347   Dissolved organic carbon (DOC)                   W-DIS   mg{C}/L
# 2610348   Dissolved organic carbon (DOC)                   W-DIS   mg{C}/L
# 2610349   Dissolved organic carbon (DOC)                   W-DIS   mg{C}/L
# 2610350   Dissolved organic carbon (DOC)                   W-DIS   mg{C}/L
# 2610351   Dissolved organic carbon (DOC)                   W-DIS   mg{C}/L
# 2610352   Dissolved organic carbon (DOC)                   W-DIS   mg{C}/L
#
#          phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 2610347                         2013  2013-02-05--2013-12-03  ...
# 2610348                         2014  2014-02-12--2014-11-26  ...
# 2610349                         2013  2013-01-22--2013-12-03  ...
# 2610350                         2014  2014-01-21--2014-11-11  ...
# 2610351                         2013  2013-01-22--2013-12-03  ...
# 2610352                         2014  2014-01-21--2014-11-11  ...
#
#          resultQualityMeanBelowLOQ  resultMeanValue  \
# 2610347                      False         4.157500
# 2610348                      False         4.235833
# 2610349                      False         4.420833
# 2610350                      False         4.420000
# 2610351                      False         4.766667
# 2610352                      False         4.957143
#
#          resultQualityMaximumBelowLOQ resultMaximumValue  \
# 2610347                         False               4.96
# 2610348                         False               5.10
# 2610349                         False               5.98
# 2610350                         False               5.70
# 2610351                         False               5.70
# 2610352                         False               6.30
#
#          resultQualityMedianBelowLOQ resultMedianValue  \
# 2610347                        False             4.155
# 2610348                        False             4.350
# 2610349                        False             4.280
# 2610350                        False             4.300
# 2610351                        False             4.700
# 2610352                        False             5.000
#
#          resultStandardDeviationValue parameterSampleDepth  \
# 2610347                      0.493206                 0.25
# 2610348                      0.448506                 0.25
# 2610349                      0.831519                 0.25
# 2610350                      0.500511                 0.25
# 2610351                      0.516935                 0.25
# 2610352                      0.698687                 0.25
#
#          resultObservationStatus       UID
# 2610347                        O  11196309
# 2610348                        O  11196310
# 2610349                        O  11196311
# 2610350                        O  11196312
# 2610351                        O  11196313
# 2610352                        O  11196314
#
# [6 rows x 25 columns]

# %% [markdown]
# #### Null values

# %%
aggregated.isnull().sum()
# Out:
# countryCode                                   0
# monitoringSiteIdentifier                      0
# monitoringSiteIdentifierScheme                0
# parameterWaterBodyCategory                    0
# observedPropertyDeterminandCode               0
# observedPropertyDeterminandLabel              0
# procedureAnalysedMatrix                       0
# resultUom                                     0
# phenomenonTimeReferenceYear                   0
# parameterSamplingPeriod                   69786
# procedureLOQValue                       1437394
# resultNumberOfSamples                     62926
# resultQualityNumberOfSamplesBelowLOQ    1771224
# resultQualityMinimumBelowLOQ            1366688
# resultMinimumValue                        98666
# resultQualityMeanBelowLOQ               1364321
# resultMeanValue                              47
# resultQualityMaximumBelowLOQ            1365736
# resultMaximumValue                        97182
# resultQualityMedianBelowLOQ             2020003
# resultMedianValue                       1217190
# resultStandardDeviationValue            1079997
# parameterSampleDepth                          0
# resultObservationStatus                 3394720
# UID                                           0
# dtype: int64

# %%
aggregated[aggregated['resultMeanValue'].isna()] # Also the values in the column Median are null. Therefore those rows will be dropped.
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 1080603          IT                IT12-4_30       eionetMonitoringSiteCode
# 2096957          IT                IT12L3_44           euMonitoringSiteCode
# 2096958          IT                IT12L3_44           euMonitoringSiteCode
# 2097039          IT                IT12L3_44           euMonitoringSiteCode
# 2097053          IT                IT12L3_42           euMonitoringSiteCode
# 2097060          IT                IT12L3_57           euMonitoringSiteCode
# 2097068          IT                IT12L3_44           euMonitoringSiteCode
# 2097099          IT                IT12L4_26           euMonitoringSiteCode
# 2097118          IT                IT12L4_26           euMonitoringSiteCode
# 2097164          IT                IT12L4_26           euMonitoringSiteCode
# 2097173          IT                IT12L4_26           euMonitoringSiteCode
# 2097175          IT                IT12L4_27           euMonitoringSiteCode
# 2097180          IT                IT12L4_27           euMonitoringSiteCode
# 2097193          IT                IT12L4_26           euMonitoringSiteCode
# 2097200          IT                IT12L4_27           euMonitoringSiteCode
# 2100360          IT                IT12L3_39           euMonitoringSiteCode
# 2100471          IT                IT12L3_40           euMonitoringSiteCode
# 2106304          IT                IT12L3_42           euMonitoringSiteCode
# 2106331          IT                IT12L4_26           euMonitoringSiteCode
# 2106333          IT                IT12L4_27           euMonitoringSiteCode
# 2106341          IT                IT12L4_26           euMonitoringSiteCode
# 2106342          IT                IT12L4_26           euMonitoringSiteCode
# 2106514          IT                IT12L4_28           euMonitoringSiteCode
# 2106577          IT                IT12L4_29           euMonitoringSiteCode
# 2106578          IT                IT12L4_29           euMonitoringSiteCode
# 2106579          IT                IT12L4_29           euMonitoringSiteCode
# 2106580          IT                IT12L4_29           euMonitoringSiteCode
# 2106603          IT                IT12L4_29           euMonitoringSiteCode
# 2106646          IT                IT12L4_29           euMonitoringSiteCode
# 2106655          IT                IT12L4_28           euMonitoringSiteCode
# 2106716          IT                IT12L4_29           euMonitoringSiteCode
# 2106939          IT                IT12L4_29           euMonitoringSiteCode
# 2106940          IT                IT12L4_29           euMonitoringSiteCode
# 2106985          IT                IT12L5_34           euMonitoringSiteCode
# 2106995          IT                IT12L5_34           euMonitoringSiteCode
# 2107038          IT                IT12L5_34           euMonitoringSiteCode
# 2107039          IT                IT12L5_34           euMonitoringSiteCode
# 2107057          IT                IT12L5_34           euMonitoringSiteCode
# 2107067          IT                IT12L5_34           euMonitoringSiteCode
# 2107068          IT                IT12L5_34           euMonitoringSiteCode
# 3417549          IT             IT19RW09603A           euMonitoringSiteCode
# 3427428          IT              IT19RW09606           euMonitoringSiteCode
# 3427430          IT             IT19RW09603A           euMonitoringSiteCode
# 3428269          IT              IT19RW09609           euMonitoringSiteCode
# 3903693          IT                IT12L3_45           euMonitoringSiteCode
# 3903695          IT                IT12L3_45           euMonitoringSiteCode
# 3903696          IT                IT12L3_45           euMonitoringSiteCode
#
#         parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 1080603                         LW                  CAS_12002-48-1
# 2096957                         LW                  CAS_12002-48-1
# 2096958                         LW                  CAS_12002-48-1
# 2097039                         LW                  CAS_12002-48-1
# 2097053                         LW                  CAS_12002-48-1
# 2097060                         LW                  CAS_12002-48-1
# 2097068                         LW                  CAS_12002-48-1
# 2097099                         LW                     CAS_56-23-5
# 2097118                         LW                     CAS_56-23-5
# 2097164                         LW                  CAS_12002-48-1
# 2097173                         LW                     CAS_56-23-5
# 2097175                         LW                     CAS_56-23-5
# 2097180                         LW                  CAS_12002-48-1
# 2097193                         LW                     CAS_56-23-5
# 2097200                         LW                     CAS_56-23-5
# 2100360                         LW                  CAS_12002-48-1
# 2100471                         LW                     CAS_56-23-5
# 2106304                         LW                     CAS_56-23-5
# 2106331                         LW                  CAS_12002-48-1
# 2106333                         LW                  CAS_12002-48-1
# 2106341                         LW                     CAS_56-23-5
# 2106342                         LW                  CAS_12002-48-1
# 2106514                         LW                  CAS_12002-48-1
# 2106577                         LW                     CAS_56-23-5
# 2106578                         LW                     CAS_56-23-5
# 2106579                         LW                  CAS_12002-48-1
# 2106580                         LW                  CAS_12002-48-1
# 2106603                         LW                  CAS_12002-48-1
# 2106646                         LW                     CAS_56-23-5
# 2106655                         LW                     CAS_56-23-5
# 2106716                         LW                  CAS_12002-48-1
# 2106939                         LW                  CAS_12002-48-1
# 2106940                         LW                  CAS_12002-48-1
# 2106985                         LW                  CAS_12002-48-1
# 2106995                         LW                  CAS_12002-48-1
# 2107038                         LW                     CAS_56-23-5
# 2107039                         LW                     CAS_56-23-5
# 2107057                         LW                  CAS_12002-48-1
# 2107067                         LW                  CAS_12002-48-1
# 2107068                         LW                  CAS_12002-48-1
# 3417549                         RW                  CAS_14797-65-0
# 3427428                         RW                  CAS_14798-03-9
# 3427430                         RW                  CAS_14798-03-9
# 3428269                         RW                  CAS_14798-03-9
# 3903693                         LW                  CAS_12002-48-1
# 3903695                         LW                  CAS_12002-48-1
# 3903696                         LW                  CAS_12002-48-1
#
#         observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 1080603  Trichlorobenzenes (all isomers)                       W       ug/L
# 2096957  Trichlorobenzenes (all isomers)                       W       ug/L
# 2096958  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097039  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097053  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097060  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097068  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097099             Carbon tetrachloride                       W       ug/L
# 2097118             Carbon tetrachloride                       W       ug/L
# 2097164  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097173             Carbon tetrachloride                       W       ug/L
# 2097175             Carbon tetrachloride                       W       ug/L
# 2097180  Trichlorobenzenes (all isomers)                       W       ug/L
# 2097193             Carbon tetrachloride                       W       ug/L
# 2097200             Carbon tetrachloride                       W       ug/L
# 2100360  Trichlorobenzenes (all isomers)                       W       ug/L
# 2100471             Carbon tetrachloride                       W       ug/L
# 2106304             Carbon tetrachloride                       W       ug/L
# 2106331  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106333  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106341             Carbon tetrachloride                       W       ug/L
# 2106342  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106514  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106577             Carbon tetrachloride                       W       ug/L
# 2106578             Carbon tetrachloride                       W       ug/L
# 2106579  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106580  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106603  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106646             Carbon tetrachloride                       W       ug/L
# 2106655             Carbon tetrachloride                       W       ug/L
# 2106716  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106939  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106940  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106985  Trichlorobenzenes (all isomers)                       W       ug/L
# 2106995  Trichlorobenzenes (all isomers)                       W       ug/L
# 2107038             Carbon tetrachloride                       W       ug/L
# 2107039             Carbon tetrachloride                       W       ug/L
# 2107057  Trichlorobenzenes (all isomers)                       W       ug/L
# 2107067  Trichlorobenzenes (all isomers)                       W       ug/L
# 2107068  Trichlorobenzenes (all isomers)                       W       ug/L
# 3417549                          Nitrite                       W  mg{NO2}/L
# 3427428                         Ammonium                       W  mg{NH4}/L
# 3427430                         Ammonium                       W  mg{NH4}/L
# 3428269                         Ammonium                       W  mg{NH4}/L
# 3903693  Trichlorobenzenes (all isomers)                       W       ug/L
# 3903695  Trichlorobenzenes (all isomers)                       W       ug/L
# 3903696  Trichlorobenzenes (all isomers)                       W       ug/L
#
#          phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 1080603                         2010        2010-01--2010-12  ...
# 2096957                         2010        2010-01--2010-12  ...
# 2096958                         2010        2010-01--2010-12  ...
# 2097039                         2010        2010-01--2010-12  ...
# 2097053                         2010        2010-01--2010-12  ...
# 2097060                         2010        2010-01--2010-12  ...
# 2097068                         2010        2010-01--2010-12  ...
# 2097099                         2010        2010-01--2010-12  ...
# 2097118                         2010        2010-01--2010-12  ...
# 2097164                         2010        2010-01--2010-12  ...
# 2097173                         2010        2010-01--2010-12  ...
# 2097175                         2010        2010-01--2010-12  ...
# 2097180                         2010        2010-01--2010-12  ...
# 2097193                         2010        2010-01--2010-12  ...
# 2097200                         2010        2010-01--2010-12  ...
# 2100360                         2010        2010-01--2010-12  ...
# 2100471                         2010        2010-01--2010-12  ...
# 2106304                         2010        2010-01--2010-12  ...
# 2106331                         2010        2010-01--2010-12  ...
# 2106333                         2010        2010-01--2010-12  ...
# 2106341                         2010        2010-01--2010-12  ...
# 2106342                         2010        2010-01--2010-12  ...
# 2106514                         2010        2010-01--2010-12  ...
# 2106577                         2010        2010-01--2010-12  ...
# 2106578                         2010        2010-01--2010-12  ...
# 2106579                         2010        2010-01--2010-12  ...
# 2106580                         2010        2010-01--2010-12  ...
# 2106603                         2010        2010-01--2010-12  ...
# 2106646                         2010        2010-01--2010-12  ...
# 2106655                         2010        2010-01--2010-12  ...
# 2106716                         2010        2010-01--2010-12  ...
# 2106939                         2010        2010-01--2010-12  ...
# 2106940                         2010        2010-01--2010-12  ...
# 2106985                         2010        2010-01--2010-12  ...
# 2106995                         2010        2010-01--2010-12  ...
# 2107038                         2010        2010-01--2010-12  ...
# 2107039                         2010        2010-01--2010-12  ...
# 2107057                         2010        2010-01--2010-12  ...
# 2107067                         2010        2010-01--2010-12  ...
# 2107068                         2010        2010-01--2010-12  ...
# 3417549                         2011        2011-01--2011-12  ...
# 3427428                         2011        2011-01--2011-12  ...
# 3427430                         2011        2011-01--2011-12  ...
# 3428269                         2011        2011-01--2011-12  ...
# 3903693                         2010        2010-01--2010-12  ...
# 3903695                         2010        2010-01--2010-12  ...
# 3903696                         2010        2010-01--2010-12  ...
#
#          resultQualityMeanBelowLOQ  resultMeanValue  \
# 1080603                        NaN              NaN
# 2096957                        NaN              NaN
# 2096958                        NaN              NaN
# 2097039                        NaN              NaN
# 2097053                        NaN              NaN
# 2097060                        NaN              NaN
# 2097068                        NaN              NaN
# 2097099                        NaN              NaN
# 2097118                        NaN              NaN
# 2097164                        NaN              NaN
# 2097173                        NaN              NaN
# 2097175                        NaN              NaN
# 2097180                        NaN              NaN
# 2097193                        NaN              NaN
# 2097200                        NaN              NaN
# 2100360                        NaN              NaN
# 2100471                        NaN              NaN
# 2106304                        NaN              NaN
# 2106331                        NaN              NaN
# 2106333                        NaN              NaN
# 2106341                        NaN              NaN
# 2106342                        NaN              NaN
# 2106514                        NaN              NaN
# 2106577                        NaN              NaN
# 2106578                        NaN              NaN
# 2106579                        NaN              NaN
# 2106580                        NaN              NaN
# 2106603                        NaN              NaN
# 2106646                        NaN              NaN
# 2106655                        NaN              NaN
# 2106716                        NaN              NaN
# 2106939                        NaN              NaN
# 2106940                        NaN              NaN
# 2106985                        NaN              NaN
# 2106995                        NaN              NaN
# 2107038                        NaN              NaN
# 2107039                        NaN              NaN
# 2107057                        NaN              NaN
# 2107067                        NaN              NaN
# 2107068                        NaN              NaN
# 3417549                        NaN              NaN
# 3427428                        NaN              NaN
# 3427430                        NaN              NaN
# 3428269                        NaN              NaN
# 3903693                        NaN              NaN
# 3903695                        NaN              NaN
# 3903696                        NaN              NaN
#
#          resultQualityMaximumBelowLOQ resultMaximumValue  \
# 1080603                           NaN                NaN
# 2096957                           NaN                NaN
# 2096958                           NaN                NaN
# 2097039                           NaN                NaN
# 2097053                           NaN                NaN
# 2097060                           NaN                NaN
# 2097068                           NaN                NaN
# 2097099                           NaN                NaN
# 2097118                           NaN                NaN
# 2097164                           NaN                NaN
# 2097173                           NaN                NaN
# 2097175                           NaN                NaN
# 2097180                           NaN                NaN
# 2097193                           NaN                NaN
# 2097200                           NaN                NaN
# 2100360                           NaN                NaN
# 2100471                           NaN                NaN
# 2106304                           NaN                NaN
# 2106331                           NaN                NaN
# 2106333                           NaN                NaN
# 2106341                           NaN                NaN
# 2106342                           NaN                NaN
# 2106514                           NaN                NaN
# 2106577                           NaN                NaN
# 2106578                           NaN                NaN
# 2106579                           NaN                NaN
# 2106580                           NaN                NaN
# 2106603                           NaN                NaN
# 2106646                           NaN                NaN
# 2106655                           NaN                NaN
# 2106716                           NaN                NaN
# 2106939                           NaN                NaN
# 2106940                           NaN                NaN
# 2106985                           NaN                NaN
# 2106995                           NaN                NaN
# 2107038                           NaN                NaN
# 2107039                           NaN                NaN
# 2107057                           NaN                NaN
# 2107067                           NaN                NaN
# 2107068                           NaN                NaN
# 3417549                           NaN                NaN
# 3427428                           NaN                NaN
# 3427430                           NaN                NaN
# 3428269                           NaN                NaN
# 3903693                           NaN                NaN
# 3903695                           NaN                NaN
# 3903696                           NaN                NaN
#
#          resultQualityMedianBelowLOQ resultMedianValue  \
# 1080603                          NaN               NaN
# 2096957                          NaN               NaN
# 2096958                          NaN               NaN
# 2097039                          NaN               NaN
# 2097053                          NaN               NaN
# 2097060                          NaN               NaN
# 2097068                          NaN               NaN
# 2097099                          NaN               NaN
# 2097118                          NaN               NaN
# 2097164                          NaN               NaN
# 2097173                          NaN               NaN
# 2097175                          NaN               NaN
# 2097180                          NaN               NaN
# 2097193                          NaN               NaN
# 2097200                          NaN               NaN
# 2100360                          NaN               NaN
# 2100471                          NaN               NaN
# 2106304                          NaN               NaN
# 2106331                          NaN               NaN
# 2106333                          NaN               NaN
# 2106341                          NaN               NaN
# 2106342                          NaN               NaN
# 2106514                          NaN               NaN
# 2106577                          NaN               NaN
# 2106578                          NaN               NaN
# 2106579                          NaN               NaN
# 2106580                          NaN               NaN
# 2106603                          NaN               NaN
# 2106646                          NaN               NaN
# 2106655                          NaN               NaN
# 2106716                          NaN               NaN
# 2106939                          NaN               NaN
# 2106940                          NaN               NaN
# 2106985                          NaN               NaN
# 2106995                          NaN               NaN
# 2107038                          NaN               NaN
# 2107039                          NaN               NaN
# 2107057                          NaN               NaN
# 2107067                          NaN               NaN
# 2107068                          NaN               NaN
# 3417549                          NaN               NaN
# 3427428                          NaN               NaN
# 3427430                          NaN               NaN
# 3428269                          NaN               NaN
# 3903693                          NaN               NaN
# 3903695                          NaN               NaN
# 3903696                          NaN               NaN
#
#          resultStandardDeviationValue parameterSampleDepth  \
# 1080603                           NaN                 25.0
# 2096957                           NaN                 26.0
# 2096958                           NaN                 55.0
# 2097039                           NaN                 50.0
# 2097053                           NaN                 30.0
# 2097060                           NaN                  0.3
# 2097068                           NaN                 25.0
# 2097099                           NaN                  0.2
# 2097118                           NaN                 50.0
# 2097164                           NaN                  0.2
# 2097173                           NaN                160.0
# 2097175                           NaN                 25.0
# 2097180                           NaN                 25.0
# 2097193                           NaN                 25.0
# 2097200                           NaN                  0.2
# 2100360                           NaN                  4.3
# 2100471                           NaN                  4.0
# 2106304                           NaN                 30.0
# 2106331                           NaN                 25.0
# 2106333                           NaN                  0.2
# 2106341                           NaN                100.0
# 2106342                           NaN                 50.0
# 2106514                           NaN                  0.2
# 2106577                           NaN                  0.2
# 2106578                           NaN                100.0
# 2106579                           NaN                100.0
# 2106580                           NaN                130.0
# 2106603                           NaN                160.0
# 2106646                           NaN                 50.0
# 2106655                           NaN                  0.2
# 2106716                           NaN                 50.0
# 2106939                           NaN                  0.2
# 2106940                           NaN                 25.0
# 2106985                           NaN                 10.0
# 2106995                           NaN                  0.5
# 2107038                           NaN                  0.5
# 2107039                           NaN                  5.0
# 2107057                           NaN                 20.0
# 2107067                           NaN                  5.0
# 2107068                           NaN                120.0
# 3417549                           NaN                  0.0
# 3427428                           NaN                  0.0
# 3427430                           NaN                  0.0
# 3428269                           NaN                  0.0
# 3903693                           NaN                 43.0
# 3903695                           NaN                 25.0
# 3903696                           NaN                 21.0
#
#          resultObservationStatus       UID
# 1080603                      NaN   9257422
# 2096957                      NaN  10624804
# 2096958                      NaN  10624805
# 2097039                      NaN  10624886
# 2097053                      NaN  10624900
# 2097060                      NaN  10624907
# 2097068                      NaN  10624915
# 2097099                      NaN  10624946
# 2097118                      NaN  10624965
# 2097164                      NaN  10625011
# 2097173                      NaN  10625020
# 2097175                      NaN  10625022
# 2097180                      NaN  10625027
# 2097193                      NaN  10625040
# 2097200                      NaN  10625047
# 2100360                      NaN  10628207
# 2100471                      NaN  10628318
# 2106304                      NaN  10634642
# 2106331                      NaN  10634669
# 2106333                      NaN  10634671
# 2106341                      NaN  10634679
# 2106342                      NaN  10634680
# 2106514                      NaN  10634852
# 2106577                      NaN  10634915
# 2106578                      NaN  10634916
# 2106579                      NaN  10634917
# 2106580                      NaN  10634918
# 2106603                      NaN  10634941
# 2106646                      NaN  10634984
# 2106655                      NaN  10634993
# 2106716                      NaN  10635054
# 2106939                      NaN  10635277
# 2106940                      NaN  10635278
# 2106985                      NaN  10635323
# 2106995                      NaN  10635333
# 2107038                      NaN  10635376
# 2107039                      NaN  10635377
# 2107057                      NaN  10635395
# 2107067                      NaN  10635405
# 2107068                      NaN  10635406
# 3417549                      NaN  12247842
# 3427428                      NaN  12257721
# 3427430                      NaN  12257723
# 3428269                      NaN  12258562
# 3903693                      NaN  14620994
# 3903695                      NaN  14620996
# 3903696                      NaN  14620997
#
# [47 rows x 25 columns]

# %%
aggregated = aggregated.dropna(subset = ['resultMeanValue'], axis = 0)

# %%
aggregated['parameterSamplingPeriod'] = np.where(aggregated['parameterSamplingPeriod'].isna(),
                                                aggregated['phenomenonTimeReferenceYear'],
                                                aggregated['parameterSamplingPeriod'])

# %%
aggregated.isnull().sum()
# Out:
# countryCode                                   0
# monitoringSiteIdentifier                      0
# monitoringSiteIdentifierScheme                0
# parameterWaterBodyCategory                    0
# observedPropertyDeterminandCode               0
# observedPropertyDeterminandLabel              0
# procedureAnalysedMatrix                       0
# resultUom                                     0
# phenomenonTimeReferenceYear                   0
# parameterSamplingPeriod                       0
# procedureLOQValue                       1437351
# resultNumberOfSamples                     62883
# resultQualityNumberOfSamplesBelowLOQ    1771177
# resultQualityMinimumBelowLOQ            1366641
# resultMinimumValue                        98619
# resultQualityMeanBelowLOQ               1364274
# resultMeanValue                               0
# resultQualityMaximumBelowLOQ            1365689
# resultMaximumValue                        97135
# resultQualityMedianBelowLOQ             2019956
# resultMedianValue                       1217143
# resultStandardDeviationValue            1079950
# parameterSampleDepth                          0
# resultObservationStatus                 3394673
# UID                                           0
# dtype: int64

# %% [markdown]
# #### Duplicates

# %%
aggregated[aggregated.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [countryCode, monitoringSiteIdentifier, monitoringSiteIdentifierScheme, parameterWaterBodyCategory, observedPropertyDeterminandCode, observedPropertyDeterminandLabel, procedureAnalysedMatrix, resultUom, phenomenonTimeReferenceYear, parameterSamplingPeriod, procedureLOQValue, resultNumberOfSamples, resultQualityNumberOfSamplesBelowLOQ, resultQualityMinimumBelowLOQ, resultMinimumValue, resultQualityMeanBelowLOQ, resultMeanValue, resultQualityMaximumBelowLOQ, resultMaximumValue, resultQualityMedianBelowLOQ, resultMedianValue, resultStandardDeviationValue, parameterSampleDepth, resultObservationStatus, UID]
# Index: []
#
# [0 rows x 25 columns]

# %%
aggregated[['parameterSamplingPeriodStart', 'parameterSamplingPeriodEnd']] = aggregated['parameterSamplingPeriod'].str.split('--',
                                                                                                                            expand = True)

# %%
aggregated[aggregated['parameterSamplingPeriodStart'].isna()]
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 1854952          EE             EESJA9303000       eionetMonitoringSiteCode
# 1854954          EE             EESJA9303000       eionetMonitoringSiteCode
# 1854955          EE             EESJA9303000       eionetMonitoringSiteCode
# 1854956          EE             EESJA9303000       eionetMonitoringSiteCode
# 1854957          EE             EESJA9303000       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4473134          DK                 DK620014       eionetMonitoringSiteCode
# 4473135          DK                 DK660014           euMonitoringSiteCode
# 4473136          DK                 DK660014           euMonitoringSiteCode
# 4473137          DK                 DK660014           euMonitoringSiteCode
# 4473138          DK                 DK660014           euMonitoringSiteCode
#
#         parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 1854952                         RW                  CAS_14265-44-2
# 1854954                         RW                  CAS_14797-65-0
# 1854955                         RW                  CAS_14798-03-9
# 1854956                         RW                   CAS_7439-92-1
# 1854957                         RW                   CAS_7440-02-0
# ...                            ...                             ...
# 4473134                         RW                   CAS_7723-14-0
# 4473135                         RW                   EEA_3161-02-2
# 4473136                         RW                  EEA_31615-01-7
# 4473137                         RW                  CAS_14265-44-2
# 4473138                         RW                   CAS_7723-14-0
#
#         observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 1854952                        Phosphate                       W    mg{P}/L
# 1854954                          Nitrite                       W  mg{NO2}/L
# 1854955                         Ammonium                       W  mg{NH4}/L
# 1854956           Lead and its compounds                   W-DIS       ug/L
# 1854957         Nickel and its compounds                   W-DIS       ug/L
# ...                                  ...                     ...        ...
# 4473134                 Total phosphorus                       W    mg{P}/L
# 4473135          Total oxidised nitrogen                   W-DIS    mg{N}/L
# 4473136                   Total nitrogen                       W    mg{N}/L
# 4473137                        Phosphate                   W-DIS    mg{P}/L
# 4473138                 Total phosphorus                       W    mg{P}/L
#
#          phenomenonTimeReferenceYear parameterSamplingPeriod  ...  \
# 1854952                         2013                    2013  ...
# 1854954                         2013                    2013  ...
# 1854955                         2013                    2013  ...
# 1854956                         2013                    2013  ...
# 1854957                         2013                    2013  ...
# ...                              ...                     ...  ...
# 4473134                         2020                    2020  ...
# 4473135                         2020                    2020  ...
# 4473136                         2020                    2020  ...
# 4473137                         2020                    2020  ...
# 4473138                         2020                    2020  ...
#
#          resultQualityMaximumBelowLOQ  resultMaximumValue  \
# 1854952                         False               0.007
# 1854954                          True               0.002
# 1854955                          True               0.010
# 1854956                         False               0.540
# 1854957                         False               2.300
# ...                               ...                 ...
# 4473134                         False               0.210
# 4473135                         False               9.800
# 4473136                         False              12.000
# 4473137                         False               0.200
# 4473138                         False               0.230
#
#          resultQualityMedianBelowLOQ resultMedianValue  \
# 1854952                         True            0.0050
# 1854954                         True            0.0020
# 1854955                         True            0.0100
# 1854956                         True            0.1000
# 1854957                        False            0.2000
# ...                              ...               ...
# 4473134                        False            0.0595
# 4473135                        False            2.0000
# 4473136                        False            2.2000
# 4473137                        False            0.1100
# 4473138                        False            0.1600
#
#          resultStandardDeviationValue parameterSampleDepth  \
# 1854952                           NaN              -9999.0
# 1854954                           NaN              -9999.0
# 1854955                           NaN              -9999.0
# 1854956                           NaN              -9999.0
# 1854957                           NaN              -9999.0
# ...                               ...                  ...
# 4473134                      0.048317                  0.0
# 4473135                      3.145656                  0.0
# 4473136                      3.538933                  0.0
# 4473137                      0.057543                  0.0
# 4473138                      0.058962                  0.0
#
#          resultObservationStatus       UID  parameterSamplingPeriodStart  \
# 1854952                      NaN  10367820                           NaN
# 1854954                      NaN  10367822                           NaN
# 1854955                      NaN  10367823                           NaN
# 1854956                      NaN  10367824                           NaN
# 1854957                      NaN  10367825                           NaN
# ...                          ...       ...                           ...
# 4473134                      NaN  17752178                           NaN
# 4473135                      NaN  17752179                           NaN
# 4473136                      NaN  17752180                           NaN
# 4473137                      NaN  17752181                           NaN
# 4473138                      NaN  17752182                           NaN
#
#         parameterSamplingPeriodEnd
# 1854952                        NaN
# 1854954                        NaN
# 1854955                        NaN
# 1854956                        NaN
# 1854957                        NaN
# ...                            ...
# 4473134                        NaN
# 4473135                        NaN
# 4473136                        NaN
# 4473137                        NaN
# 4473138                        NaN
#
# [69786 rows x 27 columns]

# %%
aggregated['parameterSamplingPeriodStart'] = np.where(aggregated['parameterSamplingPeriodStart'].isna(),
                                                     aggregated['phenomenonTimeReferenceYear'],
                                                     aggregated['parameterSamplingPeriodStart'])

# %%
aggregated['parameterSamplingPeriodStart'].isna().sum()
# Out:
# 0

# %%
aggregated['parameterSamplingPeriodEnd'] = np.where(aggregated['parameterSamplingPeriodEnd'].isna(),
                                                   aggregated['phenomenonTimeReferenceYear'],
                                                   aggregated['parameterSamplingPeriodEnd'])

# %%
aggregated['parameterSamplingPeriodEnd'].isna().sum()
# Out:
# 0

# %%
aggregated = aggregated.drop(['parameterSamplingPeriod', 'resultObservationStatus', 'parameterSampleDepth'],
                            axis = 1)

# %% [markdown]
# #### Filter to only River and Lake waters (RW, LW)

# %%
aggregated_rw_lw = aggregated[(aggregated['parameterWaterBodyCategory'] == 'RW') |
                              (aggregated['parameterWaterBodyCategory'] == 'LW')]

# %%
aggregated_rw_lw
# Out:
#         countryCode monitoringSiteIdentifier monitoringSiteIdentifierScheme  \
# 0                AL                      AL1       eionetMonitoringSiteCode
# 1                AL                      AL1       eionetMonitoringSiteCode
# 2                AL                      AL1       eionetMonitoringSiteCode
# 3                AL                      AL1       eionetMonitoringSiteCode
# 4                AL                      AL1       eionetMonitoringSiteCode
# ...             ...                      ...                            ...
# 4550554          RO                  RO85010           euMonitoringSiteCode
# 4550555          RO                  RO85010           euMonitoringSiteCode
# 4550556          RO                  RO85010           euMonitoringSiteCode
# 4550557          RO                  RO85010           euMonitoringSiteCode
# 4550558          RO                  RO85010           euMonitoringSiteCode
#
#         parameterWaterBodyCategory observedPropertyDeterminandCode  \
# 0                               LW                  CAS_14265-44-2
# 1                               LW                  CAS_14265-44-2
# 2                               LW                  CAS_14265-44-2
# 3                               LW                  CAS_14265-44-2
# 4                               LW                  CAS_14797-55-8
# ...                            ...                             ...
# 4550554                         RW                   CAS_7440-66-6
# 4550555                         RW                   CAS_7440-47-3
# 4550556                         RW                   CAS_7440-38-2
# 4550557                         RW                     EEA_31-02-7
# 4550558                         RW                   EEA_3164-01-0
#
#         observedPropertyDeterminandLabel procedureAnalysedMatrix  resultUom  \
# 0                              Phosphate                       W    mg{P}/L
# 1                              Phosphate                       W    mg{P}/L
# 2                              Phosphate                       W    mg{P}/L
# 3                              Phosphate                       W    mg{P}/L
# 4                                Nitrate                       W  mg{NO3}/L
# ...                                  ...                     ...        ...
# 4550554           Zinc and its compounds                   W-DIS       ug/L
# 4550555       Chromium and its compounds                   W-DIS       ug/L
# 4550556        Arsenic and its compounds                   W-DIS       ug/L
# 4550557           Total suspended solids                       W       mg/L
# 4550558                    Chlorophyll a                       W       ug/L
#
#          phenomenonTimeReferenceYear  procedureLOQValue  ...  \
# 0                               2004                NaN  ...
# 1                               2005                NaN  ...
# 2                               2006            0.00163  ...
# 3                               2007            0.00163  ...
# 4                               2005                NaN  ...
# ...                              ...                ...  ...
# 4550554                         2017           50.00000  ...
# 4550555                         2017            1.00000  ...
# 4550556                         2017            0.10000  ...
# 4550557                         2017           10.00000  ...
# 4550558                         2017            1.18000  ...
#
#          resultQualityMeanBelowLOQ  resultMeanValue  \
# 0                              NaN         0.001956
# 1                              NaN         0.033000
# 2                            False         0.014861
# 3                            False         0.014250
# 4                              NaN         0.442700
# ...                            ...              ...
# 4550554                       True        50.000000
# 4550555                       True         1.000000
# 4550556                      False         1.347500
# 4550557                      False        17.500000
# 4550558                      False        14.880000
#
#         resultQualityMaximumBelowLOQ  resultMaximumValue  \
# 0                                NaN            0.002608
# 1                                NaN            0.052000
# 2                              False            0.020294
# 3                              False            0.017118
# 4                                NaN            0.752590
# ...                              ...                 ...
# 4550554                         True           50.000000
# 4550555                         True            1.000000
# 4550556                        False            2.920000
# 4550557                        False           26.000000
# 4550558                        False           26.220000
#
#         resultQualityMedianBelowLOQ  resultMedianValue  \
# 0                               NaN           0.001956
# 1                               NaN           0.030000
# 2                             False           0.015324
# 3                             False           0.013912
# 4                               NaN           0.442700
# ...                             ...                ...
# 4550554                        True          50.000000
# 4550555                        True           1.000000
# 4550556                       False           1.135000
# 4550557                       False          15.500000
# 4550558                       False          14.670000
#
#         resultStandardDeviationValue       UID parameterSamplingPeriodStart  \
# 0                                NaN         1                      2004-01
# 1                           0.016050         2                      2005-01
# 2                           0.005802         3                      2006-01
# 3                           0.002409         4                      2007-01
# 4                           0.101800         5                      2005-01
# ...                              ...       ...                          ...
# 4550554                     0.000000  17834956                   2017-01-01
# 4550555                     0.000000  17834957                   2017-01-01
# 4550556                     1.153296  17834958                   2017-01-01
# 4550557                     6.137318  17834959                   2017-01-01
# 4550558                    11.290264  17834960                   2017-01-01
#
#          parameterSamplingPeriodEnd
# 0                           2004-12
# 1                           2005-12
# 2                           2006-12
# 3                           2007-12
# 4                           2005-12
# ...                             ...
# 4550554                  2017-12-31
# 4550555                  2017-12-31
# 4550556                  2017-12-31
# 4550557                  2017-12-31
# 4550558                  2017-12-31
#
# [3549404 rows x 24 columns]

# %%
aggregated_rw_lw['parameterSamplingPeriodStart'] = pd.to_datetime(aggregated_rw_lw['parameterSamplingPeriodStart']) #, format="Y%/m%/d%"
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\3032630185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aggregated_rw_lw['parameterSamplingPeriodStart'] = pd.to_datetime(aggregated_rw_lw['parameterSamplingPeriodStart']) #, format="Y%/m%/d%"

# %%
aggregated_rw_lw['parameterSamplingPeriodEnd'] = pd.to_datetime(aggregated_rw_lw['parameterSamplingPeriodEnd'])
# Out:
# C:\Users\elisa\AppData\Local\Temp\ipykernel_23448\3778761955.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   aggregated_rw_lw['parameterSamplingPeriodEnd'] = pd.to_datetime(aggregated_rw_lw['parameterSamplingPeriodEnd'])

# %%
len(aggregated_rw_lw['UID'].unique()) # Primary key
# Out:
# 3549404

# %%
aggregated_rw_lw.columns
# Out:
# Index(['countryCode', 'monitoringSiteIdentifier',
#        'monitoringSiteIdentifierScheme', 'parameterWaterBodyCategory',
#        'observedPropertyDeterminandCode', 'observedPropertyDeterminandLabel',
#        'procedureAnalysedMatrix', 'resultUom', 'phenomenonTimeReferenceYear',
#        'procedureLOQValue', 'resultNumberOfSamples',
#        'resultQualityNumberOfSamplesBelowLOQ', 'resultQualityMinimumBelowLOQ',
#        'resultMinimumValue', 'resultQualityMeanBelowLOQ', 'resultMeanValue',
#        'resultQualityMaximumBelowLOQ', 'resultMaximumValue',
#        'resultQualityMedianBelowLOQ', 'resultMedianValue',
#        'resultStandardDeviationValue', 'UID', 'parameterSamplingPeriodStart',
#        'parameterSamplingPeriodEnd'],
#       dtype='object')

# %%
aggregated_rw_lw.shape
# Out:
# (3549404, 24)

# %%
aggregated_rw_lw = aggregated_rw_lw.fillna(0)

# %%
aggregated_rw_lw.isnull().sum()
# Out:
# countryCode                             0
# monitoringSiteIdentifier                0
# monitoringSiteIdentifierScheme          0
# parameterWaterBodyCategory              0
# observedPropertyDeterminandCode         0
# observedPropertyDeterminandLabel        0
# procedureAnalysedMatrix                 0
# resultUom                               0
# phenomenonTimeReferenceYear             0
# procedureLOQValue                       0
# resultNumberOfSamples                   0
# resultQualityNumberOfSamplesBelowLOQ    0
# resultQualityMinimumBelowLOQ            0
# resultMinimumValue                      0
# resultQualityMeanBelowLOQ               0
# resultMeanValue                         0
# resultQualityMaximumBelowLOQ            0
# resultMaximumValue                      0
# resultQualityMedianBelowLOQ             0
# resultMedianValue                       0
# resultStandardDeviationValue            0
# UID                                     0
# parameterSamplingPeriodStart            0
# parameterSamplingPeriodEnd              0
# dtype: int64

# %% [markdown]
# #### Save the cleaned dataset

# %%
aggregated.to_csv("Aggregated_cleaned.csv")

# %%
aggregated_rw_lw.to_csv("Aggregated_RW_LW_cleaned.csv")

# %% [markdown]
# <a id = 'SQL_connection'></a>
# ## 2. SQL Server connection
# [Top](#top)

# %%
# !pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\elisa\anaconda3\lib\site-packages (4.0.34)

# %%
import pyodbc

# %%
DRIVER = 'ODBC Driver 18  for SQL Server'
SERVER = 'DESKTOP-7D7TC79\SQLEXPRESS'
DATABASE = 'M7_Water_Quality_Analysis'
USERNAME = 'DESKTOP-7D7TC79\elisa'
PASSWORD = ''
TRUSTED_CONNECTION = 'yes'

# %%
connection_string = f'DRIVER={DRIVER};SERVER={SERVER};DATABASE={DATABASE};UID={USERNAME};PWD={PASSWORD};Trusted_Connection={TRUSTED_CONNECTION}'

# %%
connection_string = "DRIVER={ODBC Driver 18 for SQL Server};SERVER=DESKTOP-7D7TC79\SQLEXPRESS;DATABASE=M7_Water_Quality_Analysis;UID=DESKTOP-7D7TC79\elisa;TrustServerCertificate=True;PWD=''"

# %%
connection_string = (
                        r'DRIVER={ODBC Driver 18  for SQL Server};'
                        r'SERVER=DESKTOP-7D7TC79\SQLEXPRESS;'
                        r'DATABASE=M7_Water_Quality_Analysis;'
                        r'Trusted_Connection=yes;')

# %%
connection = pyodbc.connect(connection_string)

# %%
# Connection working:
connection = pyodbc.connect('DRIVER={SQL Server};'
                            'SERVER=DESKTOP-7D7TC79\SQLEXPRESS;'
                            'DATABASE=M7_Water_Quality_Analysis;'
                            'Trusted_Connection=yes;')

# %%
cursor = connection.cursor()

# %% [markdown]
# <a id = 'create_tables'></a>
# ### 2.1 Create tables in the SQL server database
# [Top](#top)

# %% [markdown]
# <a id = 'table_spatial'></a>
# #### 2.1.1 Create table with spatial data
# [Top](#top)

# %%
cursor.execute("""
                DROP TABLE IF EXISTS spatial_data;
                
                CREATE TABLE spatial_data (
                    ID INT PRIMARY KEY,
                    countryCode VARCHAR(600),
                    thematicIdIdentifier VARCHAR(600),
                    monitoringSiteIdentifier VARCHAR(600),
                    monitoringSiteIdentifierScheme VARCHAR(600),
                    monitoringSiteName VARCHAR(600),
                    waterBodyIdentifier VARCHAR(600),
                    waterBodyIdentifierScheme VARCHAR(600),
                    waterBodyName VARCHAR(600),
                    specialisedZoneType VARCHAR(600),
                    naturalAWBHMWB VARCHAR(600),
                    reservoir VARCHAR(600),
                    surfaceWaterBodyTypeCode VARCHAR(600),
                    subUnitIdentifier VARCHAR(600),
                    rbdIdentifier  VARCHAR(600),
                    rbdName VARCHAR(600),
                    lon FLOAT,
                    lat FLOAT,
                    statusCode VARCHAR(600))""")

for row in spatial.itertuples():
    cursor.execute("""
                    INSERT INTO spatial_data (ID, countryCode, thematicIdIdentifier, monitoringSiteIdentifier,
                        monitoringSiteIdentifierScheme, monitoringSiteName, waterBodyIdentifier, waterBodyIdentifierScheme,
                        waterBodyName, specialisedZoneType, naturalAWBHMWB, reservoir, surfaceWaterBodyTypeCode,
                        subUnitIdentifier, rbdIdentifier, rbdName, lon, lat, statusCode)
                    VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""",
                    row.ID,
                    row.countryCode,
                    row.thematicIdIdentifier,
                    row.monitoringSiteIdentifier,
                    row.monitoringSiteIdentifierScheme,
                    row.monitoringSiteName,
                    row.waterBodyIdentifier,
                    row.waterBodyIdentifierScheme,
                    row.waterBodyName,
                    row.specialisedZoneType,
                    row.naturalAWBHMWB,
                    row.reservoir,
                    row.surfaceWaterBodyTypeCode,
                    row.subUnitIdentifier,
                    row.rbdIdentifier,
                    row.rbdName,
                    row.lon,
                    row.lat,
                    row.statusCode
                    )
connection.commit()

# %%
pd.read_sql_query("""SELECT DISTINCT(countryCode) 
                     FROM spatial_data""", connection)
# Out:
# C:\Users\elisa\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    countryCode
# 0           EE
# 1           TR
# 2           HU
# 3           AT
# 4           DE
# 5           RS
# 6           BE
# 7           BA
# 8           ME
# 9           SE
# 10          CZ
# 11          LI
# 12          IT
# 13          NL
# 14          IS
# 15          RO
# 16          SI
# 17          MT
# 18          XK
# 19          DK
# 20          BG
# 21          UK
# 22          CH
# 23          IE
# 24          HR
# 25          EL
# 26          PL
# 27          LT
# 28          LV
# 29          CY
# 30          FR
# 31          AL
# 32          MK
# 33          PT
# 34          SK
# 35          ES
# 36          NO
# 37          LU
# 38          FI

# %% [markdown]
# The connection to the SQL server database and the creation of the table were completed with success.

# %% [markdown]
# <a id = 'table_emissions'></a>
# #### 2.1.2 Create table with emissions water quantity data
# [Top](#top)

# %%
cursor.execute("""
                DROP TABLE IF EXISTS emissions_data;
                
                CREATE TABLE emissions_data (
                    countryCode VARCHAR(10),
                    spatialUnitIdentifier VARCHAR(400),
                    spatialUnitIdentifierScheme VARCHAR(400),
                    observedPropertyDeterminandCode VARCHAR(400),
                    observedPropertyDeterminandLabel VARCHAR(400),
                    parameterEmissionsSourceCategory VARCHAR(10),
                    parameterEPRTRfacilities VARCHAR(10),
                    procedureEmissionsMethod VARCHAR(400),
                    resultObservationStatus VARCHAR(400),
                    Remarks VARCHAR(600),
                    UID INT PRIMARY KEY,
                    resultsEmissionsValueNEW FLOAT,
                    resultEmissionsUomNEW VARCHAR(10),
                    TimeReferenceStart INT,
                    TimeReferenceEnd INT)""")

for row in emissions_df_raw.itertuples():
    cursor.execute("""
                    INSERT INTO emissions_data (countryCode, spatialUnitIdentifier, spatialUnitIdentifierScheme,
                        observedPropertyDeterminandCode, observedPropertyDeterminandLabel, parameterEmissionsSourceCategory,
                        parameterEPRTRfacilities, procedureEmissionsMethod, resultObservationStatus, Remarks, UID,
                        resultsEmissionsValueNEW, resultEmissionsUomNEW, TimeReferenceStart, TimeReferenceEnd)
                    VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""",
                    row.countryCode,
                    row.spatialUnitIdentifier,
                    row.spatialUnitIdentifierScheme,
                    row.observedPropertyDeterminandCode,
                    row.observedPropertyDeterminandLabel,
                    row.parameterEmissionsSourceCategory,
                    row.parameterEPRTRfacilities,
                    row.procedureEmissionsMethod,
                    row.resultObservationStatus,
                    row.Remarks,
                    row.UID,
                    row.resultsEmissionsValueNEW,
                    row.resultEmissionsUomNEW,
                    row.TimeReferenceStart,
                    row.TimeReferenceEnd)
connection.commit()

# %%
pd.read_sql_query("""SELECT countryCode, observedPropertyDeterminandLabel, TimeReferenceStart
                     FROM emissions_data WHERE TimeReferenceStart = '2017'""", connection)
# Out:
# C:\Users\elisa\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#       countryCode                   observedPropertyDeterminandLabel  \
# 0              UK                                       Fluoranthene
# 1              UK  Total PAHs (4 PAHs: Benzo(a)pyrene, Benzo(b)fl...
# 2              UK                                          Cyanazine
# 3              UK                                             Diuron
# 4              UK                             Zinc and its compounds
# ...           ...                                                ...
# 10097          NO                                     Total nitrogen
# 10098          NO                                     Total nitrogen
# 10099          NO                                     Total nitrogen
# 10100          NO                                     Total nitrogen
# 10101          NO  Total PAHs (4 PAHs: Benzo(a)pyrene, Benzo(b)fl...
#
#        TimeReferenceStart
# 0                    2017
# 1                    2017
# 2                    2017
# 3                    2017
# 4                    2017
# ...                   ...
# 10097                2017
# 10098                2017
# 10099                2017
# 10100                2017
# 10101                2017
#
# [10102 rows x 3 columns]

# %% [markdown]
# The connection to the SQL server database and the creation of the table were completed with success.

# %% [markdown]
# <a id = 'table_monitoring'></a>
# #### 2.1.3 Create table with monitoring water data
# [Top](#top)

# %%
cursor.execute("""
                DROP TABLE IF EXISTS monitoring_data;
                
                CREATE TABLE monitoring_data (
                    countryCode VARCHAR(10),
                    monitoringSiteIdentifier VARCHAR(400),
                    monitoringSiteIdentifierScheme VARCHAR(400),
                    observedProperty VARCHAR(400),
                    phenomenonTimePeriod_year INT,
                    phenomenonTimePeriod_month INT,
                    phenomenonTimePeriod_day INT,
                    resultObservedValue FLOAT,
                    resultObservationStatus VARCHAR(400),
                    metadata_statusCode VARCHAR(400),
                    metadata_observationStatus VARCHAR(400),
                    UID INT PRIMARY KEY,
                    phenomenonTimePeriodStart DATE,
                    phenomenonTimePeriodEnd DATE,
                    resultObservedUnit VARCHAR(400))
                """)

for row in monitoring_surf.itertuples():
    cursor.execute("""
                    INSERT INTO monitoring_data (countryCode, monitoringSiteIdentifier,
                  monitoringSiteIdentifierScheme, observedProperty, phenomenonTimePeriod_year, 
                  phenomenonTimePeriod_month, phenomenonTimePeriod_day, resultObservedValue, resultObservationStatus,
                  metadata_statusCode, metadata_observationStatus, UID, phenomenonTimePeriodStart,
                  phenomenonTimePeriodEnd, resultObservedUnit)
                    VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""",
                  row.countryCode,
                  row.monitoringSiteIdentifier,
                  row.monitoringSiteIdentifierScheme,
                  row.observedProperty,
                  row.phenomenonTimePeriod_year,
                  row.phenomenonTimePeriod_month,
                  row.phenomenonTimePeriod_day,
                  row.resultObservedValue,
                  row.resultObservationStatus,
                  row.metadata_statusCode,
                  row.metadata_observationStatus,
                  row.UID,
                  row.phenomenonTimePeriodStart,
                  row.phenomenonTimePeriodEnd,
                  row.resultObservedUnit,
                  )
connection.commit()

# %%
pd.read_sql_query("""SELECT countryCode, phenomenonTimePeriod_year, resultObservedValue
                    FROM monitoring_data
                    WHERE countryCode IN ('IT', 'AT')""", connection)
# Out:
# C:\Users\elisa\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#        countryCode  phenomenonTimePeriod_year  resultObservedValue
# 0               AT                       2007                 26.3
# 1               AT                       2007                 25.8
# 2               AT                       2007                 25.1
# 3               AT                       2007                 24.6
# 4               AT                       2007                 25.5
# ...            ...                        ...                  ...
# 520503          IT                       2019                  1.8
# 520504          IT                       2019                  1.8
# 520505          IT                       2019                  2.0
# 520506          IT                       2019                  1.7
# 520507          IT                       2019                  1.7
#
# [520508 rows x 3 columns]

# %% [markdown]
# The connection to the SQL server database and the creation of the table were completed with success.

# %% [markdown]
# <a id = 'table_aggregated'></a>
# #### 2.1.4 Create table with measured water quality data
# [Top](#top)

# %%
cursor.execute("""
                DROP TABLE IF EXISTS measured_data;
                
                CREATE TABLE measured_data (
                    countryCode VARCHAR(10), 
                    monitoringSiteIdentifier VARCHAR(100),
                    monitoringSiteIdentifierScheme VARCHAR(100),
                    parameterWaterBodyCategory VARCHAR(10),
                    observedPropertyDeterminandCode VARCHAR(100),
                    observedPropertyDeterminandLabel VARCHAR(400),
                    procedureAnalysedMatrix VARCHAR(100),
                    resultUom VARCHAR(100),
                    phenomenonTimeReferenceYear INT,
                    procedureLOQValue FLOAT,
                    resultNumberOfSamples INT,
                    resultQualityNumberOfSamplesBelowLOQ INT,
                    resultQualityMinimumBelowLOQ VARCHAR(10),
                    resultMinimumValue FLOAT,
                    resultQualityMeanBelowLOQ VARCHAR(10),
                    resultMeanValue FLOAT,
                    resultQualityMaximumBelowLOQ VARCHAR(10),
                    resultMaximumValue FLOAT,
                    resultQualityMedianBelowLOQ VARCHAR(10),
                    resultMedianValue FLOAT,
                    resultStandardDeviationValue FLOAT,
                    UID INT PRIMARY KEY,
                    parameterSamplingPeriodStart DATE,
                    parameterSamplingPeriodEnd DATE)
                """)

for row in aggregated_rw_lw.itertuples():
    cursor.execute("""
                    INSERT INTO measured_data (countryCode, monitoringSiteIdentifier,
                  monitoringSiteIdentifierScheme, parameterWaterBodyCategory, observedPropertyDeterminandCode,
                  observedPropertyDeterminandLabel, procedureAnalysedMatrix,
                  resultUom, phenomenonTimeReferenceYear, procedureLOQValue, resultNumberOfSamples,
                  resultQualityNumberOfSamplesBelowLOQ, resultQualityMinimumBelowLOQ, resultMinimumValue,
                  resultQualityMeanBelowLOQ, resultMeanValue, resultQualityMaximumBelowLOQ, resultMaximumValue,
                  resultQualityMedianBelowLOQ, resultMedianValue, resultStandardDeviationValue,
                  UID, parameterSamplingPeriodStart, parameterSamplingPeriodEnd)
                    VALUES (?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?,?)""",
                  row.countryCode,
                  row.monitoringSiteIdentifier,
                  row.monitoringSiteIdentifierScheme,
                  row.parameterWaterBodyCategory,
                  row.observedPropertyDeterminandCode,
                  row.observedPropertyDeterminandLabel,
                  row.procedureAnalysedMatrix,
                  row.resultUom,
                  row.phenomenonTimeReferenceYear,
                  row.procedureLOQValue,
                  row.resultNumberOfSamples,
                  row.resultQualityNumberOfSamplesBelowLOQ,
                  row.resultQualityMinimumBelowLOQ,
                  row.resultMinimumValue,
                  row.resultQualityMeanBelowLOQ,
                  row.resultMeanValue,
                  row.resultQualityMaximumBelowLOQ,
                  row.resultMaximumValue,
                  row.resultQualityMedianBelowLOQ,
                  row.resultMedianValue,
                  row.resultStandardDeviationValue,
                  row.UID,
                  row.parameterSamplingPeriodStart,
                  row.parameterSamplingPeriodEnd)
connection.commit()

# %%
pd.read_sql_query("""SELECT observedPropertyDeterminandLabel, resultMeanValue FROM measured_data""", connection)
# Out:
# C:\Users\elisa\anaconda3\lib\site-packages\pandas\io\sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#         observedPropertyDeterminandLabel  resultMeanValue
# 0                              Phosphate         0.001956
# 1                              Phosphate         0.033000
# 2                              Phosphate         0.014861
# 3                              Phosphate         0.014250
# 4                                Nitrate         0.442700
# ...                                  ...              ...
# 3549399           Zinc and its compounds        50.000000
# 3549400       Chromium and its compounds         1.000000
# 3549401        Arsenic and its compounds         1.347500
# 3549402           Total suspended solids        17.500000
# 3549403                    Chlorophyll a        14.880000
#
# [3549404 rows x 2 columns]

# %% [markdown]
# The connection to the SQL server database and the creation of the table were completed with success.
